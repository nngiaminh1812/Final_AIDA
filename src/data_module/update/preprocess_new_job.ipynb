# %%
import pandas as pd
import re

# %% [markdown]
# # Xử lí file job post

# %%
#đọc file job post ..\..\..\..\data\raw\merged_job_posts.csv
df = pd.read_csv('../new_raw_jobs.csv', encoding='utf-8')
df
# Out:
#                    Type                                              Title  \
# 0             Đăng việc  \n                                Thiết kế web...
# 1             Đăng việc  \n                                Cần tìm ngườ...
# 2             Đăng việc  \n                                Cần xây dựng...
# 3   Chiến dịch hiển thị  \n                                    [S8] Rev...
# 4             Đăng việc  \n                                Thiết kế web...
# ..                  ...                                                ...
# 92            Đăng việc  \n                                Viết plugin ...
# 93            Đăng việc  \n                                Cần php seni...
# 94            Đăng việc  \n                                Tích hợp sàn...
# 95            Đăng việc  \n                                Cài đặt Seo ...
# 96            Đăng việc  \n                                Tích hợp API...
#
#                                              Services  \
# 0   \n                                        Dịch...
# 1   \n                                        Dịch...
# 2   \n                                        Dịch...
# 3                                                 NaN
# 4   \n                                        Dịch...
# ..                                                ...
# 92  \n                                        Dịch...
# 93  \n                                        Dịch...
# 94  \n                                        Dịch...
# 95  \n                                        Dịch...
# 96  \n                                        Dịch...
#
#                                                Skills  \
# 0   \nKỹ năng\n\n                                 ...
# 1   \nKỹ năng\n\n                                 ...
# 2   \nKỹ năng\n\n                                 ...
# 3                                                 NaN
# 4   \nKỹ năng\n\n                                 ...
# ..                                                ...
# 92  \nKỹ năng\n\n                                 ...
# 93  \nKỹ năng\n\n                                 ...
# 94  \nKỹ năng\n\n                                 ...
# 95  \nKỹ năng\n\n                                 ...
# 96  \nKỹ năng\n\n                                 ...
#
#                                           Description  \
# 0   \n\nCần tìm 1 team Thiết kế web cho trường học...
# 1   \n\nTôi cần tìm 3 bạn có thể xem videos và viế...
# 2   \n\nChào mọi người!\n\nMình đang muốn xây dựng...
# 3   \n\n\nMình muốn review cho tiệm kính mắt ở Đà ...
# 4   \n\nCần tìm 1 team Thiết kế web cho trường học...
# ..                                                ...
# 92  \n\nTôi cần viết mốt plugin cho phép kết nối đ...
# 93  \n\nlink dự án\n\nhttps://drive.google.com/dri...
# 94  \n\nTích hợp đơn hàng từ các sàn Shopee/Lazada...
# 95  \n\nMình có 1 trang web dùng vue 3, hiện tại k...
# 96  \n\nTích hợp API Kiotviet FnB vào website bán ...
#
#                                           In4_project  \
# 0   \n\nID dự án\n80678\nNgày đăng\n\n            ...
# 1   \n\nID dự án\n80660\nNgày đăng\n\n            ...
# 2   \n\nID dự án\n80700\nNgày đăng\n\n            ...
# 3   \n\nId\n80656\nNgày đăng\n\n                10...
# 4   \n\nID dự án\n80678\nNgày đăng\n\n            ...
# ..                                                ...
# 92  \n\nID dự án\n80358\nNgày đăng\n\n            ...
# 93  \n\nID dự án\n80352\nNgày đăng\n\n            ...
# 94  \n\nID dự án\n80348\nNgày đăng\n\n            ...
# 95  \n\nID dự án\n80343\nNgày đăng\n\n            ...
# 96  \n\nID dự án\n80328\nNgày đăng\n\n            ...
#
#                                        In4_employment  \
# 0   \n\n\n\n\n\n\n\n\n\n                        Ng...
# 1   \n\n\n\n\n\n\n\n\n\n                        Hi...
# 2   \n\n\n\n\n\n\n\n\n\n                        Pr...
# 3   \n\n\n\n\n\n\n\n\n\n                        Hư...
# 4   \n\n\n\n\n\n\n\n\n\n                        Ng...
# ..                                                ...
# 92  \n\n\n\n\n\n\n\n\n\n                        Ph...
# 93  \n\n\n\n\n\n\n\n\n\n                        Ng...
# 94  \n\n\n\n\n\n\n\n\n\n                        Đô...
# 95  \n\n\n\n\n\n\n\n\n\n                        Sa...
# 96  \n\n\n\n\n\n\n\n\n\n                        Re...
#
#                                        Num_applicants  \
# 0   \n                Chào giá:                   ...
# 1   \n                Chào giá:                   ...
# 2   \n                Chào giá:                   ...
# 3               \n                Số lượng hồ sơ 61\n
# 4   \n                Chào giá:                   ...
# ..                                                ...
# 92  \n                Chào giá:                   ...
# 93  \n                Chào giá:                   ...
# 94  \n                Chào giá:                   ...
# 95  \n                Chào giá:                   ...
# 96  \n                Chào giá:                   ...
#
#                                            Applicants  \
# 0   ['/freelancer/nguyen-nhat-hao-1', '/freelancer...
# 1   ['/freelancer/pham-minh-thuan-2', '/freelancer...
# 2   ['/freelancer/hoa-tuyet', '/freelancer/anh-tua...
# 3                                                 NaN
# 4   ['/freelancer/nguyen-nhat-hao-1', '/freelancer...
# ..                                                ...
# 92  ['/freelancer/long-pham-169', '/freelancer/le-...
# 93  ['/freelancer/le-quoc-viet-1', '/freelancer/tu...
# 94  ['/freelancer/kaio-ken', '/freelancer/to-coder...
# 95  ['/freelancer/thuong-son', '/freelancer/van-mo...
# 96                       ['/freelancer/huy-pham-361']
#
#                                              Duration  \
# 0   \n                Trung bình:                2...
# 1   \n                Trung bình:                6...
# 2   \n                Trung bình:                9...
# 3   \n                                            ...
# 4   \n                Trung bình:                2...
# ..                                                ...
# 92  \n                Trung bình:                4...
# 93  \n                Trung bình:                5...
# 94  \n                Trung bình:                1...
# 95  \n                Trung bình:                3...
# 96  \n                Trung bình:                3...
#
#                                                 Price  \
# 0   \n\n                Thấp nhất:                ...
# 1   \n\n                Thấp nhất:                ...
# 2   \n\n                Thấp nhất:                ...
# 3   \n\n                Tổng ngân sách 300.000 VNĐ...
# 4   \n\n                Thấp nhất:                ...
# ..                                                ...
# 92  \n\n                Thấp nhất:                ...
# 93  \n\n                Thấp nhất:                ...
# 94  \n\n                Thấp nhất:                ...
# 95  \n\n                Thấp nhất:                ...
# 96  \n\n                Thấp nhất:                ...
#
#                                                  Link
# 0   https://www.vlance.vn/viec-freelance/thiet-ke-...
# 1   https://www.vlance.vn/viec-freelance/can-tim-n...
# 2   https://www.vlance.vn/viec-freelance/can-xay-d...
# 3   https://www.vlance.vn/cd-tang-review/s8-review...
# 4   https://www.vlance.vn/viec-freelance/thiet-ke-...
# ..                                                ...
# 92  https://www.vlance.vn/viec-freelance/viet-plug...
# 93  https://www.vlance.vn/viec-freelance/can-php-s...
# 94  https://www.vlance.vn/viec-lam/tich-hop-san-sh...
# 95  https://www.vlance.vn/viec-lam/cai-dat-seo-cho...
# 96  https://www.vlance.vn/viec-freelance/tich-hop-...
#
# [97 rows x 12 columns]

# %%
df.isnull().mean() * 100
# Out:
# Type               0.000000
# Title              0.000000
# Services           1.030928
# Skills            21.649485
# Description        0.000000
# In4_project        0.000000
# In4_employment     0.000000
# Num_applicants     0.000000
# Applicants         1.030928
# Duration           0.000000
# Price              0.000000
# Link               0.000000
# dtype: float64

# %% [markdown]
# Loại bỏ các secret project vì chúng không có thông tin gì cả

# %%
#if type = "Secret project" thì drop
df = df[df['Type'] != 'Secret project']

# %%
df
# Out:
#                    Type                                              Title  \
# 0             Đăng việc  \n                                Thiết kế web...
# 1             Đăng việc  \n                                Cần tìm ngườ...
# 2             Đăng việc  \n                                Cần xây dựng...
# 3   Chiến dịch hiển thị  \n                                    [S8] Rev...
# 4             Đăng việc  \n                                Thiết kế web...
# ..                  ...                                                ...
# 92            Đăng việc  \n                                Viết plugin ...
# 93            Đăng việc  \n                                Cần php seni...
# 94            Đăng việc  \n                                Tích hợp sàn...
# 95            Đăng việc  \n                                Cài đặt Seo ...
# 96            Đăng việc  \n                                Tích hợp API...
#
#                                              Services  \
# 0   \n                                        Dịch...
# 1   \n                                        Dịch...
# 2   \n                                        Dịch...
# 3                                                 NaN
# 4   \n                                        Dịch...
# ..                                                ...
# 92  \n                                        Dịch...
# 93  \n                                        Dịch...
# 94  \n                                        Dịch...
# 95  \n                                        Dịch...
# 96  \n                                        Dịch...
#
#                                                Skills  \
# 0   \nKỹ năng\n\n                                 ...
# 1   \nKỹ năng\n\n                                 ...
# 2   \nKỹ năng\n\n                                 ...
# 3                                                 NaN
# 4   \nKỹ năng\n\n                                 ...
# ..                                                ...
# 92  \nKỹ năng\n\n                                 ...
# 93  \nKỹ năng\n\n                                 ...
# 94  \nKỹ năng\n\n                                 ...
# 95  \nKỹ năng\n\n                                 ...
# 96  \nKỹ năng\n\n                                 ...
#
#                                           Description  \
# 0   \n\nCần tìm 1 team Thiết kế web cho trường học...
# 1   \n\nTôi cần tìm 3 bạn có thể xem videos và viế...
# 2   \n\nChào mọi người!\n\nMình đang muốn xây dựng...
# 3   \n\n\nMình muốn review cho tiệm kính mắt ở Đà ...
# 4   \n\nCần tìm 1 team Thiết kế web cho trường học...
# ..                                                ...
# 92  \n\nTôi cần viết mốt plugin cho phép kết nối đ...
# 93  \n\nlink dự án\n\nhttps://drive.google.com/dri...
# 94  \n\nTích hợp đơn hàng từ các sàn Shopee/Lazada...
# 95  \n\nMình có 1 trang web dùng vue 3, hiện tại k...
# 96  \n\nTích hợp API Kiotviet FnB vào website bán ...
#
#                                           In4_project  \
# 0   \n\nID dự án\n80678\nNgày đăng\n\n            ...
# 1   \n\nID dự án\n80660\nNgày đăng\n\n            ...
# 2   \n\nID dự án\n80700\nNgày đăng\n\n            ...
# 3   \n\nId\n80656\nNgày đăng\n\n                10...
# 4   \n\nID dự án\n80678\nNgày đăng\n\n            ...
# ..                                                ...
# 92  \n\nID dự án\n80358\nNgày đăng\n\n            ...
# 93  \n\nID dự án\n80352\nNgày đăng\n\n            ...
# 94  \n\nID dự án\n80348\nNgày đăng\n\n            ...
# 95  \n\nID dự án\n80343\nNgày đăng\n\n            ...
# 96  \n\nID dự án\n80328\nNgày đăng\n\n            ...
#
#                                        In4_employment  \
# 0   \n\n\n\n\n\n\n\n\n\n                        Ng...
# 1   \n\n\n\n\n\n\n\n\n\n                        Hi...
# 2   \n\n\n\n\n\n\n\n\n\n                        Pr...
# 3   \n\n\n\n\n\n\n\n\n\n                        Hư...
# 4   \n\n\n\n\n\n\n\n\n\n                        Ng...
# ..                                                ...
# 92  \n\n\n\n\n\n\n\n\n\n                        Ph...
# 93  \n\n\n\n\n\n\n\n\n\n                        Ng...
# 94  \n\n\n\n\n\n\n\n\n\n                        Đô...
# 95  \n\n\n\n\n\n\n\n\n\n                        Sa...
# 96  \n\n\n\n\n\n\n\n\n\n                        Re...
#
#                                        Num_applicants  \
# 0   \n                Chào giá:                   ...
# 1   \n                Chào giá:                   ...
# 2   \n                Chào giá:                   ...
# 3               \n                Số lượng hồ sơ 61\n
# 4   \n                Chào giá:                   ...
# ..                                                ...
# 92  \n                Chào giá:                   ...
# 93  \n                Chào giá:                   ...
# 94  \n                Chào giá:                   ...
# 95  \n                Chào giá:                   ...
# 96  \n                Chào giá:                   ...
#
#                                            Applicants  \
# 0   ['/freelancer/nguyen-nhat-hao-1', '/freelancer...
# 1   ['/freelancer/pham-minh-thuan-2', '/freelancer...
# 2   ['/freelancer/hoa-tuyet', '/freelancer/anh-tua...
# 3                                                 NaN
# 4   ['/freelancer/nguyen-nhat-hao-1', '/freelancer...
# ..                                                ...
# 92  ['/freelancer/long-pham-169', '/freelancer/le-...
# 93  ['/freelancer/le-quoc-viet-1', '/freelancer/tu...
# 94  ['/freelancer/kaio-ken', '/freelancer/to-coder...
# 95  ['/freelancer/thuong-son', '/freelancer/van-mo...
# 96                       ['/freelancer/huy-pham-361']
#
#                                              Duration  \
# 0   \n                Trung bình:                2...
# 1   \n                Trung bình:                6...
# 2   \n                Trung bình:                9...
# 3   \n                                            ...
# 4   \n                Trung bình:                2...
# ..                                                ...
# 92  \n                Trung bình:                4...
# 93  \n                Trung bình:                5...
# 94  \n                Trung bình:                1...
# 95  \n                Trung bình:                3...
# 96  \n                Trung bình:                3...
#
#                                                 Price  \
# 0   \n\n                Thấp nhất:                ...
# 1   \n\n                Thấp nhất:                ...
# 2   \n\n                Thấp nhất:                ...
# 3   \n\n                Tổng ngân sách 300.000 VNĐ...
# 4   \n\n                Thấp nhất:                ...
# ..                                                ...
# 92  \n\n                Thấp nhất:                ...
# 93  \n\n                Thấp nhất:                ...
# 94  \n\n                Thấp nhất:                ...
# 95  \n\n                Thấp nhất:                ...
# 96  \n\n                Thấp nhất:                ...
#
#                                                  Link
# 0   https://www.vlance.vn/viec-freelance/thiet-ke-...
# 1   https://www.vlance.vn/viec-freelance/can-tim-n...
# 2   https://www.vlance.vn/viec-freelance/can-xay-d...
# 3   https://www.vlance.vn/cd-tang-review/s8-review...
# 4   https://www.vlance.vn/viec-freelance/thiet-ke-...
# ..                                                ...
# 92  https://www.vlance.vn/viec-freelance/viet-plug...
# 93  https://www.vlance.vn/viec-freelance/can-php-s...
# 94  https://www.vlance.vn/viec-lam/tich-hop-san-sh...
# 95  https://www.vlance.vn/viec-lam/cai-dat-seo-cho...
# 96  https://www.vlance.vn/viec-freelance/tich-hop-...
#
# [97 rows x 12 columns]

# %%
len(df)
# Out:
# 97

# %%
for index, row in df.iterrows():
    print(row['Title'])
# Out:
#                                 Thiết kế web cho trường học ở BIên Hòa Đồng Nai
#
#
#                                 Cần tìm người có thể xem videos và viết lại nội dung diễn ra trong video (mỗi videos từ 1s đến 10s)
#
#
#                                 Cần xây dựng trang web bán hàng                                                                                                                                    Mới
#
#
#                                     [S8] Review cho tiệm Kính Mắt ở Đà Nẵng - Ưu tiên Local Guide
#                                                                                                                                                                                                                                     Đã đảm bảo
#
#
#                                 Thiết kế web cho trường học ở BIên Hòa Đồng Nai
#
#
#                                 Kỹ sư phát triển / PMO
#
#
#                                 Lập trình phần mềm chấm công bằng CakePHP
#
#
#                                 Đăng nhập đặt lệnh tự động api của công ty cứng khoán ssi
#
#
#                                 Cần Team Phát Triển các tính năng cho web(API, BE, FE) sử dụng nodejs, Nextjs
#
#
#                                 Tìm chuyên gia giỏi toán lập trình bài toán xếp hình , sắp xếp sẵn code python
#
#
#                                 Tuyển lập trình Vuejs 3x + nodejs
#
#
#                                 Cần người viết app điều khiển xe Robo từ xa.
#
#
#                                 Hệ Thống Hỏi Đáp RAG                                                                    Hết hạn nhận chào giá
#
#
#                                 Viết tập lệnh python / thực thi tổng hợp và xử lý số liệu nhiều file excel kết xuất thành file dữ liệu                                                                    Hết hạn nhận chào giá
#
#
#                                 Tạo plugin wordpress                                                                    Hết hạn nhận chào giá
#
#
#                                 Xây dựng website giới thiệu khách sạn
#
#
#                                 Làm app ios chỉnh sửa ảnh
#
#
#                                 Xây dựng hệ thống ứng dụng Chat, Nhắn tin, Nhóm, Video call...
#
#
#
#                                 Chuyển gitlab từ server ubuntu lên k8s                                                                    Hết hạn nhận chào giá
#
#
#                                 Cắt HTML , CSS từ figma                                                                    Hết hạn nhận chào giá
#
#
#                                 Triển khai, vận hành các hệ thống Công nghệ
#
#
#                                 Mua Source Sàn Forex Trading                                                                    Hết hạn nhận chào giá
#
#
#                                 Setup server open VPN                                                                    Hết hạn nhận chào giá
#
#
#                                 Hướng dẫn tư vấn cấu hình hệ thống Docker                                                                    Hết hạn nhận chào giá
#
#
#                                 Hướng dẫn tư vấn cấu hình hệ thống Docker                                                                    Hết hạn nhận chào giá
#
#
#                                 Phát triển lib ads Admob mediation và MAX mediation cho IOS
#
#
#                                 Lập trình firmware nhúng                                                                    Hết hạn nhận chào giá
#
#
#                                 Tuyển quản lý SEO
#
#
#                                 Viết bài - tuyệt đối không dùng AI
#
#
#                                 Xây dựng hệ thống quản lý lỗ hổng                                                                    Hết hạn nhận chào giá
#
#
#                                 Tìm 2 tester thực hiện công việc dự án
#
#
#                                 Lập trình web python (Odoo)
#
#
#                                 Crawl nội dung của website                                                                    Hết hạn nhận chào giá
#
#
#                                 Cần 1 bạn nhân viên Remote Fulltime thành thạo Larksuite
#
#
#                                 Thiết kế 1 trang doanh thu cho sản phẩm                                                                    Hết hạn nhận chào giá
#
#
#                                 Cần tìm mua tài khoản UpWork đã verify
#
#
#                                 GPM LOGIN cần tìm người viết 1 scrip gpm login auto nhắn tin vào group telegram                                                                    Hết hạn nhận chào giá
#
#
#                                 Xây dựng hệ thống ứng dụng Chat, Nhắn tin, Nhóm, Video call...
#
#
#                                 Viết game telegram
#
#
#                                 Nâng cấp source code cũ lên phiên bản .net core 6,8 tùy ý                                                                    Hết hạn nhận chào giá
#
#
#                                 Cần tìm người SEO cho mình con Game nhỏ trên nền tảng Google Play
#
#
#                                 Viết tài liệu cho phầm mềm có sẵn                                                                    Hết hạn nhận chào giá
#
#
#                                 Thiết kế chức năng thanh toán bằng QR và sửa lại thông tin                                                                    Hết hạn nhận chào giá
#
#
#                                 Viết tài liệu phần mềm
#
#
#                                 Cần tuyển Freelancer SEO hoặc làm full time nếu đạt yêu cầu
#
#
#                                 Cần làm app tin tức về thị trường ck
#
#
#                                 Embedded Software
#
#
#                                 SEO_ASO cho app/web                                                                    Hết hạn nhận chào giá
#
#
#                                 Ứng dụng android chụp ảnh và in ra máy in ( photobooth )
#
#
#                                 Xây dựng website dùng Elementor                                                                    Hết hạn nhận chào giá
#
#
#                                 Tối Ưu Dữ Liệu Khách Hàng trên Google Sheet                                                                    Hết hạn nhận chào giá
#
#
#                                 Tìm team viết cho mình ứng dụng Chùa online
#
#
#                                 Thiết kế trang web bán hàng cao cấp                                                                    Hết hạn nhận chào giá
#
#
#                                 Code module nạp coin và rút coin từ ví vào balance trên web                                                                    Hết hạn nhận chào giá
#
#
#                                 Cần Tìm Người Viết 1 Tool automation nhắn tin vào group telegram theo kịch bản tin nhắn có sẵn                                                                    Hết hạn nhận chào giá
#
#
#                                 Xây dựng phần mềm quản lý trang thiết bị trên nền tảng python oddoo                                                                    Hết hạn nhận chào giá
#
#
#                                 Function Deposit Usdt to wallet                                                                    Hết hạn nhận chào giá
#
#
#                                 Tool lấy csv data của google map
#
#
#                                 Tìm đối tác cung cấp API của nhà mạng gửi tin nhắn cho số điện thoại
#
#
#                                 Cài source code The Shop lên tên miền của shop                                                                    Đã hoàn thành
#
#
#                                 Làm việc theo tính năng, update các module phần mềm                                                                    Hết hạn nhận chào giá
#
#
#                                 Tư vấn, xây dựng và cấu hình kubernets cho hệ thống server được xây dựng trên nền proxmox
#
#
#                                 Thiết kế web bán xe oto                                                                    Hết hạn nhận chào giá
#
#
#                                 Tạo wordpress plugin đăng nhập và crawl data                                                                    Hết hạn nhận chào giá
#
#
#                                 Cần người có kinh nghiệm lập trình Joomla Component
#
#
#                                 Thiết kết trang  web bán hàng                                                                    Hết hạn nhận chào giá
#
#
#                                 Cần tìm người sửa web tối ưu tốc độ load page                                                                    Hết hạn nhận chào giá
#
#
#                                 Lập trình web bằng nukeviet                                                                    Hết hạn nhận chào giá
#
#
#                                 Cần nâng cấp website dự trên webstie có sẵn
#
#
#                                 Crawl Data từ 1 Website                                                                    Đã hoàn thành
#
#
#
#                                 Website học tiếng anh                                                                    Hết hạn nhận chào giá
#
#
#                                 Thiết kế 1 trang landing page và 1 trang webapp                                                                    Hết hạn nhận chào giá
#
#
#                                 Khắc phục lỗi AMP
#
#
#                                 Cần bạn lấy Api trang web                                                                    Hết hạn nhận chào giá
#
#
#                                 Xây dưng game MU                                                                    Hết hạn nhận chào giá
#
#
#                                 Vượt captcha với node js sử dụng puppeteer                                                                    Hết hạn nhận chào giá
#
#
#                                 Làm project cho sinh viên còn 1 vài phần chưa hoàn thiện như call api và các phím chức năng                                                                    Hết hạn nhận chào giá
#
#
#                                 Mình cần làm website lập lá số tử vi
#
#
#                                 Lập bảng tính (chứa công thức) số liệu trong excel                                                                    Hết hạn nhận chào giá
#
#
#                                 Thiết kế App quản lý bảo trì
#
#
#                                 SEO blog về bất động sản, tài chính và affiliate sản phẩm công nghệ                                                                    Hết hạn nhận chào giá
#
#
#                                 Kiểm tra cấu hình Docker và kết nối Address Website                                                                    Đã hoàn thành
#
#
#                                 Kiểm tra cấu hình Docker và kết nối Address Website                                                                    Đã hoàn thành
#
#
#                                 Viết tool reg acc insta                                                                    Hết hạn nhận chào giá
#
#
#                                 Xây dựng web app quản lý đặt tiệc cưới & hội nghị                                                                    Hết hạn nhận chào giá
#
#
#                                 Cần dev website Reactjs                                                                    Hết hạn nhận chào giá
#
#
#                                 TMS cho 4PL Logistics                                                                    Hết hạn nhận chào giá
#
#
#                                 React.js Developer cho dự án Web và Mobile
#
#
#                                 .NET Developer cho dự án Web và Mobile
#
#
#                                 Hỗ trợ xin xét duyệt quyền pages_show_list, pages_messaging                                                                    Hết hạn nhận chào giá
#
#
#                                 Hỗ trợ cài đặt và hướng dẫn sử dụng web wordpress tin tức                                                                    Hết hạn nhận chào giá
#
#
#                                 Cần mua tool kết nối lấy đơn hàng từ 3 sàn Shopee, Lazada, Tiktok Shop                                                                    Hết hạn nhận chào giá
#
#
#                                 Viết plugin wordpress                                                                    Hết hạn nhận chào giá
#
#
#                                 Cần php senior maintain upgrade UI web theo figma                                                                    Hết hạn nhận chào giá
#
#
#                                 Tích hợp sàn Shopee/Lazada/Tiktok API                                                                    Hết hạn nhận chào giá
#
#
#                                 Cài đặt Seo cho website                                                                    Hết hạn nhận chào giá
#
#
#                                 Tích hợp API Kiotviet FnB vào website bán hàng                                                                    Hết hạn nhận chào giá

# %%
# Loại bỏ ký tự xuống dòng (\n) trong Title
df['Title'] = df['Title'].str.replace('\n', ' ')

# Do không cần dùng trạng thái công việc nên ta sẽ loại bỏ các giá trị "Đã hoàn thành", "Hết hạn nhận chào giá", "Mới
df['Title'] = df['Title'].str.replace('Đã hoàn thành|Hết hạn nhận chào giá|Mới', '', regex=True).str.strip()

# %%
df['Title']
# Out:
# 0       Thiết kế web cho trường học ở BIên Hòa Đồng Nai
# 1     Cần tìm người có thể xem videos và viết lại nộ...
# 2                       Cần xây dựng trang web bán hàng
# 3     [S8] Review cho tiệm Kính Mắt ở Đà Nẵng - Ưu t...
# 4       Thiết kế web cho trường học ở BIên Hòa Đồng Nai
#                             ...
# 92                                Viết plugin wordpress
# 93    Cần php senior maintain upgrade UI web theo figma
# 94                Tích hợp sàn Shopee/Lazada/Tiktok API
# 95                              Cài đặt Seo cho website
# 96       Tích hợp API Kiotviet FnB vào website bán hàng
# Name: Title, Length: 97, dtype: object

# %%
df['Services']
# Out:
# 0     \n                                        Dịch...
# 1     \n                                        Dịch...
# 2     \n                                        Dịch...
# 3                                                   NaN
# 4     \n                                        Dịch...
#                             ...
# 92    \n                                        Dịch...
# 93    \n                                        Dịch...
# 94    \n                                        Dịch...
# 95    \n                                        Dịch...
# 96    \n                                        Dịch...
# Name: Services, Length: 97, dtype: object

# %%
#Loại bỏ \n và "Dịch vụ cần thuê" trong Services
df['Services'] = df['Services'].str.replace('\n|Dịch vụ cần thuê:', '', regex=True).str.strip()

# %%
df['Services'].unique()
# Out:
# array(['Chuyển Template thành Website', 'Viết kịch bản cho video',
#        'Dựng website bán hàng', nan, 'Bảo trì các dự án phần mềm',
#        'Phát triển ứng dụng web', 'Xây dựng Web App MVC( .net)',
#        'Xây dựng website thương mại điện tử',
#        'Viết phần mềm theo yêu cầu', 'Làm Mobile App theo yêu cầu',
#        'Tạo mô hình Deep Learning', 'Lập trình phần mềm trên Excel',
#        'Xây dựng website wordpress', 'Làm app IOS',
#        'Chỉnh sửa shell script hệ thống', 'Cắt HTML/CSS từ PSD',
#        'Tư vấn giải pháp phần mềm', 'Cài đặt / Cấu hình server',
#        'SEO website', 'Viết nội dung cho website', 'Test và kiểm tra lỗi',
#        'Thiết kế mạch điện tử, PCB', 'Tối ưu SEO cho trang web',
#        'Làm ứng dụng Android theo yêu cầu',
#        'Chuyển template thành theme Wordpress',
#        'Thiết kế giao diện website', 'Xử lý dữ liệu',
#        'Viết nội dung cho blog', 'Nhập dữ liệu lên website'], dtype=object)

# %%
df['Skills']
# Out:
# 0     \nKỹ năng\n\n                                 ...
# 1     \nKỹ năng\n\n                                 ...
# 2     \nKỹ năng\n\n                                 ...
# 3                                                   NaN
# 4     \nKỹ năng\n\n                                 ...
#                             ...
# 92    \nKỹ năng\n\n                                 ...
# 93    \nKỹ năng\n\n                                 ...
# 94    \nKỹ năng\n\n                                 ...
# 95    \nKỹ năng\n\n                                 ...
# 96    \nKỹ năng\n\n                                 ...
# Name: Skills, Length: 97, dtype: object

# %%
df.iloc[3]['In4_project']
# Out:
# '\n\nId\n80656\nNgày đăng\n\n                10/11/2024            \nChỉ còn\n27 ngày 16 giờ\nTổng ngân sách\n\n                300.000đ                            \nSố review yêu cầu\n30\nSố tiền trả cho 1 review\n10.000đ\n\n'

# %%
# Loại bỏ ký tự xuống dòng (\n) và từ "Kỹ năng" trong Skills
df['Skills'] = df['Skills'].str.replace(r'\n|Kỹ năng', '', regex=True).str.strip()

# Loại bỏ khoảng trắng thừa trước dấu phẩy (nếu có)
# df['Skills'] = df['Skills'].str.replace(' ,', ',', regex=False).str.strip()
df['Skills'] = df['Skills'].str.replace(r'\s*,\s*', ',', regex=True)

# %%
df['Skills']
# Out:
# 0                                          Thiết kế web
# 1                                           Copywriting
# 2     jQuery,Thiết kế Banner,Thiết kế logo,Node.js,L...
# 3                                                   NaN
# 4                                          Thiết kế web
#                             ...
# 92                                     Wordpress,Plugin
# 93                                            PHP,Figma
# 94                        PostgreSQL,Shopee,Tiktok Shop
# 95                             SEO,Vue.js và express.js
# 96                                   Wordpress,Bán hàng
# Name: Skills, Length: 97, dtype: object

# %%
#Đổi "\n" thành " " trong Description
df['Description'] = df['Description'].str.replace('\n', ' ').str.strip()
df['Description'].unique()
# Out:
# array(['Cần tìm 1 team Thiết kế web cho trường học ở BIên Hòa Đồng Nai. Có xuất được VAT.',
#        'Tôi cần tìm 3 bạn có thể xem videos và viết lại nội dung diễn ra trong videos.  Đã công cụ để các bạn xem videos và viết nội dung nhanh gọn.  Tôi cần người làm lâu dài vì số lượng videos rất nhiều.  Mỗi videos từ 1s đến 10s.  Chi phí sẽ tính theo số lượng videos bạn đã làm được và nội dung bạn nhập vào chi tiết đến đâu.  Trung bình mỗi videos sẽ được trả 3.000đ - 5.000đ.  Xem file đính kèm để làm bài test.',
#        'Chào mọi người!  Mình đang muốn xây dựng trang web bán hàng thưc phẩm sạch.  Web phải trải nghiệm tốt trên mobile.   Cơ bản là giống web này (Soibien.vn)  Yêu cầu có kinh nghiệm làm web bán hàng.  Chứng minh năng lực bằng demo web đã làm, cả làm cả học vui lòng không liên hệ đỡ mất thời gian của nhau.',
#        'Mình muốn review cho tiệm kính mắt ở Đà Nẵng, ưu tiên AE có tài khoản Local guide cao  AE vui lòng để ảnh chụp màn hình thể hiện cấp độ tài khoản nếu muốn dc ưu tiên nhé   Yêu cầu về hồ sơ tham gia - Tài khoản đã từng có ít nhất 3 review hiển thị công khai  - Đánh giá 5 sao theo yêu cầu  - Đánh giá phải được HIỂN THỊ CÔNG KHAI tối thiểu 15 ngày',
#        'Đối tác bên mình là cty Startup của Nhật mong muốn tuyển dụng Freelancer như dưới đây. ( dự kiến 2025 sẽ mở văn phòng ở VN nên nếu 2 bên hợp tác tốt sẽ được nhận làm Core member khi cty con ở VN đi vào hoạt động)    Yêu cầu tuyển dụng Vị trí: Kỹ sư phát triển / PMO   Nội dung công việc: Tham gia vào phát triển hệ thống đa dạng như front-end, back-end, cơ sở dữ liệu, và các công việc PMO. Tham gia vào dự án từ giai đoạn ban đầu, chịu trách nhiệm thúc đẩy toàn bộ dự án bao gồm định nghĩa yêu cầu, quản lý lịch trình, và điều phối với khách hàng.   Kỹ năng và kinh nghiệm yêu cầu:  Kinh nghiệm phát triển:  Phát triển front-end: Có kinh nghiệm thực tế phong phú về phát triển front-end cho web và di động (HTML, CSS, JavaScript, v.v.)  Phát triển cơ sở dữ liệu: Kinh nghiệm xây dựng và vận hành cơ sở dữ liệu như SQL hoặc NoSQL  Phát triển API: Có kinh nghiệm thiết kế, phát triển và triển khai RESTful API  Kinh nghiệm PMO:  Định nghĩa yêu cầu ban đầu: Liên kết với khách hàng để xây dựng định nghĩa yêu cầu ban đầu và làm rõ các yêu cầu kinh doanh  Quản lý lịch trình dự án: Có kinh nghiệm tạo lịch trình và quản lý tiến độ, bao gồm điều phối với các bên liên quan  Yêu cầu ngôn ngữ: Người có khả năng giao tiếp trôi chảy bằng tiếng Nhật hoặc tiếng Anh (trình độ kinh doanh)  Địa điểm làm việc: Hà Nội (có thể làm việc từ xa)  Thời gian làm việc: Thứ Hai đến thứ Sáu, 9:00 đến 18:00 (có thể thỏa thuận)  Công tác: Có khả năng đi công tác nội địa Nhật Bản (người có thể đi công tác trong khoảng 1 tuần)',
#        '- quản lý phê duyệt ngày nghỉ phép  - quản lý phê duyệt làm ngoài giờ  - quản lý phê duyệt ngày công tác  - quản lý chấm công hàng tháng',
#        'Cần làm một tool đăng nhập và đặt lệnh tự động thông qua api của công ty chứng khoán SSI cung cầp viết bằng c# mvc',
#        'Cần Team Phát Triển các tính năng cho web(API, BE, FE) sử dụng nodejs, Nextjs  BẮT BUỘC:   - Team ở Hồ Chí Minh, Ưu tiên team size 3-5 bạn.  - Website bên mình đã có sẵn, cần phát triển thêm các tính năng, fix lỗi, tối ưu website.   - Team đã làm website thương mại điện tử rồi, Mình cần làm website có thể đáp ứng được lượng traffic lớn (100k traffic trong 30p)   - Thời gian dự án 2 tháng.',
#        'Mình hiện tại đang có sẵn code pythol tính toán và xếp hình nhưng muốn chuyển đổi thành nodejs.   Yêu cầu biết tính toán, bài toán chủ yếu xoay quanh việc xếp hình và chọn ra phương án tối ưu nhất. Xếp hình tròn, vuông, chữ nhật trong phạm vi cho phép và nhiều kích thước khác nhau.  Ochin-ba-bay-chin-nam-chin-sau-sau-chin',
#        'Yêu cầu thành thạo nodejs + vuejs kinh nghiệm 3 năm trở lên, đã từng sử dụng các module, plugin chỉnh sủa hình ảnh trong vuejs là một lới thế.  Làm việc theo dự án',
#        'Mô tả: app dùng để điều khiển xe robo khác từ xa.  Có sử dụng camera bên trong hoặc ngoài qua cổng usb.  Kết nối với xe thông qua Bluetooth từ xa, có quyền thay đổi wifi xe robo.  Có tính năng quản lý các user khi đăng nhập.  Có quyền sử dụng GPS để theo dõi tuyến đã đi.  Có các panel điều khiển khác nhau để gán cho các user tùy tính năng mà panel sẽ khác nhau.  Có thêm tính năng nhỏ để có thể remote control và xem camera từ xa khi login trên web.',
#        'Sử dụng RAG cho hệ thống hỏi đáp  Triển khai từng module của RAG.',
#        'Vấn đề: Doanh thu nhiều kênh, nhiều format khác nhau cần được đối soát / lọc, kết xuất thành file doanh thu hoàn chỉnh hàng tháng.  Yêu cầu: Tạo file thực thi bằng python/exe thực hiện tự động kết xuất tác vụ theo yêu cầu.',
#        'Tôi cần 1 wordpress plugin cho phép người dùng tự động lấy nội dung post từ 1 kiểu website có tài khoản đăng nhập.  https://community.lexinfocus.com/  https://community.askraghuraj.com/  https://community.limitlessme.ca/  Tất cả website này đều tạo ra từ 1 nền tảng , bộ khung giống nhau mặc dù nội dung khác nhau   có 1 form cho người dùng nhập email, pass, link website',
#        '- Từ 1 web đã có sẵn cần xây dựng lại website cho hệ thống khách sạn bằng wordpress   - Có thể có các customize về bố cục, màu sắc, nội dung ở các page khác nhau  - Cần responsive min size iphone 11',
#        'mình muốn làm 1 app chỉnh sửa ảnh giống các app photoroom có các tính năng xóa font nền, xóa vật thể v.v.v',
#        'Xây dựng ứng dụng mobile (android, ios) và xử lý backend (Spring framework) gồm các chức năng cơ bản như Nhắn tin, chat nhóm, video call...',
#        'cần chuyển hạ tầng của gitlab từ ubuntu lên k8s. Cần hoàn thiện trong 2 ngày cuối tuần',
#        'Chuyển một thiết kế từ Figma sẵn có sang HTML và CSS',
#        'Ứng dụng mạng xã hội cần hợp tác với cá nhân hoặc team để triển khai các hệ thống sau:  - hệ thống LMS (hệ thống quản lý lớp học)  - Hệ thống OTT  - hệ thống booking OTA  - Hệ thống bán hàng B2B, sàn TMĐT  - Hệ thống quản lý server meeting  - Short video, streaming  - hệ thống quản lý cổng thanh toán.  [được ẩn bỏi vlance.vn]',
#        'Yêu cầu Tính năng:  1. Đăng ký/Đăng nhập (register/login):  - Tích hợp oAuth để người dùng có thể đăng ký/đăng nhập một cách dễ dàng và an toàn.  2. KYC (Xác thực danh tính):  - Hệ thống KYC để xác thực thông tin cá nhân, bảo mật cho người dùng và tuân thủ quy định pháp lý.  3. Nạp/Rút tiền (deposit/withdraw):  - Fiat: Hỗ trợ nạp/rút qua các kênh thanh toán truyền thống.  - USDT (BEP20): Hỗ trợ nạp/rút tiền qua token USDT trên mạng lưới BEP20.  4. Tích hợp Liquidity & Order Matching với MT4/MT5:  - Kết nối với hệ thống MT4/MT5 để cung cấp thanh khoản và thực hiện các lệnh mua bán một cách chính xác và nhanh chóng.  Yêu cầu Kinh nghiệm:  - Đã có kinh nghiệm phát triển sàn giao dịch Forex hoặc các sàn giao dịch tương tự.  - Có sẵn demo và source code của dự án tương tự để tham khảo.  - Khả năng chỉnh sửa giao diện UI theo yêu cầu của chúng tôi, đảm bảo trải nghiệm người dùng thân thiện và chuyên nghiệp.  Ưu tiên:  - Freelancer có thể làm việc và bàn giao trong thời gian sớm.  - Đảm bảo tính bảo mật và độ tin cậy của hệ thống.  - Có thể trao đổi trực tiếp tại Hà Nội',
#        'Tôi cần cài đặt server open VPN (win server hoặc ....) và kết nối vpn tới các vpn client là thiết bị mạng (Broadband router có support vpn).',
#        '- Giao diện máy chủ trong Docker sử dụng Portainer để quản lý  - Lỗi thiết lập có tạo 3 Volume mới cho từng container, trong loadbalancer đã tạo "Cp Default Server1, Server2, Server3"  - Các Data và port đều chạy lên Aapanel  - Trỏ ip về tên miền website không hiển thị được',
#        'Xậy dựng thư viện Lib ads Admob Mediation và MAX mediation bidding, waterfall bằng ngôn ngữ Swift cho Mobile App IOS,  Tích hợp các mạng quảng cáo  + Admob  + Meta  + Mintegral  + Applovin  + DT Exchange  + Liftoff',
#        'Cần một bạn có kinh nghiệm lập trình nhúng tốt làm về STM32 điều khiển động cơ ,liên quan đến PID ,i2c,SPI,giao tiếp với linux PC qua USB, làm giao diện điều khiển và hiển thị trên linux',
#        'Chúng tôi đang tìm kiếm Quản lý SEO có kinh nghiệm đưa nhiều từ khóa lên Top Google. Nếu bạn tự tin vào khả năng SEO của mình và có thể làm việc toàn thời gian online, đừng ngại hãy nộp đơn cho công ty!  Yêu cầu:  • Có kinh nghiệm về SEO và thành tích đã được chứng minh trong việc đưa nhiều từ khóa lên đầu kết quả tìm kiếm. Vui lòng cung cấp bằng chứng cụ thể về các dự án thành công của bạn.  • Bắt buộc phải phản hồi nhanh khi chat  • Viết bài và làm các việc liên quan đến SEO mỗi ngày. Báo cáo hàng ngày về Google search console và các hành động để SEO mỗi ngày  • Quản lý SEO cho nhiều trang web cùng lúc, đảm bảo chất lượng và đáp ứng thời hạn.  **Trách nhiệm công việc:**  1. Giao tiếp với khách hàng: Trả lời các câu hỏi, giải quyết vấn đề và duy trì mối quan hệ tốt với khách hàng.  2. Biên tập trang web: Cập nhật nội dung, tối ưu hóa SEO trên trang và thực hiện các điều chỉnh cần thiết cho trang web.  3. Quản lý nhóm: Phối hợp với những người viết nội dung, quản lý Backlink và giám sát tiến độ công việc.  4. Tạo và quản lý Google Sheet: Theo dõi dữ liệu, quản lý mốc thời gian của dự án và thực hiện các nhiệm vụ khác liên quan đến trợ lý khi được yêu cầu.  Yêu cầu đặc biệt:  • Phải có khả năng làm việc toàn thời gian, không có cam kết xung đột nào khác.  • Sẵn sàng đảm nhận khối lượng công việc lớn và cam kết hợp tác lâu dài với công ty.  • Sẽ được ưu tiên nếu bạn có niềm đam mê mạnh mẽ với phục vụ khách hàng và tìm thấy niềm vui khi thấy khách hàng hài lòng.  Quyền lợi:  • Môi trường làm việc chuyên nghiệp với nhiều cơ hội phát triển.  • Nhận cố định : 5.000.0000 đ/ tháng  . Thưởng : từ 1.000.000 => 3.000.000 đ/tháng  Vui lòng đọc kỹ tin đăng tuyển. Bạn phải có thể đáp ứng mọi yêu cầu được liệt kê ở đây. Nếu không, vui lòng không báo giá để tránh lãng phí thời gian của bạn.  Nếu bạn tự tin vào kinh nghiệm SEO của mình và đang tìm kiếm một công việc trực tuyến từ xa với thu nhập ổn định, đừng ngần ngại nộp đơn ngay!',
#        'Tuyển bạn viết bài - không copy từ AI   Khả năng viết tốt, viết được khoảng 1 - 2 bài/ ngày. (Nếu viết được hơn càng tốt)   Bài viết được tính là 1 bài post hoàn chỉnh lên website đã bao gồm hình ảnh và tối ưu.   Trả theo bài viết : 50đ/ từ. (bài 1800 từ = 90,000đ)   Yêu cầu bắt buộc : Tuyệt đối không dùng AI - nếu vi phạm sẽ phải chịu mọi trách nhiệm hậu quả.   Google đang phạt nội dung từ AI, kể cả có là 8% nội dung AI trong bài viết.   Thường xuyên online, rep tin nhắn nhanh là lợi thế.',
#        'Tạo trang web có chứa danh sách cve, tạo 1 server có cài openvas và quét hệ thống có cài project chứa cve khi detech được cve thì trả về cho quản trị viên và lấy thông tin đưa ra solutions. Ngoài ra chọn 1-2 cve tiêu biểu để demo tấn công và cách fix',
#        'Hiện tại công ty chúng tôi cần tìm 2 bạn tester làm việc tại công ty trong thời gian 4 tháng. Yêu cầu công việc  - Viết testcase kiểm thử module/chức năng  - Thực hiện test chức năng theo yêu cầu  - Có kỹ năng phân tích nghiệp vụ, viết tài liệu srs là một lợi thế  Thanks',
#        'Cần lập trình nâng cấp 2 module trong Odoo   1. Project   2. To-do  Cụ thể : liên kết 2 module để có thể tạo dự án giao và quản lý công việc từng người theo dự án.',
#        'Tôi cần 1 web app cho phép người dùng tự động lấy nội dung từ 1 kiểu website có tài khoản đăng nhập.  https://community.lexinfocus.com/  https://community.askraghuraj.com/  https://community.limitlessme.ca/  nội dung khác nhau nhưng cùng 1 kiểu  có 1 form cho người dùng nhập email, pass, link',
#        'Thực hiện triển khai các dự án Larksuite cho KH  Làm remote, áp lực cao.',
#        'giao cần có biểu đồ, thống kê doanh thu, và ý tưởng tự sáng tạo',
#        'Mình cần tìm mua tài khoản UpWork đã verify, không cần có số công việc thành công nhiều.',
#        'auto nhắn tin seedding cho group,có chức năng trả lời tin nhắn theo cấu hình định sẵn (vd acc a nhắn 1 đoạn chat thì acc b sẽ rep đoạn tin nhắn đó',
#        'Xây dựng ứng dụng Mobile app (android, ios) và xử lý backend với Spring framework. Ứng dụng có các chức năng cơ bản như Nhắn tin, chat nhóm, video call, short video...',
#        'Game chạy trên app telegram. Ib cần gấp.  Báo giá thời gian hoàn thành',
#        'có source code sẵn .cần nâng cấp chuyển code sang phiên bản .net core 6 hoặc 8',
#        'Chào các bạn.  Mình đang cần tìm người SEO cho mình con Game mà bên mình phát triển trong giai đoạn vừa qua. Target thị trường Việt Nam và các nước nói tiếng anh cũng như Indonesia.  Game mình: https://play.google.com/store/apps/details?id=com.funkyland.tileconnecttravel  Cần tìm đối tác lâu dài nếu như mình làm tốt.  Thanks.',
#        'Mình cần tìm người viết đặc tả phần mềm + tài liệu sử dụng cho một phần mềm đã có sẵn',
#        'đã có sẵn 1 trang Web cho bạn, bạn chỉ cần thêm tính năng thanh toán bằng QR/ATM, và thêm 1 ít dữ liệu mà tôi cung cấp',
#        'Hiện tại mình đang có một trang web mình cần một bạn có thể viết hướng dẫn sử dụng trang web này cũng như mô tả thiết kế đặc biệt cho trang web như các tác nhân, bảng, sơ đồ, sau khi nhận việc liên lạc mình để bàn về chi tiết hơn',
#        'Bên mình cần các bạn freelancer hỗ trợ làm SEO cho web  Có thể hỗ trợ bên mình:  1/ Tư vấn từ khóa phù hợp, hiệu quả  2/ Suport viết bài content  3/ Đề xuất chỉnh sửa nội dung website cho phù hợp  4/ Support làm short video TikTok YouTube là 1 lợi thế  Có thể nhận làm full time nếu đạt được yêu cầu, hiệu quả.  Ưu tiên các bạn ở HCM',
#        'Chào các bạn  Mình cần làm 1 app dạng tin tức tài chính. Yêu cầu cụ thể trong file đính kèm  Bạn nào làm được vui lòng báo giá mình nha  Mình cảm ơn!',
#        'Lập trình Nhúng nghiên về software, hoặc mô phỏng Proteus...',
#        'Làm plan ASO cho app, plan SEO/SEM cho web.  Vận hành, optimise và performance cho app trong appstore  1. App: soctrip  2. App: Ziichat',
#        'Mình cần một app android có thể chụp ảnh sau đó in ra máy in Sam4s gcube 100s',
#        'Mình cần tìm 1 đối tác xây dựng website Wordpress sử dụng Elementor, dựa vào thiết kế UI/UX dưới đây.  https://www.figma.com/design/5JDCoLnfzMqF5S4ZGYbU9F/Landing---Lumi-Senique---STF-2024?node-id=1842-931&t=WOB08gWiyxnCWFpN-4  Đây là landing page nên chỉ cần làm trang chủ, và có thể cần thêm 1 trang chi tiết bài viết.  Tiêu chí làm nhanh nhất có thể, bám sát thiết kế, có thể tối ưu responsive cơ bản (các thành phần fit trong giao diện là được), có thể đề xuất các hiệu ứng hiển thị bổ sung nếu có thể.',
#        'Tuyển Freelancer Tối Ưu Dữ Liệu Khách Hàng trên Google Sheet  Công việc:  - Tối ưu dữ liệu khách hàng trên Google Sheet.  - Tạo Dashboard để tìm kiếm và hiển thị thông tin khách hàng.  - Kết nối VPS từ Google Sheet.  Yêu cầu:  Thành thạo Google Sheets nâng cao và Google Apps Script.  Có kinh nghiệm làm việc với API và kết nối VPS.  Khả năng xử lý, quản lý và tối ưu dữ liệu.  Quyền lợi:  Làm việc linh hoạt, cơ hội hợp tác lâu dài.',
#        'Xin chào mọi người.  Mình đang cần tìm team Viết cho mình ứng dụng Chùa Online và nó cần chạy trên cả hai nền tảng Android và IOS.  Ý tưởng là nơi dành cho Phật tử daily praying app trao đổi kinh nghiệm học phật cúng dường etc.  Công việc của các bạn sẽ trải qua các bước sau:  1. TIẾP NHẬN PHÂN TÍCH Ý TƯỞNG  - Lắng nghe và tiếp nhận ý tưởng của khách hàng.  - Tư vấn, phân tích rõ ràng về nhu cầu, nguyện vọng của khách hàng về sản phẩm.  - Lập kế hoạch thực hiện dự án, thiết kế cấu trúc sản phẩm.  - Thu thập thông tin khách hàng.  - Thống nhất với khách hàng về nội dung, cấu trúc của sản phẩm.  2. THIẾT KẾ VÀ XÂY DỰNG  - Xem xét yêu cầu và tiến hành thiết kế sản phẩm theo yêu cầu của khách hàng.  - Xây dựng cơ sở dữ liệu (nếu có), lắp ghép các phân tích thiết kế, nội dung thành một sản phẩm hoàn chỉnh.  - Kiểm tra và chỉnh sửa sản phẩm thật kỹ lưỡng, tránh xảy ra sai sót.  3. CHẠY THỬ VÀ CHỈNH SỬA  - Tiến hành hướng dẫn sử dụng cho đến lúc sử dụng thành thạo sản phẩm.  - Tiến hành chạy thử, đánh giá sản phẩm.  - Tiến hành chỉnh sửa nếu có xảy ra lỗi hoặc thiếu sót.  - Nếu sản phẩm đã hoàn thiện thì tiến hành chuyển giao cho khách hàng.  4. CHUYỂN GIAO  - Khách hàng duyệt dự án và xác nhận sản phẩm sử dụng tốt.  - Tiến hành chuyển giao sản phẩm, hướng dẫn khách hàng sử dụng.  - Đánh giá và bảo trì sản phẩm định kỳ.  Mình có thể tham khảo cách làm của các ứng dụng sau:  Sri Mandir - Daily Praying App  https://play.google.com/store/apps/details?id=com.mandir  OmAhHum - Phật giáo Toàn cầu  https://play.google.com/store/apps/details?id=com.thanhlv2.omahhum&hl=vi  Chùa Online | Niệm Phật Online  https://play.google.com/store/apps/details?id=com.ChuaOnline.TungKinhNiemPhat  Thanks.',
#        'Trang chủ, xem hàng, thanh toán, vận chuyển, up sản phẩm bằng hình ảnh và video, chăm sóc khách hàng',
#        'Mình đang cần code chức năng deposit và withdraw usdt từ wallet vào web asp.net mvc  Chi tiết sẽ trao đổi sau khi nhận thầu. Bạn nào đã có kinh nghiệm dev rồi bid mình nhé',
#        'các tính năng phụ như add proxy ,trả lời tin nhắn theo cấu hình đã định sẵn ,  login bằng tay bằng tài khoản mật khẩu ,ko login bằng tdataa hay sesson,',
#        'Chào cả nhà! hiện tại mình đang cần thuê 1 bạn giúp mình viết 1 phần mềm quản lý các trang thiết bị bao gồm máy tính, máy in, máy chiếu....các tình trạng kỹ thuật, số lượng, phân loại ....nên nền tảng web python odoo.   Đồng thời có khả năng viết báo cáo về kết quả phần mềm đã viết.  Bạn nào thực sự có kinh nghiệm, thì hãy vào ib. đừng làm mất thời gian của mình.  xin cám ơn',
#        'Mình cần viết module nạp usdt vào ví và rút usdt từ ví bằng asp.net mvc c#  Chi tiết trao đổi sau khi nhận dự án',
#        'Cần một bạn dev đã từng lấy data của google map thành file csv và có thể viết/bán lại tool cho mình sử dụng.  Yêu cầu: 1 UI đơn giản để nhập Keyword và Area, bấm Xuất ra CSV tương ứng',
#        'cần tìm được API nhà mạng hoặc đơn vị trực thuộc nhà mạng cung cấp được API/phần mềm gửi tin nhắn  - Không qua validate tin nhắn của nhà mạng, đảm bảo tin nhắn đến người nhận 100%, kể cả mạng mobifone, vinaphone.  - gửi được số lượng lớn tin nhắn trong thời gian ngắn, 1K~10K tin nhắn tới khách hàng luôn.  - Nội dung tin nhắn tự động spin nếu cần.  - Những mô hình gửi tin nhắn bằng điện thoại đăng kí sim sẵn không áp dụng được -> vì vẫn phải qua nhà mạng filter tin nhắn , chặn spam. cần giải pháp tối ưu hơn tât cả, gửi được tin nhắn mà không bị chặn (tỉ lệ thành công 100%)  - báo giá sau khi check đáp ứng được những yêu cầu trên.',
#        '- Cài source code lên Cpanel với tên miền theo yêu cầu',
#        'Hệ thống đã sẵn có, cần nâng cấp và phát triển mới các tính năng. Liên hệ để trao đổi chi tiết',
#        'Cần 1 bạn tư vấn và xây dựng và cấu hình hệ thống kubernetes doanh nghiệp cho các sản phẩm và dịch vụ của công ty  1. Các phần mềm như mariadb, mongodb, kafka  2. Image processing  3. ...  4. Backup data  Kết quả cần:  1. Tài liệu hướng dẫn sử dụng  2. Tài liệu đăng nhập',
#        'Như tiêu đề, mình cần làm web bán xe oto tương tự như trang https://hyundaiotonhatrang.com   Liê.n hệ: https://t.me/aressoft',
#        'Tôi cần tạo 1 wordpress plugin vượt qua login (có sẵn) và crawl nội dung của website ví dụ https://community.lexinfocus.com/ .',
#        'Mình cần build một Component Joomla về quản lý SP đơn giản  Không phải để bán hàng, cơ bản frontend sẽ có các view sau  Frontend  1. Product Detail + Related Product  2. Product Category + Filter Module  3. Module Search Product  Backend  1. Product CRUD  2. Category CRUD  3. Menu Item Products  ....  Chi tiết sẽ trao đổi sâu hơn',
#        'Tôi cần làm trang web bán hàng trung quốc.  Cụ thể là giống website này.  bachhoaxanh.com  Nếu ai làm được xin vui lòng liên hệ',
#        'Hiện tại mình đang có website wordpress chủ đề Nail Salon  Web gần hoàn thiện nhưng bạn nhân viên trước làm vẫn còn nhiều thiếu sót  Mình cần 1 bạn có kinh nghiệm làm Wordpress giúp mình tối ưu lại tốc độ load page  Fix một số lỗi về web',
#        'Mình cần 1 bạn làm web gồm các tính năng sau  - Trang chủ hiển thị danh sách: bộ lọc + phân trang  - Trang xem chi tiết có đăng nhập bên thứ 3 (đã có API) + like + bình luận và xem (webview 1 trang html có sẵn)',
#        'Tôi cần nâng cấp một webstie làm trên nền tảng php larvavel   Nâng cấp phát triển webstie cũ  Viết api thêm cho app  Chỉnh sửa ux giao diện cho dễ dùng theo yêu cầu',
#        'Mình cần Crawl hết data từ 1 site có sẵn (tài khoản và server chạy mình cung cấp)  Bạn có thể dùng bất kì ngôn ngữ nào bạn dev quen.  Mình cần xử lí gấp.  Bạn nào xử lí gấp được thì chào giá mình luôn nhé.  Inbox để mình gửi thông tin site chi tiết.',
#        'Làm một Website học tiếng anh qua youtube, dictation',
#        'tôi muốn thiết kế 1 trang landing page chủ yếu đánh bật sản phẩm để chạy quảng cáo và một trang webapp có tính năng giỏ hàng và thanh toán trực tuyến có trang admin quản lý sản phẩm, khách hàng, hoá đơn, nhân viên và báo cáo.  sản phẩm của tôi là về chụp ảnh mẫu vật, sản phẩm, chụp ảnh cưới,...  web app mở rộng sau này có thể mua bán cho thuê thiết bị chụp ảnh',
#        'Chào mọi người,  Website bên mình lúc trước bị hacker tấn công và thay đổi giao diện trang web (bên mình đã khắc phục được). Tuy nhiên  - Hacker đã thêm được admin và google webmaster tool, sau đó cấu hình AMP về web họ -- Mà bên mình vẫn chưa biết cách khắc phục  - Các bạn có kinh nghiệm trong việc xử lý AMP liên hệ bên mình nhé.  Cám ơn ạ.',
#        'Lấy api web coingecko và xử lý vài phép tính cộng trừ nhân chia  Liên hệ biết thêm tt  Thank các bạn',
#        'minh mua src game mu h5 cần tim dev triển khai và support hàng tháng kết nối cổng thanh toán quốc tế vào game',
#        'Mình đang sử dụng puppeteer để tự động hoá, nhưng hôm nay site nó đòi captcha dạng silder, mình cần vượt nó trên code node js. bạn nào xử lý được làm ngay nhé',
#        'đã có source code sẵn. chỉ viết hàm call api và các nút chức năng để hoàn chỉnh web',
#        'Chào mọi người  Mình đang có nhu cầu làm một website đơn giản, tương tự như một landing page. Chức năng chính của website đó là tạo lá số tử vi từ các thông tin ngày giờ tháng năm sinh . Từ thông tin đó tạo ra một file ảnh hiển thị lá số tử vi của khách.  Công thức kết hợp thông tin lá số mình đã có. Cần bạn nào biết lập trình làm việc này.  sdt mình [được ẩn bởi vlance]',
#        'Tôi cần lập 1 trang tính Excel chứa công thức tính toán các số liệu nhập vào để ra 1 kết quả cụ thể',
#        'Thiết kế APP sử dụng cho công ty cần có các chức năng chính như sau:  1) Quản lý tài sản.  2) Quản lý công việc.  3) Quản lý kế hoạch bảo trì.  4) Báo cáo, ghi nhận các thông tin tiến độ sau bảo trì.  5) Xuất được dữ liệu.  6) Bảo trì, chỉnh sửa app theo yêu cầu.  7) Sử dụng 2 ngôn ngữ Việt, Anh  ...',
#        'Tối ưu SEO cho blog, viết bài cho blog đạt KPI hàng tháng, SEO bền vững.',
#        'Kiểm tra website và Docker container của dự án,hỗ trợ cài đặt được ip cho website riêng biệt',
#        'Mình cần tool tự động tạo nick insta liên tục, đơn giản vậy thôi ạ. Lúc code chạy thì sẽ hiện ra "username, pass, cookie".',
#        'Mình đang cần tạo 1 web app tương đối đơn giản, sử dụng nội bộ, đáp ứng được mục đích công việc sau:  - Quản lý danh mục các sảnh tiệc.  - Quản lý danh mục các đồ ăn, đồ uống.  - Cho phép nhập thông tin đặt tiệc mới, trong đó thể hiện được các thông tin về thời gian, món ăn, voucher, chi phí, số tiền đã đặt cọc lần 1, lần 2,...  - Dashboard thể hiện được các tiệc đang được đặt dưới dạng bảng calendar để tiện quản lý.  - Quản lý phân công công việc, xuất phiếu chỉ định tiệc.  Chi tiết tính năng sẽ được trao đổi cụ thể khi làm việc (có hình ảnh trực quan của một web app sẵn có để dev dễ hình dung).',
#        'Team mình cần tuyển dev Reactjs làm part-time theo tasks (có thể xem xét nhận full-time nếu làm được việc). Ưu tiên các bạn ở HCM. Hãy liên lạc với mình để trao đổi cụ thể thêm về công việc.',
#        'Mô tả Dự án: Hệ thống Quản lý Xe Vận Tải cho 4PL**  **Mục tiêu**: Xây dựng hệ thống quản lý xe vận tải nhằm quản lý các thông tin liên quan đến booking, tình trạng container, lệnh lấy và hạ rỗng, cũng như tối ưu hóa lộ trình để giảm chi phí và tăng tính minh bạch. Hệ thống sẽ hỗ trợ các bên liên quan như shipper, 2PL, 3PL và 4PL, giúp họ theo dõi và quản lý các booking, lệnh DO và quy trình vận tải chi tiết.  ### **Chức năng chính**  1. **Quản lý Booking và Container**    - Tạo và duyệt booking mới với thông tin shipper, loại container, nơi lấy rỗng, nơi hạ đầy, hạn lệnh.   - Quản lý thông tin container: Số container, trạng thái (rỗng/đầy), số seal, ảnh chụp báo cáo.  2. **Lệnh Lấy Rỗng và Hạ Đầy cho Xuất Hàng**   - Nhà xe sẽ nhận được lệnh lấy rỗng với thời gian và nơi lấy chi tiết.   - Chụp ảnh kiểm tra tình trạng container, niêm phong (seal) và báo cáo lên hệ thống.   - Nhận lệnh hạ đầy, cập nhật mã hạ cảng và cập nhật trạng thái khi container đã về cảng.  3. **Quản lý DO và Hạ Rỗng cho Nhập Hàng**   - Tạo lệnh DO cho hàng nhập với các chi tiết về hạn lệnh, nơi dỡ hàng, nơi trả rỗng.   - Nhà xe cần cập nhật hình ảnh kiểm tra tình trạng container trước khi trả về bãi được chỉ định.  4. **Tối ưu hóa lộ trình và giảm chi phí**   - Đề xuất lộ trình và bãi rỗng gần nhất theo tuyến đường của nhà xe.   - Loại trừ các bãi có chi phí nâng hạ cao bất thường hoặc các terminal với phụ phí không hợp lý.  5. **Báo cáo và Giám sát**   - Gửi thông báo đến các bên liên quan khi có cập nhật mới về trạng thái container.   - Báo cáo tình trạng container, phiếu cân, hình ảnh chụp báo cáo để đảm bảo tính minh bạch.  ### **Kiến trúc Hệ thống**  - **Frontend**:    - Sử dụng **React.js** để xây dựng giao diện người dùng (UI) thân thiện, bao gồm các form tạo booking, quản lý lệnh lấy/hạ rỗng, và các bảng quản lý container, DO.  - **Backend**:   - **Node.js với Express** hoặc **Django** để xây dựng REST API cho các tính năng như tạo booking, cập nhật container, tạo DO, gửi thông báo.  - **Cơ sở dữ liệu**:   - **PostgreSQL** hoặc **MySQL** cho dữ liệu quan hệ, bao gồm booking, thông tin container, và lệnh DO.   - **Elasticsearch** cho khả năng tìm kiếm nhanh, tối ưu hóa truy vấn khi người dùng tìm booking, DO.  - **Bảo mật**:   - **JWT (JSON Web Token)** để xác thực người dùng, đảm bảo chỉ những người có quyền mới được truy cập thông tin.  ### **Các Tính năng API Chính**  1. **Booking API**:    - **POST /create-booking**: Tạo booking mới với các thông tin cơ bản như shipper, container, địa điểm lấy/hạ.   - **GET /bookings**: Xem danh sách các booking hiện tại.  2. **Container Management API**:   - **POST /containers/update**: Cập nhật thông tin container, bao gồm trạng thái, số seal, và hình ảnh chụp báo cáo.  3. **DO Management API**:   - **POST /do/create**: Tạo DO mới cho hàng nhập.   - **GET /do/:id**: Xem chi tiết DO theo ID.  4. **Notification API**:   - **POST /notifications/send**: Gửi thông báo khi có cập nhật mới cho các bên liên quan.  ### **Cấu trúc Giao diện Người Dùng (UI)**  1. **Form Tạo Booking**: Cho phép shipper hoặc nhà xe nhập thông tin booking.  2. **Trang Quản lý Container**: Cho phép nhà xe cập nhật trạng thái container, niêm phong, và báo cáo ảnh.  3. **Trang Quản lý DO**: Xem chi tiết DO và lịch sử cập nhật tình trạng container.  ### **Quy trình Công việc và Luồng Hệ thống**  1. **Booking được tạo**: Shipper hoặc 3PL tạo booking và lệnh được duyệt trên hệ thống.  2. **Nhận lệnh lấy rỗng**: Nhà xe nhận lệnh với thông tin chi tiết, bao gồm nơi lấy rỗng và hạn lệnh.  3. **Kiểm tra và báo cáo**: Nhà xe chụp ảnh kiểm tra tình trạng, niêm phong container, và cập nhật ảnh lên hệ thống.  4. **Hạ đầy container**: Sau khi container được đóng hàng và cân, nhà xe nhận mã hạ cảng, cập nhật và chụp ảnh báo cáo tại bãi.  5. **Trả rỗng với DO nhập hàng**: Nhà xe nhận DO, kiểm tra và cập nhật ảnh trả rỗng về bãi theo yêu cầu của khách hàng.  ### **Phát triển, Thử nghiệm, và Hỗ trợ**  - **Phát triển**: Chia thành các module nhỏ để dễ d ...
#        'Trách nhiệm chính:  - Phát triển và duy trì các ứng dụng web với React.js, đảm bảo các giao diện hoạt động mượt mà và tối ưu hóa trải nghiệm người dùng.  Phối hợp với các thành viên khác trong nhóm (Backend Developer, UX/UI Designer) để phân tích yêu cầu và thiết kế các tính năng phù hợp.  - Xây dựng các thành phần giao diện có thể tái sử dụng, bảo trì, và dễ dàng mở rộng.  - Tối ưu hóa hiệu suất và tốc độ của ứng dụng.  - Đảm bảo tính bảo mật và khả năng tương thích của ứng dụng với các trình duyệt và thiết bị khác nhau.  - Cập nhật các xu hướng công nghệ mới, đề xuất các cải tiến cho sản phẩm hiện tại.  Yêu cầu:  - Có ít nhất 2 năm kinh nghiệm phát triển với React.js.  - Thành thạo JavaScript, Typescript, HTML, CSS và các công cụ front-end phổ biến.  - Kinh nghiệm với Redux, React Router, và các thư viện quản lý trạng thái.  - Hiểu biết tốt về RESTful APIs và khả năng tích hợp với backend.  - Kỹ năng làm việc nhóm tốt và có khả năng giải quyết vấn đề nhanh chóng.',
#        'Trách nhiệm chính:  - Phát triển, bảo trì và nâng cấp các ứng dụng web, phần mềm, và hệ thống nội bộ dựa trên nền tảng .NET.  - Phân tích yêu cầu, thiết kế và thực hiện các giải pháp phần mềm theo yêu cầu của khách hàng.  - Làm việc chặt chẽ với nhóm kỹ thuật, phân tích và xử lý các vấn đề kỹ thuật liên quan đến dự án.  - Tối ưu hóa hiệu suất và bảo mật cho các ứng dụng.  - Kiểm thử và bảo đảm chất lượng sản phẩm trước khi phát hành.  - Tham gia các cuộc họp và báo cáo tiến độ dự án.  Yêu cầu:  - Có kinh nghiệm từ 2 năm trở lên trong việc phát triển ứng dụng .NET (C#, ASP.NET, .NET Core).  - Kỹ năng làm việc với cơ sở dữ liệu SQL Server, Entity Framework, và các hệ quản trị cơ sở dữ liệu khác.  - Hiểu biết tốt về lập trình hướng đối tượng (OOP).  - Kỹ năng phân tích và giải quyết vấn đề nhanh chóng.  - Có khả năng làm việc độc lập và làm việc nhóm tốt.  - Kỹ năng giao tiếp và tư duy sáng tạo.  Ưu tiên:  - Kinh nghiệm với AWS, Docker, hoặc các công nghệ Cloud khác.  - Đã từng làm việc với quy trình Agile/Scrum.',
#        'Hiện tại mình đang cần xin xét duyệt quyền pages_show_list, pages_messaging. Cần người có kinh nghiệm hoặc đã từng xin xét duyệt thành công. Không cần code chỉ cần hướng dẫn mình cần chuẩn bị những gì và điền thông tin xét duyệt như thế nào',
#        'Đã chọn được mẫu theme, cần một bạn hỗ trợ mình cài đặt host, domain, và setup cho trang tin tức wordpress.',
#        'Mình là nhà bán hàng trên sàn shopee, lazada, tiktok. Mình cần mua tool kết nối sàn thương mại điện tử lấy thông tin đơn hàng trên sàn.   Mình cần tool đã hoàn thiện.',
#        'Tôi cần viết mốt plugin cho phép kết nối đồng bộ giữa trang web của tôi và một bên thứ 3, đã có docs api sẵn',
#        'link dự án  https://drive.google.com/drive/folders/11Dc6UmgBNpNJbGQpFNCaHa9HmxvdAW0Z?usp=sharing',
#        'Tích hợp đơn hàng từ các sàn Shopee/Lazada/Tiktok về hệ thống nội bộ:  - Đơn hàng và các tín hiệu  - Lấy vận đơn  - Đồng bộ: tín hiệu đơn hàng, hủy, hoàn, tồn kho.  Tech: C#, .NET Core, PostgreSQL  Tham khảo: Sapo, Kiot, Haravan',
#        'Mình có 1 trang web dùng vue 3, hiện tại không thể share link trên các nền tảng social. Cần 1 bạn cài đặt các thể meta seo cho từng trang để có thể share được',
#        'Tích hợp API Kiotviet FnB vào website bán hàng sử dụng Wordpress'],
#       dtype=object)

# %%
# df["In4_project"][1571]

# %%
def extract_info(info):
    result = {
        'ID dự án': None,
        'Ngày đăng': None,
        'Chỉ còn': None,
        'Địa điểm': None,
        'Ngân sách': None,
        'Hình thức làm việc': None,
        'Hình thức trả lương': None
    }
    
    # Tạo các mẫu biểu thức chính quy cho từng mục
    patterns = {
        'ID dự án': r'ID dự án\n(\d+)|Id\n\s*(\d+)',
        'Ngày đăng': r'Ngày đăng\n\s+([^\n]+)',
        'Chỉ còn': r'Chỉ còn\n([^\n]+)',
        'Địa điểm': r'Địa điểm\n\s+([^\n]+)',
        'Ngân sách': r'Ngân sách\n\s+([^\n]+(?:\s+-\s+[^\n]+)?)|Tổng ngân sách\n\s+([^\n]+)',  # Cập nhật cho hai dạng Ngân sách
        'Hình thức làm việc': r'Hình thức làm việc\n\s+([^\n]+)',
        'Hình thức trả lương': r'Hình thức trả lương\n\s+([^\n]+)'
    }
    
    # Áp dụng từng mẫu để trích xuất giá trị
    for key, pattern in patterns.items():
        match = re.search(pattern, info)
        if key == 'ID dự án':
            if match is not None and match.group(1) is not None:
                result[key] = match.group(1).strip()
            elif match is not None and match.group(2) is not None:
                result[key] = match.group(2).strip()
            else:
                result[key] = None
        elif key == 'Ngân sách':
            if match is not None and match.group(1) is not None:
                result[key] = match.group(1).strip()
            elif match is not None and match.group(2) is not None:
                result[key] = match.group(2).strip()
            else:
                result[key] = None
        else:
            if match is not None and match.group(1) is not None:
                result[key] = match.group(1).strip()
            else:
                result[key] = None

    return result

# %%
# Giả sử df là DataFrame của bạn
info_list = []
# Thay thế các giá trị NaN bằng chuỗi rỗng
df["In4_project"] = df["In4_project"].fillna("")

for index, project_info in enumerate(df["In4_project"]):
    print(f"Processing project {index}...") 
    extracted_info = extract_info(project_info)
    info_list.append(extracted_info)
# Out:
# Processing project 0...
# Processing project 1...
# Processing project 2...
# Processing project 3...
# Processing project 4...
# Processing project 5...
# Processing project 6...
# Processing project 7...
# Processing project 8...
# Processing project 9...
# Processing project 10...
# Processing project 11...
# Processing project 12...
# Processing project 13...
# Processing project 14...
# Processing project 15...
# Processing project 16...
# Processing project 17...
# Processing project 18...
# Processing project 19...
# Processing project 20...
# Processing project 21...
# Processing project 22...
# Processing project 23...
# Processing project 24...
# Processing project 25...
# Processing project 26...
# Processing project 27...
# Processing project 28...
# Processing project 29...
# Processing project 30...
# Processing project 31...
# Processing project 32...
# Processing project 33...
# Processing project 34...
# Processing project 35...
# Processing project 36...
# Processing project 37...
# Processing project 38...
# Processing project 39...
# Processing project 40...
# Processing project 41...
# Processing project 42...
# Processing project 43...
# Processing project 44...
# Processing project 45...
# Processing project 46...
# Processing project 47...
# Processing project 48...
# Processing project 49...
# Processing project 50...
# Processing project 51...
# Processing project 52...
# Processing project 53...
# Processing project 54...
# Processing project 55...
# Processing project 56...
# Processing project 57...
# Processing project 58...
# Processing project 59...
# Processing project 60...
# Processing project 61...
# Processing project 62...
# Processing project 63...
# Processing project 64...
# Processing project 65...
# Processing project 66...
# Processing project 67...
# Processing project 68...
# Processing project 69...
# Processing project 70...
# Processing project 71...
# Processing project 72...
# Processing project 73...
# Processing project 74...
# Processing project 75...
# Processing project 76...
# Processing project 77...
# Processing project 78...
# Processing project 79...
# Processing project 80...
# Processing project 81...
# Processing project 82...
# Processing project 83...
# Processing project 84...
# Processing project 85...
# Processing project 86...
# Processing project 87...
# Processing project 88...
# Processing project 89...
# Processing project 90...
# Processing project 91...
# Processing project 92...
# Processing project 93...
# Processing project 94...
# Processing project 95...
# Processing project 96...

# %%
len(df)
# Out:
# 97

# %%
# df.iloc[1610]

# %%
len(info_list)
# Out:
# 97

# %%
# info_list[1610]

# %%
#nối info_list vào df
info_df = pd.DataFrame(info_list)
info_df
# Out:
#    ID dự án          Ngày đăng                Chỉ còn         Địa điểm  \
# 0     80678  11/11/2024, 11:28         18 giờ 20 phút         Đồng Nai
# 1     80660  10/11/2024, 14:29         17 ngày 21 giờ        Toàn Quốc
# 2     80700  12/11/2024, 06:43          2 ngày 13 giờ        Toàn Quốc
# 3     80656         10/11/2024         27 ngày 16 giờ             None
# 4     80678  11/11/2024, 11:28         18 giờ 18 phút         Đồng Nai
# ..      ...                ...                    ...              ...
# 92    80358  28/10/2024, 22:09  Hết hạn nhận chào giá        Toàn Quốc
# 93    80352  28/10/2024, 18:52  Hết hạn nhận chào giá  TP. Hồ Chí Minh
# 94    80348  28/10/2024, 17:03  Hết hạn nhận chào giá  TP. Hồ Chí Minh
# 95    80343  28/10/2024, 11:28  Hết hạn nhận chào giá        Toàn Quốc
# 96    80328  27/10/2024, 17:37  Hết hạn nhận chào giá           Hà Nội
#
#                                             Ngân sách Hình thức làm việc  \
# 0   40.000.000đ                                   ...         Làm online
# 1   3.000.000đ                                    ...         Làm online
# 2   5.000.000đ                                    ...         Làm online
# 3                                            300.000đ               None
# 4   40.000.000đ                                   ...         Làm online
# ..                                                ...                ...
# 92  200.000đ                                      ...         Làm online
# 93  4.000.000đ                                    ...         Làm online
# 94  10.000.000đ                                   ...         Làm online
# 95  1.000.000đ                                    ...         Làm online
# 96  1.000.000đ                                    ...         Làm online
#
#    Hình thức trả lương
# 0       Trả theo dự án
# 1       Trả theo dự án
# 2       Trả theo dự án
# 3                 None
# 4       Trả theo dự án
# ..                 ...
# 92      Trả theo dự án
# 93      Trả theo dự án
# 94      Trả theo dự án
# 95      Trả theo dự án
# 96      Trả theo dự án
#
# [97 rows x 7 columns]

# %%
info_df.isnull().mean() * 100
# Out:
# ID dự án               0.000000
# Ngày đăng              0.000000
# Chỉ còn                0.000000
# Địa điểm               1.030928
# Ngân sách              0.000000
# Hình thức làm việc     1.030928
# Hình thức trả lương    1.030928
# dtype: float64

# %%
info_df[info_df['Ngân sách'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID dự án, Ngày đăng, Chỉ còn, Địa điểm, Ngân sách, Hình thức làm việc, Hình thức trả lương]
# Index: []

# %%
df["In4_project"]
# Out:
# 0     \n\nID dự án\n80678\nNgày đăng\n\n            ...
# 1     \n\nID dự án\n80660\nNgày đăng\n\n            ...
# 2     \n\nID dự án\n80700\nNgày đăng\n\n            ...
# 3     \n\nId\n80656\nNgày đăng\n\n                10...
# 4     \n\nID dự án\n80678\nNgày đăng\n\n            ...
#                             ...
# 92    \n\nID dự án\n80358\nNgày đăng\n\n            ...
# 93    \n\nID dự án\n80352\nNgày đăng\n\n            ...
# 94    \n\nID dự án\n80348\nNgày đăng\n\n            ...
# 95    \n\nID dự án\n80343\nNgày đăng\n\n            ...
# 96    \n\nID dự án\n80328\nNgày đăng\n\n            ...
# Name: In4_project, Length: 97, dtype: object

# %%
# Đặt lại chỉ số, loại bỏ chỉ số cũ
df.reset_index(drop=True, inplace=True)
df["In4_project"]
# Out:
# 0     \n\nID dự án\n80678\nNgày đăng\n\n            ...
# 1     \n\nID dự án\n80660\nNgày đăng\n\n            ...
# 2     \n\nID dự án\n80700\nNgày đăng\n\n            ...
# 3     \n\nId\n80656\nNgày đăng\n\n                10...
# 4     \n\nID dự án\n80678\nNgày đăng\n\n            ...
#                             ...
# 92    \n\nID dự án\n80358\nNgày đăng\n\n            ...
# 93    \n\nID dự án\n80352\nNgày đăng\n\n            ...
# 94    \n\nID dự án\n80348\nNgày đăng\n\n            ...
# 95    \n\nID dự án\n80343\nNgày đăng\n\n            ...
# 96    \n\nID dự án\n80328\nNgày đăng\n\n            ...
# Name: In4_project, Length: 97, dtype: object

# %%
#nối info_df vào df
df = pd.concat([df, info_df], axis=1)
df
# Out:
#                    Type                                              Title  \
# 0             Đăng việc    Thiết kế web cho trường học ở BIên Hòa Đồng Nai
# 1             Đăng việc  Cần tìm người có thể xem videos và viết lại nộ...
# 2             Đăng việc                    Cần xây dựng trang web bán hàng
# 3   Chiến dịch hiển thị  [S8] Review cho tiệm Kính Mắt ở Đà Nẵng - Ưu t...
# 4             Đăng việc    Thiết kế web cho trường học ở BIên Hòa Đồng Nai
# ..                  ...                                                ...
# 92            Đăng việc                              Viết plugin wordpress
# 93            Đăng việc  Cần php senior maintain upgrade UI web theo figma
# 94            Đăng việc              Tích hợp sàn Shopee/Lazada/Tiktok API
# 95            Đăng việc                            Cài đặt Seo cho website
# 96            Đăng việc     Tích hợp API Kiotviet FnB vào website bán hàng
#
#                          Services  \
# 0   Chuyển Template thành Website
# 1         Viết kịch bản cho video
# 2           Dựng website bán hàng
# 3                             NaN
# 4   Chuyển Template thành Website
# ..                            ...
# 92     Viết phần mềm theo yêu cầu
# 93        Phát triển ứng dụng web
# 94        Phát triển ứng dụng web
# 95          Dựng website bán hàng
# 96       Nhập dữ liệu lên website
#
#                                                Skills  \
# 0                                        Thiết kế web
# 1                                         Copywriting
# 2   jQuery,Thiết kế Banner,Thiết kế logo,Node.js,L...
# 3                                                 NaN
# 4                                        Thiết kế web
# ..                                                ...
# 92                                   Wordpress,Plugin
# 93                                          PHP,Figma
# 94                      PostgreSQL,Shopee,Tiktok Shop
# 95                           SEO,Vue.js và express.js
# 96                                 Wordpress,Bán hàng
#
#                                           Description  \
# 0   Cần tìm 1 team Thiết kế web cho trường học ở B...
# 1   Tôi cần tìm 3 bạn có thể xem videos và viết lạ...
# 2   Chào mọi người!  Mình đang muốn xây dựng trang...
# 3   Mình muốn review cho tiệm kính mắt ở Đà Nẵng, ...
# 4   Cần tìm 1 team Thiết kế web cho trường học ở B...
# ..                                                ...
# 92  Tôi cần viết mốt plugin cho phép kết nối đồng ...
# 93  link dự án  https://drive.google.com/drive/fol...
# 94  Tích hợp đơn hàng từ các sàn Shopee/Lazada/Tik...
# 95  Mình có 1 trang web dùng vue 3, hiện tại không...
# 96  Tích hợp API Kiotviet FnB vào website bán hàng...
#
#                                           In4_project  \
# 0   \n\nID dự án\n80678\nNgày đăng\n\n            ...
# 1   \n\nID dự án\n80660\nNgày đăng\n\n            ...
# 2   \n\nID dự án\n80700\nNgày đăng\n\n            ...
# 3   \n\nId\n80656\nNgày đăng\n\n                10...
# 4   \n\nID dự án\n80678\nNgày đăng\n\n            ...
# ..                                                ...
# 92  \n\nID dự án\n80358\nNgày đăng\n\n            ...
# 93  \n\nID dự án\n80352\nNgày đăng\n\n            ...
# 94  \n\nID dự án\n80348\nNgày đăng\n\n            ...
# 95  \n\nID dự án\n80343\nNgày đăng\n\n            ...
# 96  \n\nID dự án\n80328\nNgày đăng\n\n            ...
#
#                                        In4_employment  \
# 0   \n\n\n\n\n\n\n\n\n\n                        Ng...
# 1   \n\n\n\n\n\n\n\n\n\n                        Hi...
# 2   \n\n\n\n\n\n\n\n\n\n                        Pr...
# 3   \n\n\n\n\n\n\n\n\n\n                        Hư...
# 4   \n\n\n\n\n\n\n\n\n\n                        Ng...
# ..                                                ...
# 92  \n\n\n\n\n\n\n\n\n\n                        Ph...
# 93  \n\n\n\n\n\n\n\n\n\n                        Ng...
# 94  \n\n\n\n\n\n\n\n\n\n                        Đô...
# 95  \n\n\n\n\n\n\n\n\n\n                        Sa...
# 96  \n\n\n\n\n\n\n\n\n\n                        Re...
#
#                                        Num_applicants  \
# 0   \n                Chào giá:                   ...
# 1   \n                Chào giá:                   ...
# 2   \n                Chào giá:                   ...
# 3               \n                Số lượng hồ sơ 61\n
# 4   \n                Chào giá:                   ...
# ..                                                ...
# 92  \n                Chào giá:                   ...
# 93  \n                Chào giá:                   ...
# 94  \n                Chào giá:                   ...
# 95  \n                Chào giá:                   ...
# 96  \n                Chào giá:                   ...
#
#                                            Applicants  \
# 0   ['/freelancer/nguyen-nhat-hao-1', '/freelancer...
# 1   ['/freelancer/pham-minh-thuan-2', '/freelancer...
# 2   ['/freelancer/hoa-tuyet', '/freelancer/anh-tua...
# 3                                                 NaN
# 4   ['/freelancer/nguyen-nhat-hao-1', '/freelancer...
# ..                                                ...
# 92  ['/freelancer/long-pham-169', '/freelancer/le-...
# 93  ['/freelancer/le-quoc-viet-1', '/freelancer/tu...
# 94  ['/freelancer/kaio-ken', '/freelancer/to-coder...
# 95  ['/freelancer/thuong-son', '/freelancer/van-mo...
# 96                       ['/freelancer/huy-pham-361']
#
#                                              Duration  \
# 0   \n                Trung bình:                2...
# 1   \n                Trung bình:                6...
# 2   \n                Trung bình:                9...
# 3   \n                                            ...
# 4   \n                Trung bình:                2...
# ..                                                ...
# 92  \n                Trung bình:                4...
# 93  \n                Trung bình:                5...
# 94  \n                Trung bình:                1...
# 95  \n                Trung bình:                3...
# 96  \n                Trung bình:                3...
#
#                                                 Price  \
# 0   \n\n                Thấp nhất:                ...
# 1   \n\n                Thấp nhất:                ...
# 2   \n\n                Thấp nhất:                ...
# 3   \n\n                Tổng ngân sách 300.000 VNĐ...
# 4   \n\n                Thấp nhất:                ...
# ..                                                ...
# 92  \n\n                Thấp nhất:                ...
# 93  \n\n                Thấp nhất:                ...
# 94  \n\n                Thấp nhất:                ...
# 95  \n\n                Thấp nhất:                ...
# 96  \n\n                Thấp nhất:                ...
#
#                                                  Link ID dự án  \
# 0   https://www.vlance.vn/viec-freelance/thiet-ke-...    80678
# 1   https://www.vlance.vn/viec-freelance/can-tim-n...    80660
# 2   https://www.vlance.vn/viec-freelance/can-xay-d...    80700
# 3   https://www.vlance.vn/cd-tang-review/s8-review...    80656
# 4   https://www.vlance.vn/viec-freelance/thiet-ke-...    80678
# ..                                                ...      ...
# 92  https://www.vlance.vn/viec-freelance/viet-plug...    80358
# 93  https://www.vlance.vn/viec-freelance/can-php-s...    80352
# 94  https://www.vlance.vn/viec-lam/tich-hop-san-sh...    80348
# 95  https://www.vlance.vn/viec-lam/cai-dat-seo-cho...    80343
# 96  https://www.vlance.vn/viec-freelance/tich-hop-...    80328
#
#             Ngày đăng                Chỉ còn         Địa điểm  \
# 0   11/11/2024, 11:28         18 giờ 20 phút         Đồng Nai
# 1   10/11/2024, 14:29         17 ngày 21 giờ        Toàn Quốc
# 2   12/11/2024, 06:43          2 ngày 13 giờ        Toàn Quốc
# 3          10/11/2024         27 ngày 16 giờ             None
# 4   11/11/2024, 11:28         18 giờ 18 phút         Đồng Nai
# ..                ...                    ...              ...
# 92  28/10/2024, 22:09  Hết hạn nhận chào giá        Toàn Quốc
# 93  28/10/2024, 18:52  Hết hạn nhận chào giá  TP. Hồ Chí Minh
# 94  28/10/2024, 17:03  Hết hạn nhận chào giá  TP. Hồ Chí Minh
# 95  28/10/2024, 11:28  Hết hạn nhận chào giá        Toàn Quốc
# 96  27/10/2024, 17:37  Hết hạn nhận chào giá           Hà Nội
#
#                                             Ngân sách Hình thức làm việc  \
# 0   40.000.000đ                                   ...         Làm online
# 1   3.000.000đ                                    ...         Làm online
# 2   5.000.000đ                                    ...         Làm online
# 3                                            300.000đ               None
# 4   40.000.000đ                                   ...         Làm online
# ..                                                ...                ...
# 92  200.000đ                                      ...         Làm online
# 93  4.000.000đ                                    ...         Làm online
# 94  10.000.000đ                                   ...         Làm online
# 95  1.000.000đ                                    ...         Làm online
# 96  1.000.000đ                                    ...         Làm online
#
#    Hình thức trả lương
# 0       Trả theo dự án
# 1       Trả theo dự án
# 2       Trả theo dự án
# 3                 None
# 4       Trả theo dự án
# ..                 ...
# 92      Trả theo dự án
# 93      Trả theo dự án
# 94      Trả theo dự án
# 95      Trả theo dự án
# 96      Trả theo dự án
#
# [97 rows x 19 columns]

# %%
# Xóa khoảng trắng dư thừa ở bất kỳ đâu trong chuỗi của cột "Ngân sách"
df["Ngân sách"] = df["Ngân sách"].str.replace(r'\s+', ' ', regex=True).str.strip()

# %%
#In ra các cột mà ID dự án = null
df[df["ID dự án"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Type, Title, Services, Skills, Description, In4_project, In4_employment, Num_applicants, Applicants, Duration, Price, Link, ID dự án, Ngày đăng, Chỉ còn, Địa điểm, Ngân sách, Hình thức làm việc, Hình thức trả lương]
# Index: []

# %%
#drop các dòng mà cột ID dự án = null
df = df.dropna(subset=["ID dự án"]) 
#reset index
df.reset_index(drop=True, inplace=True)

# %%
df["Num_applicants"][0]
# Out:
# '\n                Chào giá:                                        \n                        36                    \n'

# %%
#'\n                Chào giá:                                        \n                        1                    \n'
df["Num_applicants"] = df["Num_applicants"].str.replace(r'\n|\s+|Chào giá:', '', regex=True).str.strip()

# %%
df
# Out:
#                    Type                                              Title  \
# 0             Đăng việc    Thiết kế web cho trường học ở BIên Hòa Đồng Nai
# 1             Đăng việc  Cần tìm người có thể xem videos và viết lại nộ...
# 2             Đăng việc                    Cần xây dựng trang web bán hàng
# 3   Chiến dịch hiển thị  [S8] Review cho tiệm Kính Mắt ở Đà Nẵng - Ưu t...
# 4             Đăng việc    Thiết kế web cho trường học ở BIên Hòa Đồng Nai
# ..                  ...                                                ...
# 92            Đăng việc                              Viết plugin wordpress
# 93            Đăng việc  Cần php senior maintain upgrade UI web theo figma
# 94            Đăng việc              Tích hợp sàn Shopee/Lazada/Tiktok API
# 95            Đăng việc                            Cài đặt Seo cho website
# 96            Đăng việc     Tích hợp API Kiotviet FnB vào website bán hàng
#
#                          Services  \
# 0   Chuyển Template thành Website
# 1         Viết kịch bản cho video
# 2           Dựng website bán hàng
# 3                             NaN
# 4   Chuyển Template thành Website
# ..                            ...
# 92     Viết phần mềm theo yêu cầu
# 93        Phát triển ứng dụng web
# 94        Phát triển ứng dụng web
# 95          Dựng website bán hàng
# 96       Nhập dữ liệu lên website
#
#                                                Skills  \
# 0                                        Thiết kế web
# 1                                         Copywriting
# 2   jQuery,Thiết kế Banner,Thiết kế logo,Node.js,L...
# 3                                                 NaN
# 4                                        Thiết kế web
# ..                                                ...
# 92                                   Wordpress,Plugin
# 93                                          PHP,Figma
# 94                      PostgreSQL,Shopee,Tiktok Shop
# 95                           SEO,Vue.js và express.js
# 96                                 Wordpress,Bán hàng
#
#                                           Description  \
# 0   Cần tìm 1 team Thiết kế web cho trường học ở B...
# 1   Tôi cần tìm 3 bạn có thể xem videos và viết lạ...
# 2   Chào mọi người!  Mình đang muốn xây dựng trang...
# 3   Mình muốn review cho tiệm kính mắt ở Đà Nẵng, ...
# 4   Cần tìm 1 team Thiết kế web cho trường học ở B...
# ..                                                ...
# 92  Tôi cần viết mốt plugin cho phép kết nối đồng ...
# 93  link dự án  https://drive.google.com/drive/fol...
# 94  Tích hợp đơn hàng từ các sàn Shopee/Lazada/Tik...
# 95  Mình có 1 trang web dùng vue 3, hiện tại không...
# 96  Tích hợp API Kiotviet FnB vào website bán hàng...
#
#                                           In4_project  \
# 0   \n\nID dự án\n80678\nNgày đăng\n\n            ...
# 1   \n\nID dự án\n80660\nNgày đăng\n\n            ...
# 2   \n\nID dự án\n80700\nNgày đăng\n\n            ...
# 3   \n\nId\n80656\nNgày đăng\n\n                10...
# 4   \n\nID dự án\n80678\nNgày đăng\n\n            ...
# ..                                                ...
# 92  \n\nID dự án\n80358\nNgày đăng\n\n            ...
# 93  \n\nID dự án\n80352\nNgày đăng\n\n            ...
# 94  \n\nID dự án\n80348\nNgày đăng\n\n            ...
# 95  \n\nID dự án\n80343\nNgày đăng\n\n            ...
# 96  \n\nID dự án\n80328\nNgày đăng\n\n            ...
#
#                                        In4_employment Num_applicants  \
# 0   \n\n\n\n\n\n\n\n\n\n                        Ng...             36
# 1   \n\n\n\n\n\n\n\n\n\n                        Hi...             18
# 2   \n\n\n\n\n\n\n\n\n\n                        Pr...             17
# 3   \n\n\n\n\n\n\n\n\n\n                        Hư...  Sốlượnghồsơ61
# 4   \n\n\n\n\n\n\n\n\n\n                        Ng...             36
# ..                                                ...            ...
# 92  \n\n\n\n\n\n\n\n\n\n                        Ph...              7
# 93  \n\n\n\n\n\n\n\n\n\n                        Ng...              5
# 94  \n\n\n\n\n\n\n\n\n\n                        Đô...              8
# 95  \n\n\n\n\n\n\n\n\n\n                        Sa...              5
# 96  \n\n\n\n\n\n\n\n\n\n                        Re...              1
#
#                                            Applicants  \
# 0   ['/freelancer/nguyen-nhat-hao-1', '/freelancer...
# 1   ['/freelancer/pham-minh-thuan-2', '/freelancer...
# 2   ['/freelancer/hoa-tuyet', '/freelancer/anh-tua...
# 3                                                 NaN
# 4   ['/freelancer/nguyen-nhat-hao-1', '/freelancer...
# ..                                                ...
# 92  ['/freelancer/long-pham-169', '/freelancer/le-...
# 93  ['/freelancer/le-quoc-viet-1', '/freelancer/tu...
# 94  ['/freelancer/kaio-ken', '/freelancer/to-coder...
# 95  ['/freelancer/thuong-son', '/freelancer/van-mo...
# 96                       ['/freelancer/huy-pham-361']
#
#                                              Duration  \
# 0   \n                Trung bình:                2...
# 1   \n                Trung bình:                6...
# 2   \n                Trung bình:                9...
# 3   \n                                            ...
# 4   \n                Trung bình:                2...
# ..                                                ...
# 92  \n                Trung bình:                4...
# 93  \n                Trung bình:                5...
# 94  \n                Trung bình:                1...
# 95  \n                Trung bình:                3...
# 96  \n                Trung bình:                3...
#
#                                                 Price  \
# 0   \n\n                Thấp nhất:                ...
# 1   \n\n                Thấp nhất:                ...
# 2   \n\n                Thấp nhất:                ...
# 3   \n\n                Tổng ngân sách 300.000 VNĐ...
# 4   \n\n                Thấp nhất:                ...
# ..                                                ...
# 92  \n\n                Thấp nhất:                ...
# 93  \n\n                Thấp nhất:                ...
# 94  \n\n                Thấp nhất:                ...
# 95  \n\n                Thấp nhất:                ...
# 96  \n\n                Thấp nhất:                ...
#
#                                                  Link ID dự án  \
# 0   https://www.vlance.vn/viec-freelance/thiet-ke-...    80678
# 1   https://www.vlance.vn/viec-freelance/can-tim-n...    80660
# 2   https://www.vlance.vn/viec-freelance/can-xay-d...    80700
# 3   https://www.vlance.vn/cd-tang-review/s8-review...    80656
# 4   https://www.vlance.vn/viec-freelance/thiet-ke-...    80678
# ..                                                ...      ...
# 92  https://www.vlance.vn/viec-freelance/viet-plug...    80358
# 93  https://www.vlance.vn/viec-freelance/can-php-s...    80352
# 94  https://www.vlance.vn/viec-lam/tich-hop-san-sh...    80348
# 95  https://www.vlance.vn/viec-lam/cai-dat-seo-cho...    80343
# 96  https://www.vlance.vn/viec-freelance/tich-hop-...    80328
#
#             Ngày đăng                Chỉ còn         Địa điểm  \
# 0   11/11/2024, 11:28         18 giờ 20 phút         Đồng Nai
# 1   10/11/2024, 14:29         17 ngày 21 giờ        Toàn Quốc
# 2   12/11/2024, 06:43          2 ngày 13 giờ        Toàn Quốc
# 3          10/11/2024         27 ngày 16 giờ             None
# 4   11/11/2024, 11:28         18 giờ 18 phút         Đồng Nai
# ..                ...                    ...              ...
# 92  28/10/2024, 22:09  Hết hạn nhận chào giá        Toàn Quốc
# 93  28/10/2024, 18:52  Hết hạn nhận chào giá  TP. Hồ Chí Minh
# 94  28/10/2024, 17:03  Hết hạn nhận chào giá  TP. Hồ Chí Minh
# 95  28/10/2024, 11:28  Hết hạn nhận chào giá        Toàn Quốc
# 96  27/10/2024, 17:37  Hết hạn nhận chào giá           Hà Nội
#
#                     Ngân sách Hình thức làm việc Hình thức trả lương
# 0   40.000.000đ - 45.000.000đ         Làm online      Trả theo dự án
# 1    3.000.000đ - 10.000.000đ         Làm online      Trả theo dự án
# 2    5.000.000đ - 10.000.000đ         Làm online      Trả theo dự án
# 3                    300.000đ               None                None
# 4   40.000.000đ - 45.000.000đ         Làm online      Trả theo dự án
# ..                        ...                ...                 ...
# 92        200.000đ - 800.000đ         Làm online      Trả theo dự án
# 93    4.000.000đ - 6.000.000đ         Làm online      Trả theo dự án
# 94  10.000.000đ - 30.000.000đ         Làm online      Trả theo dự án
# 95    1.000.000đ - 2.000.000đ         Làm online      Trả theo dự án
# 96    1.000.000đ - 3.000.000đ         Làm online      Trả theo dự án
#
# [97 rows x 19 columns]

# %%
df["Price"].unique()
# Out:
# array(['\n\n                Thấp nhất:                20.000.000 VNĐ\n\n|\n\n                Trung bình:                39.597.222 VNĐ\n\n|\n\n                Cao nhất:                50.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                3 VNĐ\n\n|\n\n                Trung bình:                2.677.778 VNĐ\n\n|\n\n                Cao nhất:                7.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                4.500.000 VNĐ\n\n|\n\n                Trung bình:                11.367.059 VNĐ\n\n|\n\n                Cao nhất:                50.000.000 VNĐ\n\n',
#        '\n\n                Tổng ngân sách 300.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                30.000.000 VNĐ\n\n|\n\n                Trung bình:                48.285.714 VNĐ\n\n|\n\n                Cao nhất:                60.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                100.000 VNĐ\n\n|\n\n                Trung bình:                20.010.000 VNĐ\n\n|\n\n                Cao nhất:                30.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                1.000.000 VNĐ\n\n|\n\n                Trung bình:                2.500.000 VNĐ\n\n|\n\n                Cao nhất:                3.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                50.000.000 VNĐ\n\n|\n\n                Trung bình:                71.800.000 VNĐ\n\n|\n\n                Cao nhất:                100.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                500.000 VNĐ\n\n|\n\n                Trung bình:                1.250.000 VNĐ\n\n|\n\n                Cao nhất:                2.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                10.000.000 VNĐ\n\n|\n\n                Trung bình:                15.000.000 VNĐ\n\n|\n\n                Cao nhất:                20.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                10.000.000 VNĐ\n\n|\n\n                Trung bình:                54.444.444 VNĐ\n\n|\n\n                Cao nhất:                130.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                5.500.000 VNĐ\n\n|\n\n                Trung bình:                6.100.000 VNĐ\n\n|\n\n                Cao nhất:                7.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                600.000 VNĐ\n\n|\n\n                Trung bình:                840.000 VNĐ\n\n|\n\n                Cao nhất:                1.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                2.500.000 VNĐ\n\n|\n\n                Trung bình:                2.500.000 VNĐ\n\n|\n\n                Cao nhất:                2.500.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                2.000.000 VNĐ\n\n|\n\n                Trung bình:                5.757.143 VNĐ\n\n|\n\n                Cao nhất:                10.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                1.000.000 VNĐ\n\n|\n\n                Trung bình:                15.500.000 VNĐ\n\n|\n\n                Cao nhất:                30.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                0 VNĐ\n\n|\n\n                Trung bình:                0 VNĐ\n\n|\n\n                Cao nhất:                0 VNĐ\n\n',
#        '\n\n                Thấp nhất:                1.000.000 VNĐ\n\n|\n\n                Trung bình:                1.000.000 VNĐ\n\n|\n\n                Cao nhất:                1.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                1.500.000 VNĐ\n\n|\n\n                Trung bình:                1.833.333 VNĐ\n\n|\n\n                Cao nhất:                2.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                10.000.000 VNĐ\n\n|\n\n                Trung bình:                52.500.000 VNĐ\n\n|\n\n                Cao nhất:                100.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                1.000.000 VNĐ\n\n|\n\n                Trung bình:                2.250.000 VNĐ\n\n|\n\n                Cao nhất:                3.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                500.000 VNĐ\n\n|\n\n                Trung bình:                500.000 VNĐ\n\n|\n\n                Cao nhất:                500.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                10.000.000 VNĐ\n\n|\n\n                Trung bình:                10.000.000 VNĐ\n\n|\n\n                Cao nhất:                10.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                6.200.000 VNĐ\n\n|\n\n                Trung bình:                6.200.000 VNĐ\n\n|\n\n                Cao nhất:                6.200.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                200.000 VNĐ\n\n|\n\n                Trung bình:                4.609.700 VNĐ\n\n|\n\n                Cao nhất:                8.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                4.000.000 VNĐ\n\n|\n\n                Trung bình:                4.500.000 VNĐ\n\n|\n\n                Cao nhất:                5.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                1.000.000 VNĐ\n\n|\n\n                Trung bình:                8.000.000 VNĐ\n\n|\n\n                Cao nhất:                20.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                1.000.000 VNĐ\n\n|\n\n                Trung bình:                1.564.286 VNĐ\n\n|\n\n                Cao nhất:                2.500.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                500.000 VNĐ\n\n|\n\n                Trung bình:                2.833.333 VNĐ\n\n|\n\n                Cao nhất:                5.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                5.000.000 VNĐ\n\n|\n\n                Trung bình:                14.000.000 VNĐ\n\n|\n\n                Cao nhất:                20.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                5.000.000 VNĐ\n\n|\n\n                Trung bình:                13.333.333 VNĐ\n\n|\n\n                Cao nhất:                19.999.999 VNĐ\n\n',
#        '\n\n                Thấp nhất:                500.000 VNĐ\n\n|\n\n                Trung bình:                1.500.000 VNĐ\n\n|\n\n                Cao nhất:                2.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                5.000.000 VNĐ\n\n|\n\n                Trung bình:                7.138.462 VNĐ\n\n|\n\n                Cao nhất:                10.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                500.000 VNĐ\n\n|\n\n                Trung bình:                1.500.000 VNĐ\n\n|\n\n                Cao nhất:                3.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                500.000 VNĐ\n\n|\n\n                Trung bình:                3.666.667 VNĐ\n\n|\n\n                Cao nhất:                15.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                5.000.000 VNĐ\n\n|\n\n                Trung bình:                6.700.000 VNĐ\n\n|\n\n                Cao nhất:                10.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                5.000.000 VNĐ\n\n|\n\n                Trung bình:                16.500.000 VNĐ\n\n|\n\n                Cao nhất:                50.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                2.000.000 VNĐ\n\n|\n\n                Trung bình:                6.500.000 VNĐ\n\n|\n\n                Cao nhất:                11.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                2.000.000 VNĐ\n\n|\n\n                Trung bình:                5.000.000 VNĐ\n\n|\n\n                Cao nhất:                10.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                1.000.000 VNĐ\n\n|\n\n                Trung bình:                1.833.333 VNĐ\n\n|\n\n                Cao nhất:                2.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                500.000 VNĐ\n\n|\n\n                Trung bình:                1.571.429 VNĐ\n\n|\n\n                Cao nhất:                2.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                10.000.000 VNĐ\n\n|\n\n                Trung bình:                12.666.667 VNĐ\n\n|\n\n                Cao nhất:                15.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                8.000.000 VNĐ\n\n|\n\n                Trung bình:                14.887.857 VNĐ\n\n|\n\n                Cao nhất:                20.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                500.000 VNĐ\n\n|\n\n                Trung bình:                5.500.000 VNĐ\n\n|\n\n                Cao nhất:                15.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                1.500.000 VNĐ\n\n|\n\n                Trung bình:                1.733.333 VNĐ\n\n|\n\n                Cao nhất:                2.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                30.000.000 VNĐ\n\n|\n\n                Trung bình:                56.666.667 VNĐ\n\n|\n\n                Cao nhất:                70.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                500.000 VNĐ\n\n|\n\n                Trung bình:                750.000 VNĐ\n\n|\n\n                Cao nhất:                1.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                500.000 VNĐ\n\n|\n\n                Trung bình:                9.642.857 VNĐ\n\n|\n\n                Cao nhất:                50.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                200.000 VNĐ\n\n|\n\n                Trung bình:                400.000 VNĐ\n\n|\n\n                Cao nhất:                500.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                1.000.000 VNĐ\n\n|\n\n                Trung bình:                16.222.222 VNĐ\n\n|\n\n                Cao nhất:                30.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                2.000.000 VNĐ\n\n|\n\n                Trung bình:                7.600.000 VNĐ\n\n|\n\n                Cao nhất:                10.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                500.000 VNĐ\n\n|\n\n                Trung bình:                4.800.000 VNĐ\n\n|\n\n                Cao nhất:                11.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                1.000.000 VNĐ\n\n|\n\n                Trung bình:                10.500.000 VNĐ\n\n|\n\n                Cao nhất:                20.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                7.000.000 VNĐ\n\n|\n\n                Trung bình:                7.000.000 VNĐ\n\n|\n\n                Cao nhất:                7.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                3.000.000 VNĐ\n\n|\n\n                Trung bình:                19.472.889 VNĐ\n\n|\n\n                Cao nhất:                300.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                2.000.000 VNĐ\n\n|\n\n                Trung bình:                2.666.667 VNĐ\n\n|\n\n                Cao nhất:                3.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                500.000 VNĐ\n\n|\n\n                Trung bình:                1.875.000 VNĐ\n\n|\n\n                Cao nhất:                3.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                5.000.000 VNĐ\n\n|\n\n                Trung bình:                8.461.538 VNĐ\n\n|\n\n                Cao nhất:                10.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                500.000 VNĐ\n\n|\n\n                Trung bình:                1.609.091 VNĐ\n\n|\n\n                Cao nhất:                5.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                1.000.000 VNĐ\n\n|\n\n                Trung bình:                6.658.333 VNĐ\n\n|\n\n                Cao nhất:                11.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                2.000.000 VNĐ\n\n|\n\n                Trung bình:                17.727.778 VNĐ\n\n|\n\n                Cao nhất:                30.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                500.000 VNĐ\n\n|\n\n                Trung bình:                5.750.000 VNĐ\n\n|\n\n                Cao nhất:                11.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                100.000 VNĐ\n\n|\n\n                Trung bình:                2.894.444 VNĐ\n\n|\n\n                Cao nhất:                4.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                1.000.000 VNĐ\n\n|\n\n                Trung bình:                4.250.000 VNĐ\n\n|\n\n                Cao nhất:                10.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                300.000 VNĐ\n\n|\n\n                Trung bình:                650.000 VNĐ\n\n|\n\n                Cao nhất:                1.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                100.000 VNĐ\n\n|\n\n                Trung bình:                5.425.926 VNĐ\n\n|\n\n                Cao nhất:                10.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                200.000 VNĐ\n\n|\n\n                Trung bình:                325.000 VNĐ\n\n|\n\n                Cao nhất:                500.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                100.000 VNĐ\n\n|\n\n                Trung bình:                22.682.143 VNĐ\n\n|\n\n                Cao nhất:                50.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                5.000.000 VNĐ\n\n|\n\n                Trung bình:                5.400.000 VNĐ\n\n|\n\n                Cao nhất:                6.200.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                5.000.000 VNĐ\n\n|\n\n                Trung bình:                6.000.000 VNĐ\n\n|\n\n                Cao nhất:                7.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                200.000 VNĐ\n\n|\n\n                Trung bình:                7.277.778 VNĐ\n\n|\n\n                Cao nhất:                15.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                2.000.000 VNĐ\n\n|\n\n                Trung bình:                19.333.333 VNĐ\n\n|\n\n                Cao nhất:                50.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                25.000.000 VNĐ\n\n|\n\n                Trung bình:                38.333.333 VNĐ\n\n|\n\n                Cao nhất:                50.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                15.000.000 VNĐ\n\n|\n\n                Trung bình:                31.200.000 VNĐ\n\n|\n\n                Cao nhất:                50.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                1.500.000 VNĐ\n\n|\n\n                Trung bình:                1.500.000 VNĐ\n\n|\n\n                Cao nhất:                1.500.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                300.000 VNĐ\n\n|\n\n                Trung bình:                467.857 VNĐ\n\n|\n\n                Cao nhất:                1.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                10.000.000 VNĐ\n\n|\n\n                Trung bình:                16.666.667 VNĐ\n\n|\n\n                Cao nhất:                20.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                300.000 VNĐ\n\n|\n\n                Trung bình:                642.857 VNĐ\n\n|\n\n                Cao nhất:                1.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                4.000.000 VNĐ\n\n|\n\n                Trung bình:                5.000.000 VNĐ\n\n|\n\n                Cao nhất:                6.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                10.000.000 VNĐ\n\n|\n\n                Trung bình:                28.750.000 VNĐ\n\n|\n\n                Cao nhất:                50.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                1.500.000 VNĐ\n\n|\n\n                Trung bình:                1.800.000 VNĐ\n\n|\n\n                Cao nhất:                2.000.000 VNĐ\n\n'],
#       dtype=object)

# %%
#Bỏ dấu "."
df["Price"] = df["Price"].str.replace('.', '')


# Sử dụng regex để tách giá trị thấp nhất, trung bình và cao nhất
df['Chào giá thấp nhất'] = df['Price'].str.extract(r'Thấp nhất:\s*([\d]+)').astype(float)
df['Chào giá trung bình'] = df['Price'].str.extract(r'Trung bình:\s*([\d]+)').astype(float)
df['Chào giá cao nhất'] = df['Price'].str.extract(r'Cao nhất:\s*([\d]+)').astype(float)

# %%
df
# Out:
#                    Type                                              Title  \
# 0             Đăng việc    Thiết kế web cho trường học ở BIên Hòa Đồng Nai
# 1             Đăng việc  Cần tìm người có thể xem videos và viết lại nộ...
# 2             Đăng việc                    Cần xây dựng trang web bán hàng
# 3   Chiến dịch hiển thị  [S8] Review cho tiệm Kính Mắt ở Đà Nẵng - Ưu t...
# 4             Đăng việc    Thiết kế web cho trường học ở BIên Hòa Đồng Nai
# ..                  ...                                                ...
# 92            Đăng việc                              Viết plugin wordpress
# 93            Đăng việc  Cần php senior maintain upgrade UI web theo figma
# 94            Đăng việc              Tích hợp sàn Shopee/Lazada/Tiktok API
# 95            Đăng việc                            Cài đặt Seo cho website
# 96            Đăng việc     Tích hợp API Kiotviet FnB vào website bán hàng
#
#                          Services  \
# 0   Chuyển Template thành Website
# 1         Viết kịch bản cho video
# 2           Dựng website bán hàng
# 3                             NaN
# 4   Chuyển Template thành Website
# ..                            ...
# 92     Viết phần mềm theo yêu cầu
# 93        Phát triển ứng dụng web
# 94        Phát triển ứng dụng web
# 95          Dựng website bán hàng
# 96       Nhập dữ liệu lên website
#
#                                                Skills  \
# 0                                        Thiết kế web
# 1                                         Copywriting
# 2   jQuery,Thiết kế Banner,Thiết kế logo,Node.js,L...
# 3                                                 NaN
# 4                                        Thiết kế web
# ..                                                ...
# 92                                   Wordpress,Plugin
# 93                                          PHP,Figma
# 94                      PostgreSQL,Shopee,Tiktok Shop
# 95                           SEO,Vue.js và express.js
# 96                                 Wordpress,Bán hàng
#
#                                           Description  \
# 0   Cần tìm 1 team Thiết kế web cho trường học ở B...
# 1   Tôi cần tìm 3 bạn có thể xem videos và viết lạ...
# 2   Chào mọi người!  Mình đang muốn xây dựng trang...
# 3   Mình muốn review cho tiệm kính mắt ở Đà Nẵng, ...
# 4   Cần tìm 1 team Thiết kế web cho trường học ở B...
# ..                                                ...
# 92  Tôi cần viết mốt plugin cho phép kết nối đồng ...
# 93  link dự án  https://drive.google.com/drive/fol...
# 94  Tích hợp đơn hàng từ các sàn Shopee/Lazada/Tik...
# 95  Mình có 1 trang web dùng vue 3, hiện tại không...
# 96  Tích hợp API Kiotviet FnB vào website bán hàng...
#
#                                           In4_project  \
# 0   \n\nID dự án\n80678\nNgày đăng\n\n            ...
# 1   \n\nID dự án\n80660\nNgày đăng\n\n            ...
# 2   \n\nID dự án\n80700\nNgày đăng\n\n            ...
# 3   \n\nId\n80656\nNgày đăng\n\n                10...
# 4   \n\nID dự án\n80678\nNgày đăng\n\n            ...
# ..                                                ...
# 92  \n\nID dự án\n80358\nNgày đăng\n\n            ...
# 93  \n\nID dự án\n80352\nNgày đăng\n\n            ...
# 94  \n\nID dự án\n80348\nNgày đăng\n\n            ...
# 95  \n\nID dự án\n80343\nNgày đăng\n\n            ...
# 96  \n\nID dự án\n80328\nNgày đăng\n\n            ...
#
#                                        In4_employment Num_applicants  \
# 0   \n\n\n\n\n\n\n\n\n\n                        Ng...             36
# 1   \n\n\n\n\n\n\n\n\n\n                        Hi...             18
# 2   \n\n\n\n\n\n\n\n\n\n                        Pr...             17
# 3   \n\n\n\n\n\n\n\n\n\n                        Hư...  Sốlượnghồsơ61
# 4   \n\n\n\n\n\n\n\n\n\n                        Ng...             36
# ..                                                ...            ...
# 92  \n\n\n\n\n\n\n\n\n\n                        Ph...              7
# 93  \n\n\n\n\n\n\n\n\n\n                        Ng...              5
# 94  \n\n\n\n\n\n\n\n\n\n                        Đô...              8
# 95  \n\n\n\n\n\n\n\n\n\n                        Sa...              5
# 96  \n\n\n\n\n\n\n\n\n\n                        Re...              1
#
#                                            Applicants  \
# 0   ['/freelancer/nguyen-nhat-hao-1', '/freelancer...
# 1   ['/freelancer/pham-minh-thuan-2', '/freelancer...
# 2   ['/freelancer/hoa-tuyet', '/freelancer/anh-tua...
# 3                                                 NaN
# 4   ['/freelancer/nguyen-nhat-hao-1', '/freelancer...
# ..                                                ...
# 92  ['/freelancer/long-pham-169', '/freelancer/le-...
# 93  ['/freelancer/le-quoc-viet-1', '/freelancer/tu...
# 94  ['/freelancer/kaio-ken', '/freelancer/to-coder...
# 95  ['/freelancer/thuong-son', '/freelancer/van-mo...
# 96                       ['/freelancer/huy-pham-361']
#
#                                              Duration  ... ID dự án  \
# 0   \n                Trung bình:                2...  ...    80678
# 1   \n                Trung bình:                6...  ...    80660
# 2   \n                Trung bình:                9...  ...    80700
# 3   \n                                            ...  ...    80656
# 4   \n                Trung bình:                2...  ...    80678
# ..                                                ...  ...      ...
# 92  \n                Trung bình:                4...  ...    80358
# 93  \n                Trung bình:                5...  ...    80352
# 94  \n                Trung bình:                1...  ...    80348
# 95  \n                Trung bình:                3...  ...    80343
# 96  \n                Trung bình:                3...  ...    80328
#
#             Ngày đăng                Chỉ còn         Địa điểm  \
# 0   11/11/2024, 11:28         18 giờ 20 phút         Đồng Nai
# 1   10/11/2024, 14:29         17 ngày 21 giờ        Toàn Quốc
# 2   12/11/2024, 06:43          2 ngày 13 giờ        Toàn Quốc
# 3          10/11/2024         27 ngày 16 giờ             None
# 4   11/11/2024, 11:28         18 giờ 18 phút         Đồng Nai
# ..                ...                    ...              ...
# 92  28/10/2024, 22:09  Hết hạn nhận chào giá        Toàn Quốc
# 93  28/10/2024, 18:52  Hết hạn nhận chào giá  TP. Hồ Chí Minh
# 94  28/10/2024, 17:03  Hết hạn nhận chào giá  TP. Hồ Chí Minh
# 95  28/10/2024, 11:28  Hết hạn nhận chào giá        Toàn Quốc
# 96  27/10/2024, 17:37  Hết hạn nhận chào giá           Hà Nội
#
#                     Ngân sách Hình thức làm việc Hình thức trả lương  \
# 0   40.000.000đ - 45.000.000đ         Làm online      Trả theo dự án
# 1    3.000.000đ - 10.000.000đ         Làm online      Trả theo dự án
# 2    5.000.000đ - 10.000.000đ         Làm online      Trả theo dự án
# 3                    300.000đ               None                None
# 4   40.000.000đ - 45.000.000đ         Làm online      Trả theo dự án
# ..                        ...                ...                 ...
# 92        200.000đ - 800.000đ         Làm online      Trả theo dự án
# 93    4.000.000đ - 6.000.000đ         Làm online      Trả theo dự án
# 94  10.000.000đ - 30.000.000đ         Làm online      Trả theo dự án
# 95    1.000.000đ - 2.000.000đ         Làm online      Trả theo dự án
# 96    1.000.000đ - 3.000.000đ         Làm online      Trả theo dự án
#
#    Chào giá thấp nhất Chào giá trung bình  Chào giá cao nhất
# 0          20000000.0          39597222.0         50000000.0
# 1                 3.0           2677778.0          7000000.0
# 2           4500000.0          11367059.0         50000000.0
# 3                 NaN                 NaN                NaN
# 4          20000000.0          39597222.0         50000000.0
# ..                ...                 ...                ...
# 92           300000.0            642857.0          1000000.0
# 93          4000000.0           5000000.0          6000000.0
# 94         10000000.0          28750000.0         50000000.0
# 95          1500000.0           1800000.0          2000000.0
# 96          1000000.0           1000000.0          1000000.0
#
# [97 rows x 22 columns]

# %%
# df["Price"][11452]

# %%
len(df["Duration"].unique())
# Out:
# 26

# %%
print(df["Duration"].unique())
# Out:
# ['\n                Trung bình:                21 ngày\n'
#  '\n                Trung bình:                6 ngày\n'
#  '\n                Trung bình:                9 ngày\n'
#  '\n                                                            Chỉ còn 27 ngày 16 giờ\n'
#  '\n                Trung bình:                12 ngày\n'
#  '\n                Trung bình:                7 ngày\n'
#  '\n                Trung bình:                13 ngày\n'
#  '\n                Trung bình:                3 ngày\n'
#  '\n                Trung bình:                15 ngày\n'
#  '\n                Trung bình:                10 ngày\n'
#  '\n                Trung bình:                8 ngày\n'
#  '\n                Trung bình:                25 ngày\n'
#  '\n                Trung bình:                0 ngày\n'
#  '\n                Trung bình:                4 ngày\n'
#  '\n                Trung bình:                24 ngày\n'
#  '\n                Trung bình:                28 ngày\n'
#  '\n                Trung bình:                16 ngày\n'
#  '\n                Trung bình:                2 ngày\n'
#  '\n                Trung bình:                5 ngày\n'
#  '\n                Trung bình:                22 ngày\n'
#  '\n                Trung bình:                30 ngày\n'
#  '\n                Trung bình:                1 ngày\n'
#  '\n                Trung bình:                14 ngày\n'
#  '\n                Trung bình:                11 ngày\n'
#  '\n                Trung bình:                17 ngày\n'
#  '\n                Trung bình:                29 ngày\n']

# %%
#đổi tên cột Duration thành Duration (ngày)
df.rename(columns={"Duration": "Duration (ngày)"}, inplace=True)
#chỉ giữ số trong cột Duration (ngày)
df["Duration (ngày)"] = df["Duration (ngày)"].str.replace(r'\n|\s+|Trung bình:|ngày|-', '', regex=True).str.strip()
df["Duration (ngày)"].unique()
# Out:
# array(['21', '6', '9', 'Chỉcòn2716giờ', '12', '7', '13', '3', '15', '10',
#        '8', '25', '0', '4', '24', '28', '16', '2', '5', '22', '30', '1',
#        '14', '11', '17', '29'], dtype=object)

# %%
df["Ngân sách"].unique()
# Out:
# array(['40.000.000đ - 45.000.000đ', '3.000.000đ - 10.000.000đ',
#        '5.000.000đ - 10.000.000đ', '300.000đ',
#        '40.000.000đ - 60.000.000đ', '20.000.000đ - 30.000.000đ',
#        '1.000.000đ - 3.000.000đ', '50.000.000đ - 70.000.000đ',
#        '500.000đ - 2.000.000đ', '10.000.000đ - 20.000.000đ',
#        '40.000.000đ', '5.000.000đ - 7.000.000đ', '300.000đ - 1.000.000đ',
#        '2.000.000đ - 2.500.000đ', '2.000.000đ - 7.000.000đ',
#        '1.000.000đ - 30.000.000đ', '500.000đ - 1.000.000đ',
#        '1.000.000đ - 2.000.000đ', '10.000.000đ - 50.000.000đ',
#        '50.000.000đ - 100.000.000đ', '300.000đ - 500.000đ',
#        '5.000.000đ - 8.000.000đ', '4.000.000đ - 8.000.000đ',
#        '2.500.000đ - 3.500.000đ', '1.000.000đ - 1.500.000đ',
#        '3.000.000đ - 5.000.000đ', '200.000đ - 400.000đ',
#        '200.000đ - 500.000đ', '300.000đ - 800.000đ',
#        '5.000.000đ - 20.000.000đ', '200.000đ - 300.000đ',
#        '2.000.000đ - 15.000.000đ', '2.000.000đ - 4.000.000đ',
#        '10.000.000đ - 15.000.000đ', '8.000.000đ - 20.000.000đ',
#        '1.700.000đ - 2.000.000đ', '30.000.000đ - 70.000.000đ',
#        '200.000đ - 5.000.000đ', '10.000.000đ - 30.000.000đ',
#        '2.000.000đ - 10.000.000đ', '7.000.000đ - 10.000.000đ',
#        '2.000.000đ - 3.000.000đ', '1.000.000đ - 10.000.000đ',
#        '5.000.000đ', '2.000.000đ - 5.000.000đ',
#        '5.000.000đ - 15.000.000đ', '2.000.000đ - 6.000.000đ',
#        '20.000.000đ - 55.000.000đ', '1.500.000đ - 2.000.000đ',
#        '200.000đ - 800.000đ', '4.000.000đ - 6.000.000đ'], dtype=object)

# %%
df.isnull().mean() * 100
# Out:
# Type                    0.000000
# Title                   0.000000
# Services                1.030928
# Skills                 21.649485
# Description             0.000000
# In4_project             0.000000
# In4_employment          0.000000
# Num_applicants          0.000000
# Applicants              1.030928
# Duration (ngày)         0.000000
# Price                   0.000000
# Link                    0.000000
# ID dự án                0.000000
# Ngày đăng               0.000000
# Chỉ còn                 0.000000
# Địa điểm                1.030928
# Ngân sách               0.000000
# Hình thức làm việc      1.030928
# Hình thức trả lương     1.030928
# Chào giá thấp nhất      1.030928
# Chào giá trung bình     1.030928
# Chào giá cao nhất       1.030928
# dtype: float64

# %%
# Hàm để tách ngân sách thấp nhất và cao nhất
def parse_budget(budget):
    # Xóa ký tự 'đ' và chuyển đổi thành số nguyên
    budget = budget.replace('đ', '').replace('.', '').strip()
    
    # Kiểm tra có dấu '-' không
    if '-' in budget:
        low, high = budget.split('-')
        return (float(low.strip()), float(high.strip()))
    else:
        # Không có dấu '-', gán ngân sách thấp nhất là 0
        return (0.0, float(budget))

# %%
# Áp dụng hàm để tách ngân sách
df[['Ngân sách thấp nhất', 'Ngân sách cao nhất']] = df['Ngân sách'].apply(parse_budget).apply(pd.Series)

# %%
df.columns
# Out:
# Index(['Type', 'Title', 'Services', 'Skills', 'Description', 'In4_project',
#        'In4_employment', 'Num_applicants', 'Applicants', 'Duration (ngày)',
#        'Price', 'Link', 'ID dự án', 'Ngày đăng', 'Chỉ còn', 'Địa điểm',
#        'Ngân sách', 'Hình thức làm việc', 'Hình thức trả lương',
#        'Chào giá thấp nhất', 'Chào giá trung bình', 'Chào giá cao nhất',
#        'Ngân sách thấp nhất', 'Ngân sách cao nhất'],
#       dtype='object')

# %%
#Cỉ lấy các cột cần thiết: ID dự án, Type, Title, Services, Skills, Description, Ngày đăng , Chỉ còn , Địa điểm ,Ngân sách thấp nhất, Ngân sách cao nhất, Hình thức làm việc, Hình thức trả lương, Num_applicants, Chào giá thấp nhất, Chào giá trung bình, Chào giá cao nhất, Duration (ngày)
df = df[['ID dự án', 'Type', 'Title', 'Services', 'Skills', 'Description', 'Ngày đăng', 'Chỉ còn', 'Địa điểm', 'Ngân sách thấp nhất', 'Ngân sách cao nhất', 'Hình thức làm việc', 'Hình thức trả lương', 'Num_applicants', 'Chào giá thấp nhất', 'Chào giá trung bình', 'Chào giá cao nhất', 'Duration (ngày)', "Link"]]
df
# Out:
#    ID dự án                 Type  \
# 0     80678            Đăng việc
# 1     80660            Đăng việc
# 2     80700            Đăng việc
# 3     80656  Chiến dịch hiển thị
# 4     80678            Đăng việc
# ..      ...                  ...
# 92    80358            Đăng việc
# 93    80352            Đăng việc
# 94    80348            Đăng việc
# 95    80343            Đăng việc
# 96    80328            Đăng việc
#
#                                                 Title  \
# 0     Thiết kế web cho trường học ở BIên Hòa Đồng Nai
# 1   Cần tìm người có thể xem videos và viết lại nộ...
# 2                     Cần xây dựng trang web bán hàng
# 3   [S8] Review cho tiệm Kính Mắt ở Đà Nẵng - Ưu t...
# 4     Thiết kế web cho trường học ở BIên Hòa Đồng Nai
# ..                                                ...
# 92                              Viết plugin wordpress
# 93  Cần php senior maintain upgrade UI web theo figma
# 94              Tích hợp sàn Shopee/Lazada/Tiktok API
# 95                            Cài đặt Seo cho website
# 96     Tích hợp API Kiotviet FnB vào website bán hàng
#
#                          Services  \
# 0   Chuyển Template thành Website
# 1         Viết kịch bản cho video
# 2           Dựng website bán hàng
# 3                             NaN
# 4   Chuyển Template thành Website
# ..                            ...
# 92     Viết phần mềm theo yêu cầu
# 93        Phát triển ứng dụng web
# 94        Phát triển ứng dụng web
# 95          Dựng website bán hàng
# 96       Nhập dữ liệu lên website
#
#                                                Skills  \
# 0                                        Thiết kế web
# 1                                         Copywriting
# 2   jQuery,Thiết kế Banner,Thiết kế logo,Node.js,L...
# 3                                                 NaN
# 4                                        Thiết kế web
# ..                                                ...
# 92                                   Wordpress,Plugin
# 93                                          PHP,Figma
# 94                      PostgreSQL,Shopee,Tiktok Shop
# 95                           SEO,Vue.js và express.js
# 96                                 Wordpress,Bán hàng
#
#                                           Description          Ngày đăng  \
# 0   Cần tìm 1 team Thiết kế web cho trường học ở B...  11/11/2024, 11:28
# 1   Tôi cần tìm 3 bạn có thể xem videos và viết lạ...  10/11/2024, 14:29
# 2   Chào mọi người!  Mình đang muốn xây dựng trang...  12/11/2024, 06:43
# 3   Mình muốn review cho tiệm kính mắt ở Đà Nẵng, ...         10/11/2024
# 4   Cần tìm 1 team Thiết kế web cho trường học ở B...  11/11/2024, 11:28
# ..                                                ...                ...
# 92  Tôi cần viết mốt plugin cho phép kết nối đồng ...  28/10/2024, 22:09
# 93  link dự án  https://drive.google.com/drive/fol...  28/10/2024, 18:52
# 94  Tích hợp đơn hàng từ các sàn Shopee/Lazada/Tik...  28/10/2024, 17:03
# 95  Mình có 1 trang web dùng vue 3, hiện tại không...  28/10/2024, 11:28
# 96  Tích hợp API Kiotviet FnB vào website bán hàng...  27/10/2024, 17:37
#
#                   Chỉ còn         Địa điểm  Ngân sách thấp nhất  \
# 0          18 giờ 20 phút         Đồng Nai           40000000.0
# 1          17 ngày 21 giờ        Toàn Quốc            3000000.0
# 2           2 ngày 13 giờ        Toàn Quốc            5000000.0
# 3          27 ngày 16 giờ             None                  0.0
# 4          18 giờ 18 phút         Đồng Nai           40000000.0
# ..                    ...              ...                  ...
# 92  Hết hạn nhận chào giá        Toàn Quốc             200000.0
# 93  Hết hạn nhận chào giá  TP. Hồ Chí Minh            4000000.0
# 94  Hết hạn nhận chào giá  TP. Hồ Chí Minh           10000000.0
# 95  Hết hạn nhận chào giá        Toàn Quốc            1000000.0
# 96  Hết hạn nhận chào giá           Hà Nội            1000000.0
#
#     Ngân sách cao nhất Hình thức làm việc Hình thức trả lương Num_applicants  \
# 0           45000000.0         Làm online      Trả theo dự án             36
# 1           10000000.0         Làm online      Trả theo dự án             18
# 2           10000000.0         Làm online      Trả theo dự án             17
# 3             300000.0               None                None  Sốlượnghồsơ61
# 4           45000000.0         Làm online      Trả theo dự án             36
# ..                 ...                ...                 ...            ...
# 92            800000.0         Làm online      Trả theo dự án              7
# 93           6000000.0         Làm online      Trả theo dự án              5
# 94          30000000.0         Làm online      Trả theo dự án              8
# 95           2000000.0         Làm online      Trả theo dự án              5
# 96           3000000.0         Làm online      Trả theo dự án              1
#
#     Chào giá thấp nhất  Chào giá trung bình  Chào giá cao nhất  \
# 0           20000000.0           39597222.0         50000000.0
# 1                  3.0            2677778.0          7000000.0
# 2            4500000.0           11367059.0         50000000.0
# 3                  NaN                  NaN                NaN
# 4           20000000.0           39597222.0         50000000.0
# ..                 ...                  ...                ...
# 92            300000.0             642857.0          1000000.0
# 93           4000000.0            5000000.0          6000000.0
# 94          10000000.0           28750000.0         50000000.0
# 95           1500000.0            1800000.0          2000000.0
# 96           1000000.0            1000000.0          1000000.0
#
#    Duration (ngày)                                               Link
# 0               21  https://www.vlance.vn/viec-freelance/thiet-ke-...
# 1                6  https://www.vlance.vn/viec-freelance/can-tim-n...
# 2                9  https://www.vlance.vn/viec-freelance/can-xay-d...
# 3    Chỉcòn2716giờ  https://www.vlance.vn/cd-tang-review/s8-review...
# 4               21  https://www.vlance.vn/viec-freelance/thiet-ke-...
# ..             ...                                                ...
# 92               4  https://www.vlance.vn/viec-freelance/viet-plug...
# 93               5  https://www.vlance.vn/viec-freelance/can-php-s...
# 94              14  https://www.vlance.vn/viec-lam/tich-hop-san-sh...
# 95               3  https://www.vlance.vn/viec-lam/cai-dat-seo-cho...
# 96               3  https://www.vlance.vn/viec-freelance/tich-hop-...
#
# [97 rows x 19 columns]

# %%
#Tính tỉ lệ null của các cột
df.isnull().mean() * 100
# Out:
# ID dự án                0.000000
# Type                    0.000000
# Title                   0.000000
# Services                1.030928
# Skills                 21.649485
# Description             0.000000
# Ngày đăng               0.000000
# Chỉ còn                 0.000000
# Địa điểm                1.030928
# Ngân sách thấp nhất     0.000000
# Ngân sách cao nhất      0.000000
# Hình thức làm việc      1.030928
# Hình thức trả lương     1.030928
# Num_applicants          0.000000
# Chào giá thấp nhất      1.030928
# Chào giá trung bình     1.030928
# Chào giá cao nhất       1.030928
# Duration (ngày)         0.000000
# Link                    0.000000
# dtype: float64

# %%
df[df["Chào giá trung bình"].isnull()]
# Out:
#   ID dự án                 Type  \
# 3    80656  Chiến dịch hiển thị
#
#                                                Title Services Skills  \
# 3  [S8] Review cho tiệm Kính Mắt ở Đà Nẵng - Ưu t...      NaN    NaN
#
#                                          Description   Ngày đăng  \
# 3  Mình muốn review cho tiệm kính mắt ở Đà Nẵng, ...  10/11/2024
#
#           Chỉ còn Địa điểm  Ngân sách thấp nhất  Ngân sách cao nhất  \
# 3  27 ngày 16 giờ     None                  0.0            300000.0
#
#   Hình thức làm việc Hình thức trả lương Num_applicants  Chào giá thấp nhất  \
# 3               None                None  Sốlượnghồsơ61                 NaN
#
#    Chào giá trung bình  Chào giá cao nhất Duration (ngày)  \
# 3                  NaN                NaN   Chỉcòn2716giờ
#
#                                                 Link
# 3  https://www.vlance.vn/cd-tang-review/s8-review...

# %%
#in ra dòng mà Chào giá trung bình là null

#fill null bằng giá trị trung bình Chào giá thấp nhất và Chào giá cao nhất/2
df["Chào giá trung bình"].fillna((df["Chào giá thấp nhất"] + df["Chào giá cao nhất"]) / 2, inplace=True)
# Out:
# /tmp/ipykernel_9739/3540137446.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Chào giá trung bình"].fillna((df["Chào giá thấp nhất"] + df["Chào giá cao nhất"]) / 2, inplace=True)
# /tmp/ipykernel_9739/3540137446.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Chào giá trung bình"].fillna((df["Chào giá thấp nhất"] + df["Chào giá cao nhất"]) / 2, inplace=True)

# %%
#Điền Service bằng mode 
df["Services"].fillna(df["Services"].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_9739/1531877793.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Services"].fillna(df["Services"].mode()[0], inplace=True)
# /tmp/ipykernel_9739/1531877793.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Services"].fillna(df["Services"].mode()[0], inplace=True)

# %%
#in ra các dòng mà Skills là null và Link
df[df["Skills"].isnull()]["Link"]
# Out:
# 3     https://www.vlance.vn/cd-tang-review/s8-review...
# 11    https://www.vlance.vn/viec-freelance/can-nguoi...
# 12    https://www.vlance.vn/viec-freelance/he-thong-...
# 18    https://www.vlance.vn/viec-freelance/chuyen-gi...
# 22    https://www.vlance.vn/viec-freelance/setup-ser...
# 33    https://www.vlance.vn/viec-freelance/can-1-ban...
# 34    https://www.vlance.vn/viec-lam/thiet-ke-1-tran...
# 36    https://www.vlance.vn/viec-freelance/gpm-login...
# 38    https://www.vlance.vn/viec-freelance/viet-game...
# 41    https://www.vlance.vn/viec-freelance/viet-tai-...
# 42    https://www.vlance.vn/viec-lam/thiet-ke-chuc-n...
# 43    https://www.vlance.vn/viec-freelance/viet-tai-...
# 48    https://www.vlance.vn/viec-freelance/ung-dung-...
# 54    https://www.vlance.vn/viec-freelance/can-tim-n...
# 57    https://www.vlance.vn/viec-freelance/tool-cron...
# 58    https://www.vlance.vn/viec-freelance/tim-doi-t...
# 70    https://www.vlance.vn/viec-freelance/website-h...
# 72     https://www.vlance.vn/viec-lam/khac-phuc-loi-amp
# 73    https://www.vlance.vn/viec-freelance/can-ban-l...
# 81    https://www.vlance.vn/viec-freelance/kiem-tra-...
# 82    https://www.vlance.vn/viec-freelance/kiem-tra-...
# Name: Link, dtype: object

# %%
#điền Skills bằng mode
df["Skills"].fillna(df["Skills"].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_9739/1782406455.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Skills"].fillna(df["Skills"].mode()[0], inplace=True)
# /tmp/ipykernel_9739/1782406455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Skills"].fillna(df["Skills"].mode()[0], inplace=True)

# %%
len(df["Skills"].unique())
# Out:
# 69

# %%
# Tạo từ điển để ánh xạ tên cột từ tiếng Việt sang tiếng Anh
column_mapping = {
    'ID dự án': 'Project ID',
    'Ngày đăng': 'Posted Date',
    'Chỉ còn': 'Remaining Days',
    'Địa điểm': 'Location',
    'Ngân sách thấp nhất': 'Minimum Budget',
    'Ngân sách cao nhất': 'Maximum Budget',
    'Hình thức làm việc': 'Working Type',
    'Hình thức trả lương': 'Payment Type',
    'Chào giá thấp nhất': 'Lowest Bid',
    'Chào giá trung bình': 'Average Bid',
    'Chào giá cao nhất': 'Highest Bid',
    'Duration (ngày)': 'Duration (Days)',
}

# Áp dụng ánh xạ để đổi tên cột
df = df.rename(columns=column_mapping)

# Kiểm tra lại tên cột sau khi đổi tên
print(df.columns)
# Out:
# Index(['Project ID', 'Type', 'Title', 'Services', 'Skills', 'Description',
#        'Posted Date', 'Remaining Days', 'Location', 'Minimum Budget',
#        'Maximum Budget', 'Working Type', 'Payment Type', 'Num_applicants',
#        'Lowest Bid', 'Average Bid', 'Highest Bid', 'Duration (Days)', 'Link'],
#       dtype='object')

# %%
df
# Out:
#    Project ID                 Type  \
# 0       80678            Đăng việc
# 1       80660            Đăng việc
# 2       80700            Đăng việc
# 3       80656  Chiến dịch hiển thị
# 4       80678            Đăng việc
# ..        ...                  ...
# 92      80358            Đăng việc
# 93      80352            Đăng việc
# 94      80348            Đăng việc
# 95      80343            Đăng việc
# 96      80328            Đăng việc
#
#                                                 Title  \
# 0     Thiết kế web cho trường học ở BIên Hòa Đồng Nai
# 1   Cần tìm người có thể xem videos và viết lại nộ...
# 2                     Cần xây dựng trang web bán hàng
# 3   [S8] Review cho tiệm Kính Mắt ở Đà Nẵng - Ưu t...
# 4     Thiết kế web cho trường học ở BIên Hòa Đồng Nai
# ..                                                ...
# 92                              Viết plugin wordpress
# 93  Cần php senior maintain upgrade UI web theo figma
# 94              Tích hợp sàn Shopee/Lazada/Tiktok API
# 95                            Cài đặt Seo cho website
# 96     Tích hợp API Kiotviet FnB vào website bán hàng
#
#                          Services  \
# 0   Chuyển Template thành Website
# 1         Viết kịch bản cho video
# 2           Dựng website bán hàng
# 3      Viết phần mềm theo yêu cầu
# 4   Chuyển Template thành Website
# ..                            ...
# 92     Viết phần mềm theo yêu cầu
# 93        Phát triển ứng dụng web
# 94        Phát triển ứng dụng web
# 95          Dựng website bán hàng
# 96       Nhập dữ liệu lên website
#
#                                                Skills  \
# 0                                        Thiết kế web
# 1                                         Copywriting
# 2   jQuery,Thiết kế Banner,Thiết kế logo,Node.js,L...
# 3                                                code
# 4                                        Thiết kế web
# ..                                                ...
# 92                                   Wordpress,Plugin
# 93                                          PHP,Figma
# 94                      PostgreSQL,Shopee,Tiktok Shop
# 95                           SEO,Vue.js và express.js
# 96                                 Wordpress,Bán hàng
#
#                                           Description        Posted Date  \
# 0   Cần tìm 1 team Thiết kế web cho trường học ở B...  11/11/2024, 11:28
# 1   Tôi cần tìm 3 bạn có thể xem videos và viết lạ...  10/11/2024, 14:29
# 2   Chào mọi người!  Mình đang muốn xây dựng trang...  12/11/2024, 06:43
# 3   Mình muốn review cho tiệm kính mắt ở Đà Nẵng, ...         10/11/2024
# 4   Cần tìm 1 team Thiết kế web cho trường học ở B...  11/11/2024, 11:28
# ..                                                ...                ...
# 92  Tôi cần viết mốt plugin cho phép kết nối đồng ...  28/10/2024, 22:09
# 93  link dự án  https://drive.google.com/drive/fol...  28/10/2024, 18:52
# 94  Tích hợp đơn hàng từ các sàn Shopee/Lazada/Tik...  28/10/2024, 17:03
# 95  Mình có 1 trang web dùng vue 3, hiện tại không...  28/10/2024, 11:28
# 96  Tích hợp API Kiotviet FnB vào website bán hàng...  27/10/2024, 17:37
#
#            Remaining Days         Location  Minimum Budget  Maximum Budget  \
# 0          18 giờ 20 phút         Đồng Nai      40000000.0      45000000.0
# 1          17 ngày 21 giờ        Toàn Quốc       3000000.0      10000000.0
# 2           2 ngày 13 giờ        Toàn Quốc       5000000.0      10000000.0
# 3          27 ngày 16 giờ             None             0.0        300000.0
# 4          18 giờ 18 phút         Đồng Nai      40000000.0      45000000.0
# ..                    ...              ...             ...             ...
# 92  Hết hạn nhận chào giá        Toàn Quốc        200000.0        800000.0
# 93  Hết hạn nhận chào giá  TP. Hồ Chí Minh       4000000.0       6000000.0
# 94  Hết hạn nhận chào giá  TP. Hồ Chí Minh      10000000.0      30000000.0
# 95  Hết hạn nhận chào giá        Toàn Quốc       1000000.0       2000000.0
# 96  Hết hạn nhận chào giá           Hà Nội       1000000.0       3000000.0
#
#    Working Type    Payment Type Num_applicants  Lowest Bid  Average Bid  \
# 0    Làm online  Trả theo dự án             36  20000000.0   39597222.0
# 1    Làm online  Trả theo dự án             18         3.0    2677778.0
# 2    Làm online  Trả theo dự án             17   4500000.0   11367059.0
# 3          None            None  Sốlượnghồsơ61         NaN          NaN
# 4    Làm online  Trả theo dự án             36  20000000.0   39597222.0
# ..          ...             ...            ...         ...          ...
# 92   Làm online  Trả theo dự án              7    300000.0     642857.0
# 93   Làm online  Trả theo dự án              5   4000000.0    5000000.0
# 94   Làm online  Trả theo dự án              8  10000000.0   28750000.0
# 95   Làm online  Trả theo dự án              5   1500000.0    1800000.0
# 96   Làm online  Trả theo dự án              1   1000000.0    1000000.0
#
#     Highest Bid Duration (Days)  \
# 0    50000000.0              21
# 1     7000000.0               6
# 2    50000000.0               9
# 3           NaN   Chỉcòn2716giờ
# 4    50000000.0              21
# ..          ...             ...
# 92    1000000.0               4
# 93    6000000.0               5
# 94   50000000.0              14
# 95    2000000.0               3
# 96    1000000.0               3
#
#                                                  Link
# 0   https://www.vlance.vn/viec-freelance/thiet-ke-...
# 1   https://www.vlance.vn/viec-freelance/can-tim-n...
# 2   https://www.vlance.vn/viec-freelance/can-xay-d...
# 3   https://www.vlance.vn/cd-tang-review/s8-review...
# 4   https://www.vlance.vn/viec-freelance/thiet-ke-...
# ..                                                ...
# 92  https://www.vlance.vn/viec-freelance/viet-plug...
# 93  https://www.vlance.vn/viec-freelance/can-php-s...
# 94  https://www.vlance.vn/viec-lam/tich-hop-san-sh...
# 95  https://www.vlance.vn/viec-lam/cai-dat-seo-cho...
# 96  https://www.vlance.vn/viec-freelance/tich-hop-...
#
# [97 rows x 19 columns]

# %%
#ghi xuống file csv ..\..\..\..\..\data\processed\cleaned_job_posts.csv
# df.to_csv(r'..\..\..\..\data\processed\cleaned_job_posts.csv', index=False)
