# %%
import pandas as pd
import re

# %% [markdown]
# # Xử lí file job post

# %%
#đọc file job post ..\..\..\..\data\raw\merged_job_posts.csv
df = pd.read_csv(r'..\..\..\..\data\raw\merged_job_posts.csv')
df
# Out:
#                  Type                                              Title  \
# 0       Nhận chào giá      \nChỉnh sửa website Wordpress Đã hoàn thành\n
# 1           Đăng việc  \nMình cần làm 1 web bán hàng và giới thiệu sả...
# 2      Secret project                                                NaN
# 3           Đăng việc  \nThiết kế trang Web từ file thiết kế đã làm (...
# 4           Đăng việc       \nMobile APP nhà cái Hết hạn nhận chào giá\n
# ...               ...                                                ...
# 11695       Đăng việc           \nThiết kế UI/UX Hết hạn nhận chào giá\n
# 11696       Đăng việc  \nViết lại script theo yêu cầu mới để có thể c...
# 11697  Secret project                                                NaN
# 11698   Nhận chào giá      \nChỉnh sửa website Wordpress Đã hoàn thành\n
# 11699       Đăng việc  \nMình cần làm 1 web bán hàng và giới thiệu sả...
#
#                                                 Services  \
# 0      \nDịch vụ cần thuê:\n\n\nViết phần mềm theo yê...
# 1      \nDịch vụ cần thuê:\n\n\nDựng website bán hàng...
# 2                                                    NaN
# 3      \nDịch vụ cần thuê:\n\n\nCắt HTML/CSS từ PSD \n\n
# 4      \nDịch vụ cần thuê:\n\n\nLàm Mobile App theo y...
# ...                                                  ...
# 11695  \nDịch vụ cần thuê:\n\n\nThiết kế giao diện we...
# 11696  \nDịch vụ cần thuê:\n\n\nViết phần mềm theo yê...
# 11697                                                NaN
# 11698  \nDịch vụ cần thuê:\n\n\nViết phần mềm theo yê...
# 11699  \nDịch vụ cần thuê:\n\n\nDựng website bán hàng...
#
#                                                   Skills  \
# 0      \nKỹ năng\n\nWordpress , \nresponsive , \ndesi...
# 1                                \nKỹ năng\n\nBán hàng
# 2                                                    NaN
# 3      \nKỹ năng\n\nTiếng Anh , \nPSD , \nThiết kế tr...
# 4                            \nKỹ năng\n\niOS , \ncode
# ...                                                  ...
# 11695  \nKỹ năng\n\niOS , \nGraphic Design , \nAndroi...
# 11696  \nKỹ năng\n\nJavascript , \njQuery , \nThiết k...
# 11697                                                NaN
# 11698  \nKỹ năng\n\nWordpress , \nresponsive , \ndesi...
# 11699                            \nKỹ năng\n\nBán hàng
#
#                                              Description  \
# 0      \n\nYêu cầu: \nLàm giống Design thêm Responsiv...
# 1      \n\nWebsite không yêu cầu nhiều chỉ cần giao d...
# 2                                                    NaN
# 3      \n\nCông ty mình cần tuyển một bạn Freelancer ...
# 4      \n\nApp chỉ có chức năng gọi API kết quả bóng ...
# ...                                                  ...
# 11695  \n\nXin chào \nHiện tại bên công ty mình đang ...
# 11696  \n\n+OLDED: Script đang chạy được trên trang h...
# 11697                                                NaN
# 11698  \n\nYêu cầu: \nLàm giống Design thêm Responsiv...
# 11699  \n\nWebsite không yêu cầu nhiều chỉ cần giao d...
#
#                                              In4_project  \
# 0      \n\nID dự án\n42059\nNgày đăng\n\n            ...
# 1      \n\nID dự án\n42057\nNgày đăng\n\n            ...
# 2                                                    NaN
# 3      \n\nID dự án\n42052\nNgày đăng\n\n            ...
# 4      \n\nID dự án\n42051\nNgày đăng\n\n            ...
# ...                                                  ...
# 11695  \n\nID dự án\n42063\nNgày đăng\n\n            ...
# 11696  \n\nID dự án\n42056\nNgày đăng\n\n            ...
# 11697                                                NaN
# 11698  \n\nID dự án\n42059\nNgày đăng\n\n            ...
# 11699  \n\nID dự án\n42057\nNgày đăng\n\n            ...
#
#                                           In4_employment  \
# 0      \n\n\n\n\n\n\n\n\n\n                        Vă...
# 1      \n\n\n\n\n\n\n\n\n\n                        Tu...
# 2                                                    NaN
# 3      \n\n\n\n\n\n\n\n\n\n                        Ph...
# 4      \n\n\n\n\n\n\n\n\n\n                        Tr...
# ...                                                  ...
# 11695  \n\n\n\n\n\n\n\n\n\n                        Dư...
# 11696  \n\n\n\n\n\n\n\n\n\n                        Ng...
# 11697                                                NaN
# 11698  \n\n\n\n\n\n\n\n\n\n                        Vă...
# 11699  \n\n\n\n\n\n\n\n\n\n                        Tu...
#
#                                           Num_applicants  \
# 0      \n                Chào giá:                   ...
# 1      \n                Chào giá:                   ...
# 2                                                    NaN
# 3      \n                Chào giá:                   ...
# 4      \n                Chào giá:                   ...
# ...                                                  ...
# 11695  \n                Chào giá:                   ...
# 11696  \n                Chào giá:                   ...
# 11697                                                NaN
# 11698  \n                Chào giá:                   ...
# 11699  \n                Chào giá:                   ...
#
#                                               Applicants  \
# 0                                   ['/freelancer/dong']
# 1      ['/freelancer/luu-ngoc-quang', '/freelancer/ng...
# 2                                                    NaN
# 3      ['/freelancer/hoang-van-quang-2', '/freelancer...
# 4      ['/freelancer/tung-pham-thanh-5', '/freelancer...
# ...                                                  ...
# 11695  ['/freelancer/nghi-tran-nguyen', '/freelancer/...
# 11696  ['/freelancer/khanh-nguyen-253', '/freelancer/...
# 11697                                                NaN
# 11698                               ['/freelancer/dong']
# 11699  ['/freelancer/luu-ngoc-quang', '/freelancer/ng...
#
#                                                 Duration  \
# 0      \n                Trung bình:                3...
# 1      \n                Trung bình:                5...
# 2                                                    NaN
# 3      \n                Trung bình:                9...
# 4      \n                Trung bình:                1...
# ...                                                  ...
# 11695  \n                Trung bình:                8...
# 11696  \n                Trung bình:                2...
# 11697                                                NaN
# 11698  \n                Trung bình:                3...
# 11699  \n                Trung bình:                5...
#
#                                                    Price  \
# 0      \n\n                Thấp nhất:                ...
# 1      \n\n                Thấp nhất:                ...
# 2                                                    NaN
# 3      \n\n                Thấp nhất:                ...
# 4      \n\n                Thấp nhất:                ...
# ...                                                  ...
# 11695  \n\n                Thấp nhất:                ...
# 11696  \n\n                Thấp nhất:                ...
# 11697                                                NaN
# 11698  \n\n                Thấp nhất:                ...
# 11699  \n\n                Thấp nhất:                ...
#
#                                                     Link
# 0      https://www.vlance.vn/viec-freelance/chinh-sua...
# 1      https://www.vlance.vn/viec-freelance/minh-can-...
# 2      https://www.vlance.vn/viec-freelance/crawl-dat...
# 3      https://www.vlance.vn/viec-freelance/thiet-ke-...
# 4      https://www.vlance.vn/viec-freelance/mobile-ap...
# ...                                                  ...
# 11695  https://www.vlance.vn/viec-freelance/thiet-ke-...
# 11696  https://www.vlance.vn/viec-freelance/viet-lai-...
# 11697  https://www.vlance.vn/viec-freelance/can-tim-t...
# 11698  https://www.vlance.vn/viec-freelance/chinh-sua...
# 11699  https://www.vlance.vn/viec-freelance/minh-can-...
#
# [11700 rows x 12 columns]

# %% [markdown]
# Loại bỏ các secret project vì chúng không có thông tin gì cả

# %%
#if type = "Secret project" thì drop
df = df[df['Type'] != 'Secret project']

# %%
df
# Out:
#                 Type                                              Title  \
# 0      Nhận chào giá      \nChỉnh sửa website Wordpress Đã hoàn thành\n
# 1          Đăng việc  \nMình cần làm 1 web bán hàng và giới thiệu sả...
# 3          Đăng việc  \nThiết kế trang Web từ file thiết kế đã làm (...
# 4          Đăng việc       \nMobile APP nhà cái Hết hạn nhận chào giá\n
# 5          Đăng việc  \nClone 1 trang bằng Elementor Hết hạn nhận ch...
# ...              ...                                                ...
# 11694      Đăng việc  \nSửa code plugin theo đúng chuẩn wordpress Hế...
# 11695      Đăng việc           \nThiết kế UI/UX Hết hạn nhận chào giá\n
# 11696      Đăng việc  \nViết lại script theo yêu cầu mới để có thể c...
# 11698  Nhận chào giá      \nChỉnh sửa website Wordpress Đã hoàn thành\n
# 11699      Đăng việc  \nMình cần làm 1 web bán hàng và giới thiệu sả...
#
#                                                 Services  \
# 0      \nDịch vụ cần thuê:\n\n\nViết phần mềm theo yê...
# 1      \nDịch vụ cần thuê:\n\n\nDựng website bán hàng...
# 3      \nDịch vụ cần thuê:\n\n\nCắt HTML/CSS từ PSD \n\n
# 4      \nDịch vụ cần thuê:\n\n\nLàm Mobile App theo y...
# 5      \nDịch vụ cần thuê:\n\n\nThiết kế giao diện we...
# ...                                                  ...
# 11694  \nDịch vụ cần thuê:\n\n\nViết phần mềm theo yê...
# 11695  \nDịch vụ cần thuê:\n\n\nThiết kế giao diện we...
# 11696  \nDịch vụ cần thuê:\n\n\nViết phần mềm theo yê...
# 11698  \nDịch vụ cần thuê:\n\n\nViết phần mềm theo yê...
# 11699  \nDịch vụ cần thuê:\n\n\nDựng website bán hàng...
#
#                                                   Skills  \
# 0      \nKỹ năng\n\nWordpress , \nresponsive , \ndesi...
# 1                                \nKỹ năng\n\nBán hàng
# 3      \nKỹ năng\n\nTiếng Anh , \nPSD , \nThiết kế tr...
# 4                            \nKỹ năng\n\niOS , \ncode
# 5                               \nKỹ năng\n\nWordpress
# ...                                                  ...
# 11694  \nKỹ năng\n\nPHP , \nWordpress , \nPlugin , \n...
# 11695  \nKỹ năng\n\niOS , \nGraphic Design , \nAndroi...
# 11696  \nKỹ năng\n\nJavascript , \njQuery , \nThiết k...
# 11698  \nKỹ năng\n\nWordpress , \nresponsive , \ndesi...
# 11699                            \nKỹ năng\n\nBán hàng
#
#                                              Description  \
# 0      \n\nYêu cầu: \nLàm giống Design thêm Responsiv...
# 1      \n\nWebsite không yêu cầu nhiều chỉ cần giao d...
# 3      \n\nCông ty mình cần tuyển một bạn Freelancer ...
# 4      \n\nApp chỉ có chức năng gọi API kết quả bóng ...
# 5      \n\nMình cần clone lại chỉ 1 trang này: tidal....
# ...                                                  ...
# 11694  \n\nHi all, \nTôi cần tìm một wordpress dev ex...
# 11695  \n\nXin chào \nHiện tại bên công ty mình đang ...
# 11696  \n\n+OLDED: Script đang chạy được trên trang h...
# 11698  \n\nYêu cầu: \nLàm giống Design thêm Responsiv...
# 11699  \n\nWebsite không yêu cầu nhiều chỉ cần giao d...
#
#                                              In4_project  \
# 0      \n\nID dự án\n42059\nNgày đăng\n\n            ...
# 1      \n\nID dự án\n42057\nNgày đăng\n\n            ...
# 3      \n\nID dự án\n42052\nNgày đăng\n\n            ...
# 4      \n\nID dự án\n42051\nNgày đăng\n\n            ...
# 5      \n\nID dự án\n42044\nNgày đăng\n\n            ...
# ...                                                  ...
# 11694  \n\nID dự án\n42064\nNgày đăng\n\n            ...
# 11695  \n\nID dự án\n42063\nNgày đăng\n\n            ...
# 11696  \n\nID dự án\n42056\nNgày đăng\n\n            ...
# 11698  \n\nID dự án\n42059\nNgày đăng\n\n            ...
# 11699  \n\nID dự án\n42057\nNgày đăng\n\n            ...
#
#                                           In4_employment  \
# 0      \n\n\n\n\n\n\n\n\n\n                        Vă...
# 1      \n\n\n\n\n\n\n\n\n\n                        Tu...
# 3      \n\n\n\n\n\n\n\n\n\n                        Ph...
# 4      \n\n\n\n\n\n\n\n\n\n                        Tr...
# 5      \n\n\n\n\n\n\n\n\n\n                        Tu...
# ...                                                  ...
# 11694  \n\n\n\n\n\n\n\n\n\n                        Tu...
# 11695  \n\n\n\n\n\n\n\n\n\n                        Dư...
# 11696  \n\n\n\n\n\n\n\n\n\n                        Ng...
# 11698  \n\n\n\n\n\n\n\n\n\n                        Vă...
# 11699  \n\n\n\n\n\n\n\n\n\n                        Tu...
#
#                                           Num_applicants  \
# 0      \n                Chào giá:                   ...
# 1      \n                Chào giá:                   ...
# 3      \n                Chào giá:                   ...
# 4      \n                Chào giá:                   ...
# 5      \n                Chào giá:                   ...
# ...                                                  ...
# 11694  \n                Chào giá:                   ...
# 11695  \n                Chào giá:                   ...
# 11696  \n                Chào giá:                   ...
# 11698  \n                Chào giá:                   ...
# 11699  \n                Chào giá:                   ...
#
#                                               Applicants  \
# 0                                   ['/freelancer/dong']
# 1      ['/freelancer/luu-ngoc-quang', '/freelancer/ng...
# 3      ['/freelancer/hoang-van-quang-2', '/freelancer...
# 4      ['/freelancer/tung-pham-thanh-5', '/freelancer...
# 5      ['/freelancer/huynh-chi-hieu', '/freelancer/gu...
# ...                                                  ...
# 11694                 ['/freelancer/tran-xuan-truong-7']
# 11695  ['/freelancer/nghi-tran-nguyen', '/freelancer/...
# 11696  ['/freelancer/khanh-nguyen-253', '/freelancer/...
# 11698                               ['/freelancer/dong']
# 11699  ['/freelancer/luu-ngoc-quang', '/freelancer/ng...
#
#                                                 Duration  \
# 0      \n                Trung bình:                3...
# 1      \n                Trung bình:                5...
# 3      \n                Trung bình:                9...
# 4      \n                Trung bình:                1...
# 5      \n                Trung bình:                1...
# ...                                                  ...
# 11694  \n                Trung bình:                3...
# 11695  \n                Trung bình:                8...
# 11696  \n                Trung bình:                2...
# 11698  \n                Trung bình:                3...
# 11699  \n                Trung bình:                5...
#
#                                                    Price  \
# 0      \n\n                Thấp nhất:                ...
# 1      \n\n                Thấp nhất:                ...
# 3      \n\n                Thấp nhất:                ...
# 4      \n\n                Thấp nhất:                ...
# 5      \n\n                Thấp nhất:                ...
# ...                                                  ...
# 11694  \n\n                Thấp nhất:                ...
# 11695  \n\n                Thấp nhất:                ...
# 11696  \n\n                Thấp nhất:                ...
# 11698  \n\n                Thấp nhất:                ...
# 11699  \n\n                Thấp nhất:                ...
#
#                                                     Link
# 0      https://www.vlance.vn/viec-freelance/chinh-sua...
# 1      https://www.vlance.vn/viec-freelance/minh-can-...
# 3      https://www.vlance.vn/viec-freelance/thiet-ke-...
# 4      https://www.vlance.vn/viec-freelance/mobile-ap...
# 5      https://www.vlance.vn/viec-freelance/clone-1-t...
# ...                                                  ...
# 11694  https://www.vlance.vn/viec-freelance/sua-code-...
# 11695  https://www.vlance.vn/viec-freelance/thiet-ke-...
# 11696  https://www.vlance.vn/viec-freelance/viet-lai-...
# 11698  https://www.vlance.vn/viec-freelance/chinh-sua...
# 11699  https://www.vlance.vn/viec-freelance/minh-can-...
#
# [11457 rows x 12 columns]

# %%
len(df)
# Out:
# 11457

# %%
for index, row in df.iterrows():
    print(row['Title'])
# Out:
# Chỉnh sửa website Wordpress Đã hoàn thành
#
#
# Mình cần làm 1 web bán hàng và giới thiệu sản phẩm Hết hạn nhận chào giá
#
#
# Thiết kế trang Web từ file thiết kế đã làm (PSD) Hết hạn nhận chào giá
#
#
# Mobile APP nhà cái Hết hạn nhận chào giá
#
#
# Clone 1 trang bằng Elementor Hết hạn nhận chào giá
#
#
# App đo số liệu cơ thể bằng hình ảnh chụp Hết hạn nhận chào giá
#
#
# Sửa lỗi PHP của tablet of content Hết hạn nhận chào giá
#
#
# Ecommerce Website - Magento Hết hạn nhận chào giá
#
#
# Tool chạy quảng cáo facebook ads trên web Hết hạn nhận chào giá
#
#
# Scrape và xử lý dữ liệu từ Twitter Đã hoàn thành
#
#
# Làm Mobile App đơn giản cho IOS Hết hạn nhận chào giá
#
#
# Nhân viên wordpress Hết hạn nhận chào giá
#
#
# Tải File và Rename File Thủ Công Đã hoàn thành
#
#
# Chỉnh sửa website Hết hạn nhận chào giá
#
#
# Thiết kế và lập trình website cho hội phụ nữ Hết hạn nhận chào giá
#
#
# Cần triển khai app cho ứng dụng FuniMart bên công ty Hết hạn nhận chào giá
#
#
# Phát triển tool đăng ký sản phẩm lên amazon Hết hạn nhận chào giá
#
#
# Tìm coder thiết kế website chủ yếu là Landing Page Hết hạn nhận chào giá
#
#
# Lập trình Website Hết hạn nhận chào giá
#
#
# Viết vòng lặp treeview bằng ngôn ngữ asp Hết hạn nhận chào giá
#
#
# Thiết kế trang web thông tin Hết hạn nhận chào giá
#
#
# Thiết kế phần mền lấy số điện thoại trong bài chờ phê duyệt trên group và ibox tin nhắn trên fanphae Hết hạn nhận chào giá
#
#
# Cá nhân hóa mục đăng ký Hết hạn nhận chào giá
#
#
# Lọc và đổ dữ liệu đơn hàng cho file Excel từ các file excel khác Đã hoàn thành
#
#
# Viết srcipt cho tổng đài Asterisk Hết hạn nhận chào giá
#
#
# Lập trình PHP/MySQL Hết hạn nhận chào giá
#
#
# Thiết kế game, thiết kế website, tool theo yêu cầu Hết hạn nhận chào giá
#
#
# Làm Mobile App cho IOS Hết hạn nhận chào giá
# FANPAGE
#
#
# Thiết kế website bán hàng online, có tích hợp thanh toán tự động bằng Vietcombank và MOMO Hết hạn nhận chào giá
#
#
# Thiết kế Font-end Webapp Quản lý khối lượng công trình Hết hạn nhận chào giá
# FANPAGE
#
#
#
# Test và kiểm tra lỗi xác thực REST API của WORDPRESS, WOOCOMMERCE Hết hạn nhận chào giá
# FANPAGE
#
#
# Cần nâng cấp web noithatshop.vn Hết hạn nhận chào giá
#
#
#
# Cần viết mod game Hết hạn nhận chào giá
# FANPAGE
#
#
# App mua sắm trực tuyến - ưu tiên HCM Hết hạn nhận chào giá
#
#
# SEO cho web Đã hoàn thành
#
#
# Code site trên nền wordpress giống trang Chanhtuoi Hết hạn nhận chào giá
#
#
# App Livestream Hết hạn nhận chào giá
#
#
# Design a incident fault system front end only Hết hạn nhận chào giá
#
#
# Cần nhờ người kiểm tra test lỗi website Hết hạn nhận chào giá
#
#
# Tạo Tool Tự Động Download và Rename File Hết hạn nhận chào giá
#
#
# Crawl data lưu về googlesheets (hoặc khác) theo thời gian thực Hết hạn nhận chào giá
#
#
# Sửa ứng dụng viết bằng Java Hết hạn nhận chào giá
#
#
# Hoàn thiện trang web giáo dục (đã có code sẵn và giao diện cơ bản) Hết hạn nhận chào giá
#
#
# Phát triển website review sản phẩm, tìm kiếm thông tin Hết hạn nhận chào giá
#
#
#
# Tích hợp web application vào website Hết hạn nhận chào giá
#
#
# Lấy dữ liệu youtube thông qua proxy hoặc giải pháp khác miễn là ổn định Hết hạn nhận chào giá
#
#
# Sao chép dựa trên 1 app có sẵn Hết hạn nhận chào giá
#
#
# Tìm người phát triển app trên android và IOS Hết hạn nhận chào giá
#
#
# Thiết kế web chuyên về đầu tư tài chính Hết hạn nhận chào giá
#
#
# Cần người setup gian hàng shopify Hết hạn nhận chào giá
#
#
# Viết ứng dụng game cờ đặt cho trẻ em Hết hạn nhận chào giá
#
#
# Xuất dữ liệu từ website và tool rút đồ game tự động Đã hoàn thành
#
#
# Làm mobile App đặt lịch theo chức năng yêu cầu Hết hạn nhận chào giá
#
#
# Lập trình app trên điện thoại di động androi Hết hạn nhận chào giá
#
#
# Dự án rpython nhỏ có sẳn dữ liệu và code Hết hạn nhận chào giá
#
#
# Viết tool hoặc mod game Hết hạn nhận chào giá
#
#
# THIẾT KẾ WEB QUẢNG CÁO BÁN HÀNG KÈM BOOKING GIỐNG AGODA Hết hạn nhận chào giá
#
#
# PHP, HTML,CSS, JS, OPENCART Hết hạn nhận chào giá
#
#
# Chuyển từ C++ sang Python Hết hạn nhận chào giá
#
#
# Cần xây dựng Backlink cho Website Hết hạn nhận chào giá
#
#
# Crypto/USDT Hết hạn nhận chào giá
#
#
# Chuyển nội dung mấy blog qua website Đã hoàn thành
#
#
# Viết chương trình C# đọc giá trị đồng hồ số Fluke 8845A qua cổng RS232 Hết hạn nhận chào giá
#
#
# Thiết kế website và di động Hết hạn nhận chào giá
#
#
# Decompile file ex4 thành file mq4 Hết hạn nhận chào giá
#
#
# Chăm sóc khách hàng bằng Zalo Hết hạn nhận chào giá
#
#
# Tìm người sửa lỗi WordPress plugin, theme Hết hạn nhận chào giá
#
#
# Mình cần thiết kế website bán sim, đã có mẫu, cần up được nhiều sim 1 lúc Hết hạn nhận chào giá
#
#
# NodeJs Backend RESTful API Đã hoàn thành
#
#
# Tạo Tool Tự Động Download và Rename File Hết hạn nhận chào giá
#
#
# Website bán hàng Mỹ Phẩm cho Đại Lý - Có Hoa hồng, Thưởng Hết hạn nhận chào giá
#
#
# Cài đặt plugin yêu cầu login để xem link trong discourse Hết hạn nhận chào giá
#
#
# Cần làm module đồng bộ sản phẩm giữa odoo và sàn thương mại điện tử lazada, kiti, shopee, hot deal Hết hạn nhận chào giá
#
#
# Viết các công cụ bằng C# theo yêu cầu Hết hạn nhận chào giá
#
#
# Thiết kế website doanh nghiệp Hết hạn nhận chào giá
#
#
# Lập trình Flutter Hết hạn nhận chào giá
#
#
# Cty mình cần 1 bạn nghiên cứu cách xác minh Google maps hàng loạt để tạo 100-500 maps phủ thị trường Hết hạn nhận chào giá
#
#
# Design giao diện và cắt html Đã hoàn thành
#
#
# Làm Mạch On-Off 12v sử dụng c005 Hết hạn nhận chào giá
#
#
# Tuyển DEV game code .LUA . Hết hạn nhận chào giá
#
#
# Xây dựng frontend wap/web chuyên về xem video, phim, review phim Hết hạn nhận chào giá
#
#
# Chỉnh sửa source code website, tối ưu SEO, thêm chức năng cho trang web Hết hạn nhận chào giá
#
#
# Tao web thiêt kế ung dung Hết hạn nhận chào giá
#
#
# Lập trình lịch làm việc theo mẫu riêng Hết hạn nhận chào giá
#
#
# Thiết kế file Dashboard tổng hợp dữ liệu KPI Hết hạn nhận chào giá
#
#
# Hoàn thiện tool sử dụng facebook API đăng ảnh lên tường Hết hạn nhận chào giá
#
#
# Cần viết regex để làm data mining Hết hạn nhận chào giá
#
#
# Personal Assistant/Writer/Research/Project management, Monthly, Junior Level Hết hạn nhận chào giá
#
#
# THIẾT KẾ WEBSITE CHO CÔNG TY SẢN XUẤT CA CAO VÀ SÔ CÔ LA Hết hạn nhận chào giá
#
#
# Cần 1 bạn viết tool auto game MU https://muvip.mobi Hết hạn nhận chào giá
#
#
# Làm cổng thanh toán momo và 1 số ngân hàng cho website Hết hạn nhận chào giá
#
#
# Lập trình viên PHPFOX Hết hạn nhận chào giá
#
#
# Tạo Bot Giao Dịch Crypto trên Sàn binance.com FUTURE Hết hạn nhận chào giá
#
#
# [JAVA DEVLOPER] - UP TO 1700USD Hết hạn nhận chào giá
#
#
# Nhân Viên IT Hết hạn nhận chào giá
#
#
# Cần giúp viết 1 đoạn imacros auto upload Hết hạn nhận chào giá
#
#
# Viết 1 tool có tính năng tự động chặn video trùng khớp khi Right manager của Facebook quét được Hết hạn nhận chào giá
#
#
# Thiết kế app booking khách sạn có location api from google Hết hạn nhận chào giá
#
#
# Lập trình codova trên ios Hết hạn nhận chào giá
#
#
# Thiết kế website theo API có sẵn Hết hạn nhận chào giá
#
#
# Xây dựng web theo bản wireframe đã vẽ Hết hạn nhận chào giá
#
#
# Thiết kế mạch điện tử Hết hạn nhận chào giá
#
#
# Tìm Developer Cứng WooCommerce Hết hạn nhận chào giá
#
#
# Cần tìm người hoàn thiện nội dung website Hết hạn nhận chào giá
#
#
# Cần tìm web developer Hết hạn nhận chào giá
#
#
# Tìm đơn vị thiết kế hệ thống điều khiển thiết bị trên web - ưu tiên HCM Hết hạn nhận chào giá
#
#
# Từ SDK của nhà cung cấp, chỉnh sửa phát triển lại cho mainboard tuỳ chỉnh Hết hạn nhận chào giá
#
#
# Viết Extension Chrome - Upload lên Webstore Hết hạn nhận chào giá
#
#
#
# Cần Thiết kế Website update các chức năng api từ trang ngoài vào liên quan đến facebook Hết hạn nhận chào giá
#
#
# SENIOR BACKEND DEVELOPER (NODEJS/GOLAND) - UP TO 2500USD Hết hạn nhận chào giá
#
#
# SEO service cho website công ty Hết hạn nhận chào giá
#
#
# ERASF Hết hạn nhận chào giá
#
#
# Tuyển Free lancer Lập trình Hệ thống Quản lý Support e-Ticket Hết hạn nhận chào giá
#
#
# Xử lý sự kiện Zalo Official Account Hết hạn nhận chào giá
#
#
# I need this Wordpress Theme Hết hạn nhận chào giá
#
#
# Viết phần mềm java Đã hoàn thành
#
#
# Cần làm nốt App cho mobile Hết hạn nhận chào giá
#
#
# Php html css sql developper Hết hạn nhận chào giá
#
#
# Tuyển người có kinh nghiệm lâu năm về SEO Hết hạn nhận chào giá
#
#
# Lập trình Google Apps Script Hết hạn nhận chào giá
#
#
# Lập trình phần mềm IOS cho ứng dụng nhà thông minh Hết hạn nhận chào giá
#
#
# Thiết kế web bán hàng Hết hạn nhận chào giá
#
#
# Tuyển Dụng Freelance Developer Làm Web Scraping và Xử Lý Data (Làm Việc Partime Tại Nhà/Lương Cạnh Tranh) - TK Media Hết hạn nhận chào giá
#
#
# Chỉnh sửa giao diện hiện tại để hiển thị tốt trên iphone, android Hết hạn nhận chào giá
#
#
# Tuyển Free lancer Lập trình Webmail client Hết hạn nhận chào giá
#
#
# Nhân viên lập trình mobile Hết hạn nhận chào giá
#
#
# Web developer Hết hạn nhận chào giá
#
#
# Tuyển BLACK CODER kỹ thuật cao làm dự án về FB (Lương $2000 - $3000/tháng) Hết hạn nhận chào giá
#
#
# MySQL and Firebase Hết hạn nhận chào giá
#
#
# Edit Moodle Quizz theo giao diện sẵn có Hết hạn nhận chào giá
#
#
# Tuyển Free lancer Lập trình Hệ thống Điều lịch xe Hết hạn nhận chào giá
#
#
# Phần mềm đăng ký tài khoản tự động Hết hạn nhận chào giá
#
#
# Cắt giao diện app mobile chuẩn theo file thiết kế Hết hạn nhận chào giá
#
#
# Phat trien he thong chat (chatbot) Hết hạn nhận chào giá
#
#
# Cần chỉnh sửa 1 template Access database Hết hạn nhận chào giá
#
#
# Lập trình java Hết hạn nhận chào giá
#
#
# Viết phần mềm java Hết hạn nhận chào giá
#
#
# Thiết kế - Xây dựng website quản lý mua hàng và thanh toán Hết hạn nhận chào giá
#
#
# Phần mềm quản lý Studio Hết hạn nhận chào giá
#
#
# Cần giúp tạo một chrome extension và front end cho một dự án Hết hạn nhận chào giá
#
#
# Mình cần tìm người viết một app chat như whatsapp, chạy dc trên mobile và web Hết hạn nhận chào giá
#
#
# Cần Thiết kế Website update các chức năng api từ trang ngoài vào liên quan đến facebook Hết hạn nhận chào giá
#
#
# Chỉnh sửa lại web từ template có sắn Hết hạn nhận chào giá
#
#
# Cần tìm bạn làm php codeignier Hết hạn nhận chào giá
#
#
# Thiết Kế 1 Form Đặt hàng Hết hạn nhận chào giá
#
#
# App hiển thị giá trị chỉ báo tradingview Đã hoàn thành
#
#
# Cắt css + build landing responsive quảng cáo game Hết hạn nhận chào giá
#
#
# Chỉnh sửa website tour du lịch Đã hoàn thành
#
#
# Cần team thiết kế app IOS và Android bán hàng tương tự Canifa Đã hoàn thành
#
#
# Cần một bạn rành về c/c++, QT hoặc Juce ưu tiên giỏi toán/DSP Hết hạn nhận chào giá
#
#
# Develop React native app Hết hạn nhận chào giá
#
#
# VBA- EXCEL Đã hoàn thành
#
#
# Cần viết một apps chạy nền web, get dữ liệu Email từ web bất kỳ Hết hạn nhận chào giá
#
#
# Tối ưu SEO onpage Hết hạn nhận chào giá
#
#
# Done Hết hạn nhận chào giá
#
#
# Chuyển dữ liệu từ EXcel lên firebase google Hết hạn nhận chào giá
#
#
# Cần Team làm Token TRC-21 Hết hạn nhận chào giá
#
#
# [Laravel] Xây dựng web site về Casino & Gambling Online (Poker) Hết hạn nhận chào giá
#
#
# Cài đặt cấu hình server forum discourse Hết hạn nhận chào giá
#
#
# Việc bán thời gian lập trình viên PHP, HTML, và crypto Hết hạn nhận chào giá
#
#
# Lập trình viên PHP, HTML có kiến thức về blockchain Hết hạn nhận chào giá
#
#
# Nâng cấp hệ thống web + server đang có Hết hạn nhận chào giá
#
#
# Nâng cấp web PHP có sẵn Hết hạn nhận chào giá
#
#
# Cần app Lịch Việt tiện dụng trên Android Hết hạn nhận chào giá
#
#
# Thiet ke trang web ban hang cao cap cho beauty supplies Hết hạn nhận chào giá
#
#
# Tích hợp template lên Haravan Hết hạn nhận chào giá
#
#
# Thiết kế website công ty Hết hạn nhận chào giá
#
#
# Lập trình app mobile android &iOS Hết hạn nhận chào giá
#
#
# Full Stack Developer Hết hạn nhận chào giá
#
#
# Back-end Developer Hết hạn nhận chào giá
#
#
# Cần làm app dạng webview android Đã hoàn thành
#
#
# Thiết kê website về review Hết hạn nhận chào giá
#
#
# React native app cho website video Đã hoàn thành
#
#
# Viết VBA hoặc tool để process excel data liên quan đến payroll Hết hạn nhận chào giá
#
#
# Thiết kế Website Đổi thẻ cào thành tiền mặt Hết hạn nhận chào giá
#
#
# Mua code website bán giày Hết hạn nhận chào giá
#
#
# Cần update lại giao diện app theo thiết kế Hết hạn nhận chào giá
#
#
# Viết phần mêm tự động các thao tác trên web sử dụng selenium Hết hạn nhận chào giá
#
#
# Hà Nội - Cắt html, css theo giao diện Hết hạn nhận chào giá
#
#
# Viết plugin wordpress Hết hạn nhận chào giá
#
#
# Làm tool auto đánh tài xỉu theo yêu cầu Đã hoàn thành
#
#
# Lập hệ thống cho web bán hàng đã có giao diện Hết hạn nhận chào giá
#
#
# Cần viết phần mềm đơn giản thao tác với simbank bằng C# Hết hạn nhận chào giá
#
#
# Thiết kế/xây dựng thay đổi giao diện website giới thiệu công ty. Đã hoàn thành
#
#
# App game giải trí Hết hạn nhận chào giá
#
#
# SEO website công ty Hết hạn nhận chào giá
#
#
# Test và Fix lỗi cơ bản cho mã nguồn PHP chạy API Hết hạn nhận chào giá
#
#
#
# Cần deploy 2 mã nguồn PHP Yii lên server Hết hạn nhận chào giá
#
#
# So Sánh Hình Ảnh Thủ Công Bằng Mắt và Nhập Số Đã hoàn thành
#
#
# Xây dựng ứng dụng web bằng ReactJS Hết hạn nhận chào giá
#
#
# Viết lại Api ( Dựa theo tài liệu và code có sẵn ) Hết hạn nhận chào giá
#
#
# App Vòng xoay cuộc đời (game) Hết hạn nhận chào giá
#
#
# Tuyển người xây dựng app Bảo hiểm công nghệ số Hết hạn nhận chào giá
#
#
#
# Viết nội dung cho web, viết về cái gì cũng đc Hết hạn nhận chào giá
#
#
# Xây dựng Webapp + Mobile App Hết hạn nhận chào giá
#
#
# Tối ưu tốc độ load Website Wordpress Hết hạn nhận chào giá
#
#
# Hoàn thiện, làm đẹp Website Wordpress Hết hạn nhận chào giá
#
#
# Cần 1 bạn tối ưu SEO cho Website Funimart.vn Hết hạn nhận chào giá
#
#
# Thiết kế trang web cho Viện Khoa học hàng không Hết hạn nhận chào giá
#
#
# Addon Pet Cho Xenforo 2 Hết hạn nhận chào giá
#
#
# Cần thiết kế 1 loạt các template website và plugin wordpress Hết hạn nhận chào giá
#
#
# Xây dựng web app đơn giản với Django Hết hạn nhận chào giá
#
#
# Cần tinh chỉnh chức năng trên website Đã hoàn thành
#
#
# Cài đặt website bán hàng wordpress theo template Hết hạn nhận chào giá
#
#
# Làm phần back-end dùng nodejs và redis Hết hạn nhận chào giá
#
#
# Cần viết phần mềm tự động UP sản phẩm lên Website Hết hạn nhận chào giá
#
#
# Cần tìm coder web playtube và wowonder Đã hoàn thành
#
#
# Thiết kế website bán hàng (nhỏ - không thanh toán trực tuyến) Hết hạn nhận chào giá
#
#
# Cần 1 bạn làm Website bằng Reactjs Hết hạn nhận chào giá
#
#
# Dự Án Coffee work station Hết hạn nhận chào giá
#
#
# Thiết kế trang web bán hàng Hết hạn nhận chào giá
#
#
# Cần tìm người xây dựng website shopify Hết hạn nhận chào giá
#
#
# Tuyển React Native - Thêm chức năng maintain dự án Hết hạn nhận chào giá
#
#
# Hoàn thiện file excel theo yêu cầu- Đòi hỏi Trình độ tương đối cao Đã hoàn thành
#
#
# Làm tool auto đánh tài xỉu theo yêu cầu Hết hạn nhận chào giá
#
#
# Scrape và xử lý dữ liệu từ Reddit Đã hoàn thành
#
#
# Thiết kế trang web cho siêu thị Hết hạn nhận chào giá
#
#
# Tối ưu website và seo Hết hạn nhận chào giá
#
#
# SEO web Hết hạn nhận chào giá
#
#
# Viết Access Xuất Nhập Tồn Công nợ Lương NC Đã hoàn thành
#
#
# Website download video bilibili Hết hạn nhận chào giá
#
#
# Clone lại 1 website e - commerce đã có sẵn Hết hạn nhận chào giá
#
#
# Tạo 1 trang upload và import CSV vào MySQL bằng PHP Đã hoàn thành
#
#
#
# Hoàn thiện file excel theo yêu cầu- Đòi hỏi Trình độ tương đối cao Hết hạn nhận chào giá
#
#
# Viết tool auto đánh tài xỉu Hết hạn nhận chào giá
#
#
# Phát triển và bảo trì tiếp hệ thống website Hết hạn nhận chào giá
#
#
# Cần một bạn IOS, maintain app trên Ipad, rành về Object C và swift Hết hạn nhận chào giá
#
#
# Nhân viên SEO tại TPHCM Hết hạn nhận chào giá
#
#
# Extension chrome Hết hạn nhận chào giá
#
#
# LẬP TRÌNH WEB Hết hạn nhận chào giá
#
#
# Lập trình viên Hết hạn nhận chào giá
#
#
# Cần nhúng library pagination vào theme WordPress có sẵn Hết hạn nhận chào giá
#
#
# TUYỂN GIẢNG VIÊN PART-TIME CÁC KHOÁ LẬP TRÌNH Di ĐỘNG, WEBSITE Hết hạn nhận chào giá
#
#
# Extension chrome Hết hạn nhận chào giá
#
#
# Chuyển nội dung từ một Wordpress Webseite sang trang mới Hết hạn nhận chào giá
#
#
# Lập trình Liferay, cụ thể OpenCPS Hết hạn nhận chào giá
#
#
# Nâng cấp website mạng xã hội Hết hạn nhận chào giá
#
#
# MÌNH CẦN THUÊ 1 BẠN VIẾT TOOL MMO TELEGRAM Hết hạn nhận chào giá
#
#
# Dự án ngắn hạn 3 tháng, mảng thương mại điện tử. Lương upto 30M. Làm việc tại Timecity Hết hạn nhận chào giá
#
#
# Thiết kế trang kiểm tra tình trạng đơn hàng từ file PSD, AI Hết hạn nhận chào giá
#
#
# Tối ưu onpage theo cấu trúc silo cho website Hết hạn nhận chào giá
#
#
# Làm Mobile App đơn giản cho IOS và Android Hết hạn nhận chào giá
#
#
# Cấu hình tổng đài 3CX trên Google Cloud Hết hạn nhận chào giá
#
#
# Tạo Tool Sử Dụng API của DeepAI Đã hoàn thành
#
#
# Automation Tester/3 tháng - 6 tháng Hết hạn nhận chào giá
#
#
# Chỉnh sửa website wordpress Hết hạn nhận chào giá
#
#
# Thiết kế website công ty Dược Mỹ phẩm, không có bán hàng Hết hạn nhận chào giá
#
#
# Vietnet Hết hạn nhận chào giá
#
#
# SEO các từ khoá: Màng phủ nông nghiệp Màng quấn pallette / Màng quấn PE/ Màng co Hết hạn nhận chào giá
#
#
# LÀM APP IOS VÀ UP LÊN App Store Hết hạn nhận chào giá
#
#
# MÌNH CẦN THUÊ 1 BẠN VIẾT TOOL MMO TELEGRAM Hết hạn nhận chào giá
#
#
# Kết nối dữ liệu tới getfly Đã hoàn thành
#
#
# Cần phần mềm download videos từ tiktok Hết hạn nhận chào giá
#
#
# Xây dựng 1 app có chức năng phiên dịch. Hết hạn nhận chào giá
#
#
# Tái hiện bảng giá chứng khoán Hết hạn nhận chào giá
#
#
# Thực hiện maintenance và develop chức năng cho site hiện tại Hết hạn nhận chào giá
#
#
# Thiết kế trang web bán hàng cao cấp Hết hạn nhận chào giá
#
#
# App bán sách đơn gian trên ios Hết hạn nhận chào giá
#
#
#
# Cắt HTML/CSS từ file XD Hết hạn nhận chào giá
#
#
# Sửa email template cho wordpress plugin wphotelier Hết hạn nhận chào giá
#
#
# Tuyển Free lancer Lập trình Tính năng tự động tạo Password cho File Hết hạn nhận chào giá
#
#
# Hà Nội - Senior Full Stack Java developer Hết hạn nhận chào giá
#
#
# Kết nối Web server với Facebook Messenger bằng webhook + API. Tạo chrome extensions để user call API Hết hạn nhận chào giá
#
#
# Xây dựng mobile app bằng Ionic (ReactJS) Hết hạn nhận chào giá
#
#
# Senior web developer sử dụng .net, react, angular, js, node Hết hạn nhận chào giá
#
#
# Phát triển web app bất động sản dùng 1 trong tech sau: node, .net, angular, react, javascript Hết hạn nhận chào giá
#
#
# Điều chỉnh thiết kế 3 Website Đã hoàn thành
#
#
# Thiết kế website bán hàng cao cấp Hết hạn nhận chào giá
#
#
# Tuyển lập trình viên Hết hạn nhận chào giá
#
#
# Cần cắt HTML/CSS từ file XD Hết hạn nhận chào giá
#
#
# UX/UI Hết hạn nhận chào giá
#
#
# Mình cần Rip theme wordpress Đã hoàn thành
#
#
# Thiết kế App điều khiển, Website giám sát thiết bị theo mô hình SCADA Hết hạn nhận chào giá
#
#
# Thiết kế trang website bán hàng cao cấp Hết hạn nhận chào giá
#
#
# Sửa giao diện website tin tức nền tảng wordpress Hết hạn nhận chào giá
#
#
# Lập trình Web Application Laravel và MongoDB Hết hạn nhận chào giá
#
#
# Thiết kế website dịch vụ, kèm theo thanh toán thẻ tín dụng quốc tế dùng Wordpress. Hết hạn nhận chào giá
#
#
# Làm website WordPress y nguyên mẫu Hết hạn nhận chào giá
#
#
# Cần người thiết kế web quản lý nhiều nhà hàng theo yêu cầu Hết hạn nhận chào giá
#
#
# Tracking link cho landing page của website Hết hạn nhận chào giá
#
#
# Senior Wordpress Developer Hết hạn nhận chào giá
#
#
# Senior Wordpress Developer Hết hạn nhận chào giá
#
#
# Khắc phục lỗi VPS, tối ưu VPS Hết hạn nhận chào giá
#
#
# Thiết kế app giống dịch vu người giúp việc Hết hạn nhận chào giá
#
#
# React Native/ Typescript Developer Hết hạn nhận chào giá
#
#
# App thực đơn nhà hàng Hết hạn nhận chào giá
#
#
# Chức Năng Tạo Tài Khoản, Đăng Tin Sử Dựng Wordpress Hết hạn nhận chào giá
#
#
# Thiết kế website quản lý thiết bị Hết hạn nhận chào giá
#
#
# [Hà Nội] Cần tim freelancer React Native Hết hạn nhận chào giá
#
#
# Senior Python developer tại Hà Nội Hết hạn nhận chào giá
#
#
# Điều chỉnh thiết kế Website cho thẩm mỹ hơn Hết hạn nhận chào giá
#
#
# Thiết kế website cá cược gà mạng Hết hạn nhận chào giá
#
#
# Lập trình ứng dụng OTT trên WebOS (Tivi LG), Tizen (Tivi Samsung) Hết hạn nhận chào giá
#
#
# Chỉnh sửa Woocomerce Email theo Product ID Hết hạn nhận chào giá
#
#
# Build app ios Hết hạn nhận chào giá
#
#
# Tìm người có sẵn 50 địa chỉ gmail khác nhau Đã hoàn thành
#
#
# Quản trị web và tối ưu seo để bán hàng Hết hạn nhận chào giá
#
#
# Làm ứng dụng flutter thiết kế có sẵn Hết hạn nhận chào giá
#
#
# Lập trình nhúng linux cho switch Hết hạn nhận chào giá
#
#
# Tạo trang website blog Hết hạn nhận chào giá
#
#
# Chuyển template trang sản phẩm lên web có sẵn Hết hạn nhận chào giá
#
#
# Java Script Developer *** PARTTIME & cơ hội làm việc lâu dài *** Hết hạn nhận chào giá
#
#
# Nâng cấp hệ thống GSM Hết hạn nhận chào giá
#
#
# Web WP, có thêm Form liên hệ nhỏ Hết hạn nhận chào giá
#
#
# Tìm Thông Tin Trên Mạng và Nhập Dữ Liệu vào File Excel Hết hạn nhận chào giá
#
#
# Thiết kế trang web có CMS với ASP.net Hết hạn nhận chào giá
#
#
# Tái hiện bảng giá chứng khoán Hết hạn nhận chào giá
#
#
# Một tool nhỏ dạng web Hết hạn nhận chào giá
#
#
# Website mua bán Sim Hết hạn nhận chào giá
#
#
# Tuyển dụng UI/UX Hết hạn nhận chào giá
#
#
# Lập trình Web Hết hạn nhận chào giá
#
#
# Làm app casino theo yêu cầu Hết hạn nhận chào giá
#
#
# Thiết kế trang bán hàng có kết nối với kiotviet Hết hạn nhận chào giá
#
#
# Java Script Developer ** PARTTIME ** Hết hạn nhận chào giá
#
#
#
# App bán sách đơn gian trên ios Hết hạn nhận chào giá
#
#
#
# Mod app game có thể chơi được trên giả lập Hết hạn nhận chào giá
#
#
# Lấy direct link google photos Hết hạn nhận chào giá
#
#
# Clone app game Hết hạn nhận chào giá
#
#
# Tuyển dụng lập trình viên PHP Hết hạn nhận chào giá
#
#
# Tôi cần thiết kế diễn đàn forum Hết hạn nhận chào giá
#
#
# Hoàn thành app reactnative về odoo Hết hạn nhận chào giá
#
#
# Cần bạn chuyên về php api facebook Hết hạn nhận chào giá
#
#
# Tìm người viết một trang web liên quan đến bất động sản Hết hạn nhận chào giá
#
#
# Tôi cần thiết kế diễn đàn forum Hết hạn nhận chào giá
#
#
# Cấu hình trang wordpress thành landingpage cho đại lý + khách đặt hàng qua google sheet Hết hạn nhận chào giá
#
#
# PHP Quản lý kênh bán phòng khách sạn (OTA) Hết hạn nhận chào giá
#
#
# Phát triển hệ thống BSC và KPI nội bộ công ty Hết hạn nhận chào giá
#
#
# Customize template đã mua thành website hoàn chỉnh - Wordpress & SiteGround Hết hạn nhận chào giá
#
#
# Cần tuyển coder xây dựng web cho thuê code otp online Hết hạn nhận chào giá
#
#
# Thiết kế giao diện + cắt html, css Web Tin Tức Hết hạn nhận chào giá
#
#
# Viết woocommerce plugin cho phép filter product Hết hạn nhận chào giá
#
#
# Chuyển thiết kế website Ladon có sẵn qua Wordpress Đã hoàn thành
#
#
# Tìm Freelancer lập trình theo dự án ngắn hạn Hết hạn nhận chào giá
#
#
#
# PHP, LARAVEL, ARDROID, APP, C#, ,,,,,, làm theo dự án Hết hạn nhận chào giá
# FANPAGE
#
#
#
# Xây dựng Dashboard - Web App theo template có sẵn Hết hạn nhận chào giá
#
#
# Chuyển thiết kế website có sẵn qua Wordpress Hết hạn nhận chào giá
#
#
# Làm và tối ưu Blogspot, site.google, free.wordpress Hết hạn nhận chào giá
#
#
# Crawling dữ liệu cho website Wordpress Hết hạn nhận chào giá
#
#
# Seo website Hết hạn nhận chào giá
#
#
# PHP, LARAVEL, ARDROID, APP, C#, ,,,,,, làm theo dự án Hết hạn nhận chào giá
#
#
#
# Tìm người có thể thay đổi config của ứng dụng đang bị giới hạn sử dụng Hết hạn nhận chào giá
#
#
# Viết phần mềm bán hàng - quản lý tồn kho Hết hạn nhận chào giá
#
#
# Phát triển phần mềm quản lý nhân sự và tính lương. Hết hạn nhận chào giá
#
#
# Tìm người thiết kế website cash back Hết hạn nhận chào giá
#
#
# Cần tìm người Clone lại Website vonvon hoặc zenquiz Hết hạn nhận chào giá
#
#
# Tìm Thông Tin Trên Mạng và Nhập Dữ Liệu vào File Excel Hết hạn nhận chào giá
#
#
# Làm web theo ý tưởng Hết hạn nhận chào giá
#
#
# Phân biệt cảm xúc tiếng Việt Hết hạn nhận chào giá
#
#
# Cần gấp người làm HTML/CSS cho website Hết hạn nhận chào giá
#
#
# Thiết kế web học online Hết hạn nhận chào giá
#
#
# Business Analyst Hết hạn nhận chào giá
#
#
# SEO onsite, offsite, backlink, SEO content Hết hạn nhận chào giá
#
#
# Lập trình Web bằng ngôn ngữ C# ASP Net MVC Hết hạn nhận chào giá
#
#
# Amazon Price Tracker Đã hoàn thành
#
#
# Thiết kế website dựa trên website mẫu Hết hạn nhận chào giá
#
#
# Thiết kế web bán hàng online cho tiệm cà phê. Hết hạn nhận chào giá
#
#
# App đặt xe taxi như Grab Hết hạn nhận chào giá
#
#
# Cấu hình chiến dịch cho KDN và xử lý dữ liệu Đã hoàn thành
#
#
# Đồng hành cùng nhau nhé, các Start Up UNITY DEVELOPERS tương lai Hết hạn nhận chào giá
#
#
# Thiết kế giao diện website và app mobile cho ứng dụng Hết hạn nhận chào giá
#
#
# Business Analyst - Freelancer fulltime 2-3 tháng Hết hạn nhận chào giá
#
#
#
# Thiết kế Website bán hàng Wordpress chuẩn SEO Hết hạn nhận chào giá
#
#
# Thiết kế app bán hàng dựa trên website có sẵn Hết hạn nhận chào giá
#
#
# Thiết kế giao diện và cắt html, css Hết hạn nhận chào giá
#
#
# Thiết kế ứng dụng cho website thương mại điện tử Hết hạn nhận chào giá
#
#
# Seo website về dịch vụ hosting, server, vps, cloud, thuê máy chủ, thuê chỗ đặt. Hết hạn nhận chào giá
#
#
# Thiết kế website bán hàng online Hết hạn nhận chào giá
#
#
# Xây dựng phần mềm tự động tương tác livestream thông qua máy ảo Android. Hết hạn nhận chào giá
#
#
# Cần đội cung cấp website tương tự luxstay, agoda Hết hạn nhận chào giá
#
#
# Thay đổi logo và các images trong file APK Hết hạn nhận chào giá
#
#
# App bán sách trên ios Hết hạn nhận chào giá
#
#
# Convert mảng PHP Hết hạn nhận chào giá
#
#
# App thuê xe máy ios và android Hết hạn nhận chào giá
#
#
# Seo webiste Hết hạn nhận chào giá
#
#
# Dựng website đăng bài viết chia sẻ kiến thức Hết hạn nhận chào giá
#
#
# Thiết kế website get files ảnh từ freepik, pngtree, motionarray Hết hạn nhận chào giá
#
#
# Viết wordpress plugin cho phép người bán hiển thị custom fields Hết hạn nhận chào giá
#
#
# Làm app android chỉ là shortcut mở link website Đã hoàn thành
#
#
# Cần người leech sản phẩm cho website woocommerce Đã hoàn thành
#
#
# Làm Mobile App đơn giản cho IOS Hết hạn nhận chào giá
#
#
# Cần code chức năng nhận cuộc gọi trên GSM Hết hạn nhận chào giá
#
#
# Thiết kế trang web đặt hàng cho ctv Hết hạn nhận chào giá
#
#
# Scrapte data - Trích xuất dữ liệu sản phẩm (https://www.vitalitymedical.com/) Hết hạn nhận chào giá
#
#
# Phần mềm điều khiển nhiều thiết bị điện thoại Android từ máy tính, tương tác Facebook, lướt web, xem video... Hết hạn nhận chào giá
#
#
# So sánh, đánh giá phần mềm ERP của doanh nghiệp. Hết hạn nhận chào giá
#
#
# Back Link chất lượng về trang URL Hết hạn nhận chào giá
#
#
# Viết Demo đăng bài lên facebook bằng webview Android Hết hạn nhận chào giá
#
#
# Phần mềm quản lý bán hàng và tồn kho Hết hạn nhận chào giá
#
#
# Web chat bằng mongodb, nodejs có realtime socketio Hết hạn nhận chào giá
#
#
# Viết chức năng lưu ảnh game j2me Hết hạn nhận chào giá
#
#
# Cần người clone tính năng website theo yêu cầu Đã hoàn thành
#
#
# Phần mềm quản ly giao tiếp thiết bị thẻ từ Hết hạn nhận chào giá
#
#
# Cần tìm lập trình viên làm freetime Hết hạn nhận chào giá
#
#
#
# Zalo Pay Web Component Hết hạn nhận chào giá
#
#
# Tạo bot gửi tin nhắn tự động zalo- telegram Hết hạn nhận chào giá
#
#
# Tuyển sinh viên java, .Net mới ra trường Hết hạn nhận chào giá
#
#
# Lập trình trang web cửa hàng Nail+Spa Hết hạn nhận chào giá
#
#
# Kết nối cổng thanh toán Paypal cho web bán hàng Hết hạn nhận chào giá
#
#
# Làm website bán hàng trên wordpress Hết hạn nhận chào giá
#
#
# Tuyển Free lancer lập trình nhận diện ký tự Tiếng Việt Hết hạn nhận chào giá
#
#
# Cần viết macro tự động đăng nhập vào nhiều web và thực hiện thao tác trên Chrome Firefox Hết hạn nhận chào giá
#
#
# Dựng website bán hàng gỗ xuất khẩu Hết hạn nhận chào giá
#
#
# Tìm Freelancer lập trình theo dự án Hết hạn nhận chào giá
# FANPAGE
#
#
#
# Tìm Freelancer lập trình theo dự án Hết hạn nhận chào giá
# FANPAGE
#
#
#
# Viết woocommerce plugin cho phép người bán hiển thị custom fields Hết hạn nhận chào giá
#
#
# Cần viết code lấy dữ liệu xuất ra từ website UPS Đã hoàn thành
#
#
# Cần người viết Plugin tính giá theo yêu cầu Hết hạn nhận chào giá
#
#
# Chuyển Add to cart site thành dạng subscribe SAAS model. Hết hạn nhận chào giá
#
#
# Dev Wordpress - Dự án cần Dev có kinh nghiệm làm code theme, plugins Hết hạn nhận chào giá
#
#
# Làm ứng dụng đọc truyện đơn giản và có thể đưa lên AppStore Hết hạn nhận chào giá
#
#
# Tuyển nhân viên seo web của công ty Hết hạn nhận chào giá
#
#
# Tìm hiểu thuật toán/logic của Survey Hết hạn nhận chào giá
#
#
# TK Web tích hợp cổng thanh toán Paypal, Stripe, Skrill Hết hạn nhận chào giá
#
#
#
# Thiết kế website truyện chữ tương tự truyenfull.vn Đã hoàn thành
#
#
# Cần viết tool post bài lên fanpage facebook Hết hạn nhận chào giá
#
#
# Cần viết tool post bài lên fanpage facebook Hết hạn nhận chào giá
#
#
# Thêm và chỉnh sửa ứng dụng đặt sân banh Hết hạn nhận chào giá
#
#
# Thêm, chỉnh sửa ứng dụng đặt sân thể thao Hết hạn nhận chào giá
#
#
# Cần tuyền Freelancer cho dự án app React Native Hết hạn nhận chào giá
#
#
# Lập trình Game Tài xỉu & Slot Hết hạn nhận chào giá
#
#
# Tối ưu seo website Hết hạn nhận chào giá
#
#
# Thuê getlink youtube private Hết hạn nhận chào giá
#
#
# Thiết kế 5 web so sánh, bằng wordpress Hết hạn nhận chào giá
#
#
# Phần mềm quản lí kết quả xét nghiệm Hết hạn nhận chào giá
#
#
# TUYỂN DỤNG NHÂN VIÊN SEO MARKETING Hết hạn nhận chào giá
#
#
# Thêm, chỉnh sửa ứng dụng đặt sân thể thao Hết hạn nhận chào giá
#
#
# Làm page thanh toán cho web wordpress dùng woocommerce Hết hạn nhận chào giá
#
#
# Thiết kế và xây dựng website Hết hạn nhận chào giá
#
#
# Xây dựng Ứng dụng du lịch thông minh trên nền tảng IOS / Android Hết hạn nhận chào giá
#
#
# Xây dựng backend cho Ứng dụng di động Hết hạn nhận chào giá
#
#
# Viết app lấy toàn bộ notification của android bằng react native Hết hạn nhận chào giá
#
#
# Cần decode pass từ code web sẵn Hết hạn nhận chào giá
#
#
# Làm 1 App chát với tính năng cơ bản trên iOS và Android Hết hạn nhận chào giá
#
#
# Sửa code web về hỗ trợ hiển thị trên hệ điều hành ios Hết hạn nhận chào giá
#
#
# [ NodeJS - MongoDB + PHP - MySQL ] Chuyển Code PHP => NodeJS Hết hạn nhận chào giá
#
#
# Cần freelancer làm Dự án số hóa bản đồ Hết hạn nhận chào giá
#
#
# Lấy access_token của shopee Hết hạn nhận chào giá
#
#
# Cần lập trình game bắn cá H5 Hết hạn nhận chào giá
#
#
# Viết code nhận dạng chữ số và chạy lệnh. Hết hạn nhận chào giá
#
#
# Thiết kế website cho nhà hàng Hết hạn nhận chào giá
#
#
# Thiết kế web app booking hotel tour... Hết hạn nhận chào giá
#
#
# Mình cần một bạn setup dùm mình React Native Hết hạn nhận chào giá
#
#
# Tối ưu SEO cho trang web Hết hạn nhận chào giá
#
#
# Tuyển Dụng Lập Trình Viên PHP (Hợp Đồng 3 tháng) Hết hạn nhận chào giá
#
#
# Xử lý dữ liệu liên quan đến API như gửi sms qua twilio, stripe, hoặc epson sdk Hết hạn nhận chào giá
#
#
# Cần thuê để đưa app lên app store Hết hạn nhận chào giá
#
#
# Cần xác minh API Messenger Facebook app Hết hạn nhận chào giá
#
#
# SEO và fix lỗi seo cho website hiện có + xây dựng trang mới Hết hạn nhận chào giá
#
#
# Làm app đọc truyện chữ Đã hoàn thành
#
#
# Addons mua hàng chrome Hết hạn nhận chào giá
#
#
# Thực hiện dự án app react native trọn gói Hết hạn nhận chào giá
#
#
# Xây dựng hồ sơ dự thầu Hết hạn nhận chào giá
#
#
# Tuyển lập trình web trên wordpress Hết hạn nhận chào giá
#
#
# Quản trị web, fanpage, TMDT Hết hạn nhận chào giá
#
#
# Thực Tập Sinh SEO Web Hết hạn nhận chào giá
#
#
# Tạo REST API từ website wordpress Hết hạn nhận chào giá
#
#
# Viết hàm javascript chuyển hệ tọa độ từ VN2000 sang lat,long Hết hạn nhận chào giá
#
#
# Thiết kế trang web thông tin doanh nghiệp Hết hạn nhận chào giá
#
#
# Cần tuyển freelancer Cài đặt ứng dụng web-apps trên Linux Đã hoàn thành
#
#
# Thêm chức add to cart Đã hoàn thành
#
#
# Chuyển Template về website đã có php sẵn Hết hạn nhận chào giá
#
#
# Trang web quán ăn, cho phép người dùng đặt món, và chủ quán quản lí nguyên liệu tồn kho Hết hạn nhận chào giá
#
#
# Nâng cấp nền tảng website ASP.NET Đã hoàn thành
#
#
# Mid/Senior Full stack developer (Laravel, Vue, Tailwind) Hết hạn nhận chào giá
#
#
#
# Tuyển Freelancer code quy trình bán hàng và thêm cổng thanh toán Payoo Hết hạn nhận chào giá
#
#
# Thiết kế phần mềm quản lý thư viện trường học Hết hạn nhận chào giá
#
#
# Plugin của EC-Cube 4 Hết hạn nhận chào giá
#
#
# Tuyển 2 Go devs freelance cho dự án với khách hàng Nhật Hết hạn nhận chào giá
#
#
# Tuyển 2 Go devs freelance cho dự án với khách hàng Nhật Hết hạn nhận chào giá
#
#
# Tuyển 2 React frontend devs freelance cho dự án với khách hàng Nhật Hết hạn nhận chào giá
#
#
# Tuyển 2 React frontend devs freelance cho dự án với khách hàng Nhật Hết hạn nhận chào giá
#
#
# Tuyển 2 Node.js backend devs freelance cho dự án với khách hàng Nhật Hết hạn nhận chào giá
#
#
# Tuyển 3 Java/Spring devs freelance cho dự án với khách hàng Nhật Hết hạn nhận chào giá
#
#
# Làm landing page cho sản phẩm B2B dựa trên theme wordpress Hết hạn nhận chào giá
#
#
# Tuyển Project Manager Shopify Hết hạn nhận chào giá
#
#
# Cần làm website wordpress đã có sẵn PSD Hết hạn nhận chào giá
#
#
# Cần 1 Bạn Tối Ưu Tốc Độ Load trang + 1 vài yêu cầu nhỏ Hết hạn nhận chào giá
#
#
# Tuyển 2 Node.js backend devs freelance cho dự án với khách hàng Nhật Hết hạn nhận chào giá
#
#
# Tuyển 3 Java/Spring devs freelance cho dự án với khách hàng Nhật Hết hạn nhận chào giá
#
#
# Cắt trang home page Hết hạn nhận chào giá
#
#
# Viết app trên điện thoại Hết hạn nhận chào giá
#
#
# Thực thi manual test mobile app, chỉnh sửa test case Hết hạn nhận chào giá
#
#
# Thiết kế giao diện Website Hết hạn nhận chào giá
#
#
# SEO Website Hết hạn nhận chào giá
#
#
# Demo post notification use firebase Hết hạn nhận chào giá
#
#
# Code app web Hết hạn nhận chào giá
#
#
# Cần tuyển Freelancer Part-time Angular developer - Mobile and Web application Hết hạn nhận chào giá
#
#
# Tuyển cộng tác viên làm outsource wordpress, công việc đều dặn theo tháng Hết hạn nhận chào giá
#
#
# Tuyển 3 Vue.js front-end dev freelance cho dự án với khách hàng Nhật Hết hạn nhận chào giá
#
#
# Tuyển 3 Vue.js front-end dev freelance cho dự án với khách hàng Nhật Hết hạn nhận chào giá
#
#
# Cần 1 bạn SEO cho website xland.biz Hết hạn nhận chào giá
#
#
# React Native Mobile App Hết hạn nhận chào giá
#
#
# Lập trình giao diện (HTML/CSS/JS) trên mẫu có sẵn Hết hạn nhận chào giá
#
#
# Viết code cho một số hạng mục của website Hết hạn nhận chào giá
#
#
# Looking for senior mobile app developers Hết hạn nhận chào giá
#
#
# Coder Hết hạn nhận chào giá
#
#
# Hoàn thiện phần mềm bán hàng Hết hạn nhận chào giá
#
#
# Thiết kế và phát triển website xổ số Hết hạn nhận chào giá
#
#
# Thiết kế web theo mẫu Hết hạn nhận chào giá
#
#
# Code web joomla Hết hạn nhận chào giá
#
#
# Thiết kế cổng game bài Hết hạn nhận chào giá
#
#
# Hiển thị dữ liệu liên quan khách hàng lên odoo Đã hoàn thành
#
#
# Tôi cần một tool auto thao tác trên trình duyệt web theo kịch bản và data có sẵn Hết hạn nhận chào giá
#
#
# Cần Developer rành Python, Django cả front và backend (Không nhận team hoặc công ty) Hết hạn nhận chào giá
#
#
# Đọc tin tức trên android Hết hạn nhận chào giá
#
#
# Drcom - 6 website update Hết hạn nhận chào giá
#
#
# Cần thuê Freelancer: Decompile apk của app ViettelPay Pro lấy giúp mình API quan trọng Hết hạn nhận chào giá
#
#
# Cần tuyển Freelancer PHP Laravel (Angular + Postgres) Hết hạn nhận chào giá
#
#
#
# Cần thiết kế Web Bất Động Sản Hết hạn nhận chào giá
#
#
# [HCM] [IT help Desk Freelancer][paid for hours] Hết hạn nhận chào giá
#
#
# Cần chuyển phần mềm viết XP chạy được trên Windows 10 [GAP] Hết hạn nhận chào giá
#
#
# Tuyển Freenlancer cho một số hạng mục của website Hết hạn nhận chào giá
#
#
# Làm website bán hàng (nội thất) - làm giống 1 trang nội thất trên mạng Đã hoàn thành
#
#
# Tìm web developer làm công việc freelance part-time. Hết hạn nhận chào giá
#
#
# Cần thuê freelancer tối ưu SEO- Onpage cho webiste lamgiau247.com Hết hạn nhận chào giá
#
#
# CONTENT MARKETING (COPY WRITER) Hết hạn nhận chào giá
#
#
# Tool Crawl Trang Sản Phẩm Của Web Store Hết hạn nhận chào giá
#
#
# Mình cần code app lấy dữ liệu website về google sheet Hết hạn nhận chào giá
#
#
# Web Game Bài - Đổi thưởng Hết hạn nhận chào giá
#
#
#
# Cần tuyển Freelancer Cài đặt Oracle database RAC Hết hạn nhận chào giá
#
#
# Tuyển Freelancer code quy trình bán hàng và thêm cổng thanh toán Payoo Hết hạn nhận chào giá
#
#
# Crawl tool Hết hạn nhận chào giá
#
#
# Hệ thống login tự động vượt captcha Hết hạn nhận chào giá
#
#
# Cần thiết kế web PHP về trung tâm đào tạo Tiếng Anh Hết hạn nhận chào giá
#
#
# Crack ứng dụng Hết hạn nhận chào giá
#
#
# Thiết kế mobile app theo yêu cầu. Hết hạn nhận chào giá
#
#
# Gia sư lập trình Python Hết hạn nhận chào giá
#
#
# Thiết kế Web cho công ty xây dựng Hết hạn nhận chào giá
#
#
# Nhập dữ liệu website Hết hạn nhận chào giá
#
#
# Payment gateway cho website Hết hạn nhận chào giá
#
#
# [ C# or Nodjs or Java or Autoit ] Kiểm tra email gmx và web.de xem coi đã tồn tại hay chưa Hết hạn nhận chào giá
#
#
# Tạo địa điểm trên Google Maps cho 2 cửa hàng Hết hạn nhận chào giá
#
#
# Thiết kế ứng dụng thanh toán nhà hàng trên Android và iPhone Hết hạn nhận chào giá
#
#
# Viết Blazor App để thi trắc nghiệm Đã hoàn thành
#
#
# Lập trình game bầu cua online Hết hạn nhận chào giá
#
#
# Hoan thien Web To chuc Tour Hết hạn nhận chào giá
#
#
# Thiết kê website wordpress download data Đã hoàn thành
#
#
# Tuyển lập trình viên Shopify Hết hạn nhận chào giá
#
#
# Làm website bán hàng (nội thất) - làm giống 1 trang nội thất trên mạng Đã hoàn thành
#
#
# Viết chương trình nhập xuất thu chi hàng tồn Hết hạn nhận chào giá
#
#
# Cần IT fix một số lỗi và code trong checklist trên website Hết hạn nhận chào giá
#
#
# Thiết kế website bán khẩu trang y tế Hết hạn nhận chào giá
#
#
# Lập trình mobile app sử dụng React Native Hết hạn nhận chào giá
#
#
# Cần tìm coder web live stream Hết hạn nhận chào giá
#
#
# PHP Hết hạn nhận chào giá
#
#
# Magento Developer Needed Hết hạn nhận chào giá
#
#
# Cần tuyển Freelancer: [ECM]Thiết kế tool quản lý Thay đổi BOM Hết hạn nhận chào giá
#
#
# Close Hết hạn nhận chào giá
#
#
# Lập trình winform (C#, SQL) Hết hạn nhận chào giá
#
#
# Lập trình Website fulltime tại Đà Nẵng Hết hạn nhận chào giá
#
#
# Chỉnh sửa phần mềm mã nguồn mở veracrypt Đã hoàn thành
#
#
# Lập trình Javascript/PHP để tích hơp Google Tag Manager trên Frontend Hết hạn nhận chào giá
#
#
# [ NodeJS + MongoDB ] Chia Task Cho Users Hết hạn nhận chào giá
#
#
# Wordpress Landingpage + Blogs Đã hoàn thành
#
#
# Xây dựng trang thương mại điện tử Hết hạn nhận chào giá
#
#
# Cần người (Cá nhân - ko nhận team hoặc công ty) thiết kế website wordpres Hết hạn nhận chào giá
#
#
# Thuê người reskin 10 trò chơi 3D Unity Hết hạn nhận chào giá
#
#
# Hiển thị báo cáo thông qua canvas Hết hạn nhận chào giá
#
#
# Viết chương trình cho thuật toán sinh số nguyên tố của MAURER Hết hạn nhận chào giá
#
#
# Tìm người code bot forex Hết hạn nhận chào giá
#
#
# Chỉnh sửa kết nối API Bitrix 24 - Haravan Hết hạn nhận chào giá
#
#
# Tuyển PHP Developer Hết hạn nhận chào giá
#
#
# Tích hợp giao hàng nhanh, giao hàng tiết kiệm vào web rao vặt thương mại điện tử Hết hạn nhận chào giá
#
#
# Scrape Thông Tin Sản Phẩm từ Amazon Hết hạn nhận chào giá
#
#
# Fix bug ios và android publish lên app store Hết hạn nhận chào giá
#
#
# Part-time project developer Hết hạn nhận chào giá
#
#
# Phần mềm quản lý tài khoản, đăng sản phẩm trên shopee Hết hạn nhận chào giá
#
#
# Cần Tuyển PHP Developer làm việc Online Hết hạn nhận chào giá
#
#
# React programmer Hết hạn nhận chào giá
#
#
# Lập trình game Hết hạn nhận chào giá
#
#
# Tuyển Freelancer code quy trình bán hàng và thêm cổng thanh toán Payoo Đã hoàn thành
#
#
# Thiết Kế Trang Web Bán Hàng Cơ Bản Hết hạn nhận chào giá
#
#
# Cần freelancer thiết kế wordpress theo yêu cầu Hết hạn nhận chào giá
#
#
# CÔNG CỤ ĐỌC DỮ LIỆU ẢNH TRONG THƯ MỤC RỒI UP LÊN CLOUD. Hết hạn nhận chào giá
#
#
# API check ACH in plaid Hết hạn nhận chào giá
#
#
#
# Submit form tự động ngay khi trang được load Hết hạn nhận chào giá
#
#
# Lập trình web xem thống kê báo cáo Hết hạn nhận chào giá
#
#
# Mình người code game bài Hết hạn nhận chào giá
#
#
# Thiết kế web stream bóng đá trực tuyến Hết hạn nhận chào giá
#
#
# Thiết kế game bắn cá, nổ hủ Hết hạn nhận chào giá
#
#
# Buyer's Guide Hết hạn nhận chào giá
#
#
# Tuyển dụng front end angular 9 bán thời gian Hết hạn nhận chào giá
#
#
# Làm một bản hack game GTA sever gta5vn.com Hết hạn nhận chào giá
#
#
#
# Viết tool giả lập người dùng đăng tin Hết hạn nhận chào giá
#
#
# Phát Triển trang web giống croxyproxy Hết hạn nhận chào giá
#
#
# API thanh toán Cybersource Hết hạn nhận chào giá
#
#
#
# Viết JavaScript cho Adobe illustrator để export tọa độ đối tượng vẽ ra file text Đã hoàn thành
#
#
# Nhập dữ liệu và tối ưu SEO web Hết hạn nhận chào giá
#
#
# [Python] Xây dựng chức năng Xử lý ảnh Hết hạn nhận chào giá
#
#
# Front-end Dev Hết hạn nhận chào giá
#
#
# Cần làm 1 landingpage trên nền tảng ladipage theo mẫu có sẵn (y nguyên, chỉ thay nội dung) Hết hạn nhận chào giá
#
#
# Tìm và loại bỏ đoạn mã độc trong trang web. Hết hạn nhận chào giá
#
#
# Nhúng mã tag Google Analytics và Facebook Pixel vào template website Đã hoàn thành
#
#
# Làm thêm tính năng friend list, chat cho game Action RPG online có sẵn, làm lâu dài Hết hạn nhận chào giá
#
#
# Viết phần mềm đăng ký thành viên, quản lý doanh thu và hệ thống nhập hàng cho công ty mỹ phẩm Hết hạn nhận chào giá
#
#
# Tuyển 3 Vue.js front-end dev freelance cho dự án với khách hàng Nhật Hết hạn nhận chào giá
#
#
# Tiếp tục tuyển 3 iOS devs freelance cho dự án với khách hàng Nhật Hết hạn nhận chào giá
#
#
# Tiếp tục tuyển 2 iOS devs freelance cho dự án với khách hàng Nhật Hết hạn nhận chào giá
#
#
# Mình cần chỉnh sửa header và menu cho giao diện mobile Hết hạn nhận chào giá
#
#
# Tự động giao dịch Hết hạn nhận chào giá
#
#
# Tuyển freelancer làm SEO off-page Hết hạn nhận chào giá
#
#
# ASP.net project Hết hạn nhận chào giá
#
#
# Web Master Hết hạn nhận chào giá
#
#
# Cần người chỉnh sửa Odoo Hết hạn nhận chào giá
#
#
# Onpage SEO/ Optimize cho 1 website có sẵn + thêm 1 page service trên wordpress Hết hạn nhận chào giá
#
#
# Cần tìm người dựng một website bán hàng về sản phẩm viên đặt phụ khoa dành cho nữ giới Hết hạn nhận chào giá
#
#
# Mình cần 01 team lập trình web cho Start up dạy tiếng Anh Hết hạn nhận chào giá
#
#
# Cần 1 bạn viết module auth + profile cho template có sẵn cho react native Hết hạn nhận chào giá
#
#
# Code API auto addfund Vietcombank, Vietinbank, techcombank Hết hạn nhận chào giá
#
#
# Thiết kế website bất động sản Hết hạn nhận chào giá
#
#
# Viết phần mềm quản lý nhân viên Đã hoàn thành
#
#
# Tìm coding cho web đã có sẵn design. Code trên nền tảng haravan hoặc sapo Hết hạn nhận chào giá
#
#
# Tối ưu nginx php-fpm cho download website Hết hạn nhận chào giá
#
#
# Thiết kế app phúc lợi cho nhân viên Hết hạn nhận chào giá
#
#
# Lập trình Web .Net MVC Hết hạn nhận chào giá
#
#
# Cần thuê freelancer có Kinh nghiệm làm việc với Google Tag Manager and Firebase Hết hạn nhận chào giá
#
#
# [React Native] VOIP App - Kết nối với tổng đài Mobifone 3C Hết hạn nhận chào giá
#
#
# Lập trình phần mềm quản lý thông tin khách sạn Hết hạn nhận chào giá
#
#
# Thiết kế web wordpress Hết hạn nhận chào giá
#
#
# Thiết kế app bán cafe mang đi Hết hạn nhận chào giá
#
#
# Dự án làm Ionic 3, REST API PHP Hết hạn nhận chào giá
#
#
# Viết Tool Lấy Tín Hiệu Từ Sàn Binance Chuyển Tới Telegram Hết hạn nhận chào giá
#
#
# Thiết kế Mobile App Flutter - Giao hàng Hết hạn nhận chào giá
#
#
# Đăng tin thử thôi Hết hạn nhận chào giá
#
#
# Lập trình tính năng thành viên cho website bán hàng Hết hạn nhận chào giá
#
#
# Cần 2 bạn có kinh nghiệm làm Ionic 3, REST API PHP Hết hạn nhận chào giá
#
#
# Project làm website cung cấp dịch vụ nhà ở Đã hoàn thành
#
#
#
# Web / app bán hàng, kết nối dịch vụ Hết hạn nhận chào giá
#
#
# Quản lý kho hàng Hết hạn nhận chào giá
#
#
# Tối ưu hóa website và chạy quảng cáo Hết hạn nhận chào giá
#
#
# Xây dựng App cho di động Hết hạn nhận chào giá
#
#
# Thiết kế và viết Mobile App cho website Hết hạn nhận chào giá
#
#
# Tùy biến plugin export/import mặc định của Wordpress Đã hoàn thành
#
#
# Tool lọc Kênh Youtube có Fan page Facebook và không có Fan page Hết hạn nhận chào giá
#
#
# Thiết kế phần mềm thao tác chrome theo kịch bản Hết hạn nhận chào giá
#
#
# Thiết kế Blog tiếng anh Hết hạn nhận chào giá
#
#
# Dựng app Hết hạn nhận chào giá
#
#
# Cần tuyển 2 freelancer laravel Hết hạn nhận chào giá
#
#
# Thiết kế trang web theo yêu cầu Hết hạn nhận chào giá
#
#
# Nội dung: Tổng hợp dữ liệu tài chính của các công ty trên excel (25 công ty và có thể nhiều hơn) hàng quý. Hết hạn nhận chào giá
#
#
# Test kiểm tra lỗi , hoàn chỉnh chức năng thống kê Hết hạn nhận chào giá
#
#
# Tôi cần thiết kế một trang thống kê kết quả xổ số và tư vấn kết quả Hết hạn nhận chào giá
#
#
# Scan memorygame Hết hạn nhận chào giá
#
#
# Thiết kế video không skip. Hết hạn nhận chào giá
#
#
# Viết SDK cho android và ios Hết hạn nhận chào giá
#
#
# Thiết kế trang web bán đồ chơi và 1 số mặt hàng khác Hết hạn nhận chào giá
#
#
# IT Project Management Hết hạn nhận chào giá
#
#
# App tư vấn du học Hết hạn nhận chào giá
#
#
# Thiết kế chatbot dựa trên nền tảng Harafunnel Hết hạn nhận chào giá
#
#
# Cần Clone lại website Hết hạn nhận chào giá
#
#
# Bảo mật website Wordpress Đã hoàn thành
#
#
# Tư vấn triển khai Odoo Hết hạn nhận chào giá
#
#
# Cài đặt FingerPrint Reader DigitalPersona Hết hạn nhận chào giá
#
#
# Tích hợp cổng thanh toán Google play vào website Đã hoàn thành
#
#
# Cần tuyển dev magento hiểu biết về server để bảo trì, vận hành web có sẵn Hết hạn nhận chào giá
#
#
# Cần cố vấn, chỉ ra vấn để, đưa ra giải pháp SEO cho website Hết hạn nhận chào giá
#
#
# Wordpress website + mobile (not app) Hết hạn nhận chào giá
#
#
# Làm web Hết hạn nhận chào giá
#
#
# Thiết kế userform quản lý đơn hàng vận chuyển excel VBA Hết hạn nhận chào giá
#
#
# CAI DAT data luu du lieu khoá học online Hết hạn nhận chào giá
#
#
# Chép lịch sử xem phim từ tk A sang tk B Hết hạn nhận chào giá
#
#
# TUYỂN THIẾT KẾ GIAO DIỆN APP MOBILE Hết hạn nhận chào giá
#
#
# Thiết Kế Flash / Animation / 2D Hết hạn nhận chào giá
#
#
# Lập trình viên Html5 - Javascript Hết hạn nhận chào giá
#
#
# Chỉnh sửa plugin wordpress Đã hoàn thành
#
#
# Thiết kế Web WordPress Hết hạn nhận chào giá
#
#
#
# Chuyên Viên Hướng Dẫn Lập Trình Php Drupal Hết hạn nhận chào giá
#
#
# Làm 3 Game HTML5 - Mobile Hết hạn nhận chào giá
#
#
# Việc Làm Lao Động Phổ Thông 3-10 triệu/tháng Hết hạn nhận chào giá
#
#
# Cần làm web ecommerce wordpress (Woo) template có sẵn Đã hoàn thành
#
#
# Viết chương trình nhập xuất tồn thu chi Hết hạn nhận chào giá
#
#
# Mình cần viết 1 tool tự động hóa quá trình theo yêu cầu của mình Hết hạn nhận chào giá
#
#
# Pen Test Cho Website Hết hạn nhận chào giá
#
#
# Tạo bot auto trade Hết hạn nhận chào giá
#
#
# Viết script cấu hình máy chủ Centos 7 dùng dải IPV6 /64 thành Proxy Hết hạn nhận chào giá
#
#
# App Bán Đồng Hồ Hết hạn nhận chào giá
#
#
# Kết Nối API Với Wordpress Hết hạn nhận chào giá
#
#
# Cần tìm chuyên gia hỗ trợ xử lý các vấn đề của ứng dụng viết trên MS Access Hết hạn nhận chào giá
#
#
# Giúp sửa lỗi và tạo thêm tính năng có bài tập EMS secure Hết hạn nhận chào giá
#
#
# Design a web for a wine seller Hết hạn nhận chào giá
#
#
# Thiết kế trang web game bài online đổi thưởng Hết hạn nhận chào giá
#
#
# Danh bạ dịch vụ Hết hạn nhận chào giá
#
#
# Quản trị VPS và Website trên VPS Hết hạn nhận chào giá
#
#
# User test Hết hạn nhận chào giá
#
#
# App bán hàng , giao hàng Hết hạn nhận chào giá
#
#
# Cần làm một ứng dụng giả lập zalo cá nhân để lưu lịch sử chat zalo Hết hạn nhận chào giá
#
#
# Tuyển lập trình App Android Ios partime Hết hạn nhận chào giá
#
#
# Thiết kế web / app book lao động thời vụ Hết hạn nhận chào giá
#
#
# Hỗ trợ lập trình Wordpress nâng cao Hết hạn nhận chào giá
#
#
# Cài đặt cổng thanh quốc tế cho website wordpress - woocommerce Hết hạn nhận chào giá
#
#
# Fix lỗi tool javascript: html editor plugin Hết hạn nhận chào giá
#
#
# Tạo app tùy chỉnh sản phẩm trên nền tảng Shopify Hết hạn nhận chào giá
#
#
# Cần 1 bạn làm seo partime Hết hạn nhận chào giá
#
#
# Lập trình full stack Hết hạn nhận chào giá
#
#
# Android and iOS Development for an American Startup Hết hạn nhận chào giá
#
#
# Xây dựng web / app android / ios đặt dịch vụ giúp việc Hết hạn nhận chào giá
#
#
# Tuyển lập trình web / app / android / ios tham gia Co-Founder các dự án Startup Hết hạn nhận chào giá
#
#
# Thiết lập phần mềm thử password có 6 chữ số Hết hạn nhận chào giá
#
#
# Cần tìm người giải giúp đề homework NLP- Bachelor degre Hết hạn nhận chào giá
#
#
# Làm website quản lý bán hàng cho cửa hàng Hết hạn nhận chào giá
#
#
# Lập trình PLC Hết hạn nhận chào giá
#
#
# Thiết kế Mobile App cho web đã có sẵn Hết hạn nhận chào giá
#
#
# Tuyển freelancer có kinh nghiệm làm việc với React/React Native (NodeJS) (có thể làm việc cùng team tại cty thì tốt ) Hết hạn nhận chào giá
#
#
# Mình cần thiết kế web kế nối blockchain ví tomo wallet Hết hạn nhận chào giá
#
#
# Mình muốn SEO website lên top google Hết hạn nhận chào giá
#
#
# SEO website công nghệ Hết hạn nhận chào giá
#
#
# Thiết kế website bán hàng đơn giản tích hợp API có sẵn, đã có sẵn thư viện Hết hạn nhận chào giá
#
#
# Mình cần làm web với php, mysql, jquery. Ưu tiên sinh viên và dev nghiệp dư có kinh nghiệm Hết hạn nhận chào giá
#
#
# User test Hết hạn nhận chào giá
#
#
# Lập trình Server API (Ưu tiên sử dụng ngôn ngữ Java) Hết hạn nhận chào giá
#
#
# Cần tìm lập trình viên PHP/Wordpress để kết nối API Mews vào trang web Hết hạn nhận chào giá
#
#
#
# Cần một wordpress developer chuyên nghiệp Hết hạn nhận chào giá
#
#
# Thiết kế website Hết hạn nhận chào giá
#
#
# Thiết kế trang web bán hàng mỹ phẩm Hết hạn nhận chào giá
#
#
# SEO cho website dự án bất động sản Hết hạn nhận chào giá
#
#
# Chỉnh sữa thêm các trường trong Perfex CRM. Hết hạn nhận chào giá
#
#
# Symfony Web Developer Hết hạn nhận chào giá
#
#
#
# LD789 PRO Đã hoàn thành
#
#
# Viết một mini game quiz (UNITY) Hết hạn nhận chào giá
#
#
#
# Cần làm web wordpress (Woo) template có sẵn Đã hoàn thành
#
#
# Lập trình Angular 7 Hết hạn nhận chào giá
#
#
# Web Marketor Hết hạn nhận chào giá
#
#
# Website download video reddit Đã hoàn thành
#
#
# Wordpress freelancer Hết hạn nhận chào giá
#
#
# Game Server Engineer - Contractor (Vietnamese Only, Working Onsite In Hanoi) Hết hạn nhận chào giá
#
#
#
# Sửa lỗi cho website viết bằng CodeIgniter Framework Hết hạn nhận chào giá
#
#
# Tuyển freelancer làm SEO khu vực tphcm Hết hạn nhận chào giá
#
#
# Viết App quản lý nhà cho thuê Hết hạn nhận chào giá
#
#
# WP: thêm chức năng nhắn tin SMS khi user đăng ký Đã hoàn thành
#
#
# ...
#
#
# Thiết kế web theo mẫu Hết hạn nhận chào giá
#
#
# Cần thiết kế website giống Nhà Thuốc SUMO Hết hạn nhận chào giá
#
#
# Thiết kế phần mềm(web base) để post hình lên Facebook, Instagram, Google my business. Hết hạn nhận chào giá
#
#
# SEO website Xổ số, Vietlot Hết hạn nhận chào giá
#
#
# Thiết kế và lập trình app android , ios Hết hạn nhận chào giá
#
#
# Cần Tìm giảng viên dạy về phần cứng máy tính Hết hạn nhận chào giá
#
#
# Cần 1 bạn viết script cho link rút gọn Đã hoàn thành
#
#
# Thêm chức năng giao hàng bằng key, code Đã hoàn thành
#
#
# Cần api của ứng dụng mPoS.vn Hết hạn nhận chào giá
#
#
# Kêt nối Odoo với API vận chuyển Hết hạn nhận chào giá
#
#
# Thiết kế backend cho app gọi video call và phone call, chat. Hết hạn nhận chào giá
#
#
# Cần tìm 1 bạn Viết token trên nền tảng TRC-20 Hết hạn nhận chào giá
#
#
# Looking for web/Mobile developer for long term Hết hạn nhận chào giá
#
#
# Thiết kế trang web giới thiệu trung tâm dạy học tiếng Hết hạn nhận chào giá
#
#
# Dự án nhập liệu báo cáo sản lượng online Hết hạn nhận chào giá
#
#
# Cắt HTML Dự Án Web Công Ty 10 Page Hết hạn nhận chào giá
#
#
# Tuyển người số hóa dữ liệu GIS mẫu tại Bà Rịa (3.5tr/1 tuần) Hết hạn nhận chào giá
#
#
# Flutter - Kết nối API show dữ liệu cho App có sẵn Hết hạn nhận chào giá
#
#
#
# Cần tìm người làm App React Native gấp Đã hoàn thành
#
#
# Viết plugin cho WordPress (WooCommerce) Hết hạn nhận chào giá
#
#
# Copy website và tạo bản sao để chỉnh sửa trước khi publish Hết hạn nhận chào giá
#
#
# Thiết kế web e-commerce nền tản Magento 2 Hết hạn nhận chào giá
#
#
# Làm APP đọc truyện online Hết hạn nhận chào giá
#
#
# Lập trình Mobile App React Native Hết hạn nhận chào giá
#
#
# Thiết kế web và nôi dung trên web có sẵn Hết hạn nhận chào giá
#
#
# CHỈNH SỬA, THAY CLIENT, BỔ SUNG THÊM OPTION CHO GAME BÀI ĐỔI THƯỞNG Hết hạn nhận chào giá
#
#
# Lập trình dev app dịch vụ sửa chữa điện, nước, giúp việc gia dụng Hết hạn nhận chào giá
#
#
# Edit phần mềm. Hết hạn nhận chào giá
#
#
# Tích hợp thanh toán ví momo vào web application Hết hạn nhận chào giá
#
#
# Hệ thống quản lý quảng cáo Fb ads Hết hạn nhận chào giá
#
#
# Tối ưu hóa phần mềm mô phỏng Android Hết hạn nhận chào giá
#
#
# ứng dụng như now Hết hạn nhận chào giá
#
#
# SEO Website trong nước và nước ngoài (công ty hỗ trợ content) Hết hạn nhận chào giá
#
#
# Lập trình giao diện website VueJs Hết hạn nhận chào giá
#
#
# App iOS đơn giản, kết nối đến mySQL Hết hạn nhận chào giá
#
#
# Seeking full stack developer / webRTC - Chrome extension - Mobile app - web Hết hạn nhận chào giá
#
#
# Gia công website quản lý resort Hết hạn nhận chào giá
#
#
# Python Developer (làm online) Hết hạn nhận chào giá
#
#
# Lập trình MVP phần mềm (làm online) Hết hạn nhận chào giá
#
#
# Cần Freelancer DEV FLUTTER làm app wiki cho game (dạng app tra cứu dữ liệu) Đã hoàn thành
#
#
# Lập trình ứng dụng iOS bằng swiftUI Hết hạn nhận chào giá
#
#
# Lập trình Hết hạn nhận chào giá
#
#
# C# dev làm stock trading với SciChart Hết hạn nhận chào giá
#
#
# Part Time - NodeJS Developer Hết hạn nhận chào giá
#
#
# Web / Mobile developer for - long term Hết hạn nhận chào giá
#
#
# Fix hệ thống website chạy API theo yêu cầu Đã hoàn thành
#
#
# Thiết kế website cho tiệm nail Hết hạn nhận chào giá
#
#
# Convert PDF file sang Joomla Hết hạn nhận chào giá
#
#
# Code giao diện website haravan Hết hạn nhận chào giá
#
#
# Convert HTML5/CSS3 từ PDF file Hết hạn nhận chào giá
#
#
# Cần mua tài khoản Apple developer account (individual) Hết hạn nhận chào giá
#
#
# Thiết kế APP karaoke social network Hết hạn nhận chào giá
#
#
# Tuyển Freelance Tester/QC Manual 1-3 năm kinh nghiệm Hết hạn nhận chào giá
#
#
# Nhận các dự án seo uy tín Hết hạn nhận chào giá
#
#
# Tuyển 5 Dev biết Mod và chỉnh sửa games Hết hạn nhận chào giá
#
#
# LẬP TRÌNH WEBSITE DU LỊCH Hết hạn nhận chào giá
#
#
# Crawl data wordpress Hết hạn nhận chào giá
#
#
# Tuyển dụng blog comment Hết hạn nhận chào giá
#
#
# Cần một tester kiểm thử cho hệ thống nghiệp vụ kế toán mầm non Hết hạn nhận chào giá
#
#
# PHP: Chỉnh sửa Core Plugin Wordpress Hết hạn nhận chào giá
#
#
# Thiết kế app bán hàng cho công ty sơn yamotovietnam Hết hạn nhận chào giá
#
#
# Cần tìm một mã nguồn mở bằng PHP, chủ đề về tin tức, đại khái giống vnexpress Hết hạn nhận chào giá
#
#
# Lập trình OpenCart Hết hạn nhận chào giá
#
#
# Full Stack Developer Hết hạn nhận chào giá
#
#
# Website Live Stream các trận bóng đá Hết hạn nhận chào giá
#
#
# Cần tìm bạn chuyển template thành website Hết hạn nhận chào giá
#
#
# Thiết kế trang web bán hàng sử dụng cakephp Hết hạn nhận chào giá
#
#
#
# Tư vấn nội dung và thẩm định nội dung của website, logo Đã hoàn thành
#
#
#
# Tạo Plugin cho WordPress (WooCommerce) Đã hoàn thành
#
#
# Python Developer (làm online) Hết hạn nhận chào giá
#
#
#
# Build Same System As https://www.ggleap.com/features/ Hết hạn nhận chào giá
#
#
# Cần tuyển người thiết kế cho tôi một web game tài xỉu tương tự như gam vip. Fap club. Sao club vv... Hết hạn nhận chào giá
#
#
# Thiết kế website bán hàng fashion Đã hoàn thành
#
#
# Thiết kế Website xem trực tiếp bóng đá ở các giải bóng đá Hết hạn nhận chào giá
#
#
# Cần tuyển freelancer DEV FLUTTER Hết hạn nhận chào giá
#
#
# Lọc từ và cập nhật từ điển Hết hạn nhận chào giá
#
#
# Triển khai game làm vườn 2D bằng HTML5 (phase 1) Hết hạn nhận chào giá
#
#
# Tối ưu tốc độ query tìm kiếm Hết hạn nhận chào giá
#
#
# Lập trình website 3D Đã hoàn thành
#
#
# Full-stack developer (làm online) Hết hạn nhận chào giá
#
#
#
# Sửa hệ thống Wordpress Hết hạn nhận chào giá
#
#
# Sync Amazon & Etsy Hết hạn nhận chào giá
#
#
# Thiết kế mobile app cho ứng dụng thực tại ảo tăng cường Đã hoàn thành
#
#
# App game giải trí Hết hạn nhận chào giá
#
#
# Thiết kế web bán hàng bằng Cs-cart Hết hạn nhận chào giá
#
#
# Thiết kế app công ty , tích điểm Hết hạn nhận chào giá
#
#
# Thiết kế application để người dùng download video và file Hết hạn nhận chào giá
#
#
# SELENIUM BROWSER AUTOMATION Hết hạn nhận chào giá
#
#
#
# Xây dựng trang web sử dụng Python, Selenium và Flash. Hết hạn nhận chào giá
#
#
# Automate java applet Hết hạn nhận chào giá
#
#
# Tôi cần làm 1 ứng dụng loyalty cho salon tóc Hết hạn nhận chào giá
#
#
# Viết tool submit contact form hàng loạt Hết hạn nhận chào giá
#
#
# Thiết kế website để hỗ trợ cho việc quản lý và phát trển shop Nails Hết hạn nhận chào giá
#
#
# Nâng cấp backend của app Android Hết hạn nhận chào giá
#
#
# Tool nhập dữ liệu từ file word/notepad lên trang web nội bộ của công ty Hết hạn nhận chào giá
#
#
# Phần mềm tự điền 4 dòng text vào 1 phần mềm khác Hết hạn nhận chào giá
#
#
# Tích hợp cổng thanh toán Perfect Money cho website Hết hạn nhận chào giá
#
#
# Thiết kế web mới và chuyển tính năng sang web mới Hết hạn nhận chào giá
#
#
# Code modul chatrom cho web Hết hạn nhận chào giá
#
#
# Nâng cấp phần mềm Quản lý bãi xe Hết hạn nhận chào giá
#
#
# Thêm chức năng cho trang web truyện tranh online Hết hạn nhận chào giá
#
#
# Cần người Chỉnh sữa và tối ưu CSS và Java Script cho Magento 2.x Hết hạn nhận chào giá
#
#
# Viết phần mềm restful api bằng kotlin/java Hết hạn nhận chào giá
#
#
#
# Web cho phéo lưu link sản phẩm từ web, với chrome extension Hết hạn nhận chào giá
#
#
# Xây dựng web call function API chrome extension Hết hạn nhận chào giá
#
#
#
# Code website tin tức và chia sẻ tài liệu Hết hạn nhận chào giá
#
#
# Cải tiến file kế toán excel đã có Hết hạn nhận chào giá
#
#
# Lập trình HTML/CSS từ file thiết kế Hết hạn nhận chào giá
#
#
# Làm 2 màn hình đơn giản (Giới thiệu, Danh sách link, hình ảnh) Hết hạn nhận chào giá
#
#
# Sửa giao diện và nâng cấp 1 vài chức năng cho website bán hàng Hết hạn nhận chào giá
#
#
# Phầm mềm quản lí salon ( dịch vụ khách làm, in hoá đơn, thẻ khách hàng, hoa hồng nhân viên, lương nhân viên, báo cáo doanh thu Hết hạn nhận chào giá
#
#
# Thiết kế website Wordpress cho công ty dược phẩm Hết hạn nhận chào giá
#
#
# Lập trình ngôn ngữ Unity Hết hạn nhận chào giá
#
#
# Cần làm template_page cho website đã có sẵn giao diện Hết hạn nhận chào giá
#
#
# Sửa lỗi và hoàn thiện app mobile đang xây dựng Hết hạn nhận chào giá
#
#
# Dịch tiếng anh, dịch tiếng trung , dịch tiếng hàn Hết hạn nhận chào giá
#
#
# Viết một phần web app để quản lý các giao dịch bằng flutter Hết hạn nhận chào giá
#
#
#
# Dựng website bán hàng Haravan Hết hạn nhận chào giá
#
#
# Làm app cho ios và android , sử dụng bluetooth trên phone để lấy data từ thiết bị Hết hạn nhận chào giá
#
#
# WEB TRA CỨU NỘI DUNG QUẢNG CÁO Hết hạn nhận chào giá
#
#
# VIẾT PLUGINS TÌM KIẾM CHO WORDPRESS Hết hạn nhận chào giá
#
#
# Cần coder PHP chỉnh sửa bổ sung các chức năng lặt vặt của website Hết hạn nhận chào giá
#
#
# Mình cần thiết kế 1 app mobile chuyên về thương mại điện tử bán các sản phẩm nông nghiệp Hết hạn nhận chào giá
#
#
# Lập trình web Hết hạn nhận chào giá
#
#
# VIẾT CHỨC NĂNG QUẢN LÝ CHAT FACEBOOK FANPAGE Hết hạn nhận chào giá
#
#
# Code trang thanh toán bằng bitcoin qua API V2 của Blockchain.com Đã hoàn thành
#
#
#
# XD trang betting bóng đá Hết hạn nhận chào giá
#
#
# Làm landingpage trên nền tảng ladipage có sẵn nội dung Hết hạn nhận chào giá
#
#
# TẠO APP Hết hạn nhận chào giá
#
#
# Thiết kế Website cá cược thể thao Hết hạn nhận chào giá
#
#
# Chỉnh sửa website wordpress (tour) Đã hoàn thành
#
#
# Tích hợp Shipment API cho Drupal 7 + Drupal Commerce Hết hạn nhận chào giá
#
#
# Thiết kế phần mềm lưu trữ Hết hạn nhận chào giá
#
#
# Xây dựng công cụ chuyển văn bản thành giọng nói Google Cloud TTS Hết hạn nhận chào giá
#
#
# Cắt file psd sang html css bootstrap Hết hạn nhận chào giá
#
#
# Chỉnh lại mã nguồn PHP của 1 trang dùng ghi dữ liệu XML vào database MySQL Chỉnh sửa lại chức năng Đại Lý Đã hoàn thành
#
#
# Cần thiết kế website truyện tranh theo nhu cầu cá nhân Hết hạn nhận chào giá
#
#
# Dựng, việt hóa, dịch Phần mềm kết nối hệ thống Hết hạn nhận chào giá
#
#
#
# Làm ứng dụng tạo video từ ảnh cho Android Hết hạn nhận chào giá
#
#
#
# Triển khai website thương mại điện tử Hết hạn nhận chào giá
#
#
# Drupal 7 website, Bug fix, content update and addition Hết hạn nhận chào giá
#
#
# Tool lấy dữ liệu từ website chứng khoán Hết hạn nhận chào giá
#
#
# Xây dựng phần mềm HRM cho doanh nghiệp Hết hạn nhận chào giá
#
#
# Xử lý sentiment của tweets (có sẵn tool) Hết hạn nhận chào giá
#
#
# Website Subscriptions And Memberships Hết hạn nhận chào giá
#
#
# Lập trình viên biết PHP, BPMN để viết process trong ProcessMaker Hết hạn nhận chào giá
#
#
# Công cụ hỗ trợ truy xuất dữ liệu khách hàng Hết hạn nhận chào giá
#
#
# Cần lập trình viên thông thạo MS Access và SQL Hết hạn nhận chào giá
#
#
# Cần bạn giúp mình thảy đổi một chút về giao diện wordpress Hết hạn nhận chào giá
#
#
# Mình cần bạn có kỹ năng viết bài SEO ngành xây dựng trên website Hết hạn nhận chào giá
#
#
# Xử lý data twitter Hết hạn nhận chào giá
#
#
# Tối ưu nâng cấp shop lên phiên bản codenighter mới nhất Hết hạn nhận chào giá
#
#
# Thiết kế website cho công ty ở Canada Hết hạn nhận chào giá
#
#
# PSD to HTML/CSS, sửa website wordpress Đã hoàn thành
#
#
# Convert link google drive sang m3u8 Hết hạn nhận chào giá
#
#
# Tạo trang web theo yêu cầu Hết hạn nhận chào giá
#
#
# Viết tool tự động rút item game theo điều kiện đặt ra Hết hạn nhận chào giá
#
#
# CHỉnh sửa giao diện Wordpress Đã hoàn thành
#
#
# Xây dựng ứng dụng Windows Universal App!!! Hết hạn nhận chào giá
#
#
# Tích hợp Zalopay vào website TMĐT Hết hạn nhận chào giá
#
#
# Thiết kế hệ thống AFF 5 tầng - 10 tầng bằng ngôn ngữ PHP Hết hạn nhận chào giá
#
#
#
# Chỉnh sửa mã nguồn PHP quản lý đại lý, thành viên giới thiệu với các thống kê chi tiết, báo cáo, tính tiền linh động Đã hoàn thành
#
#
# Viết phần mềm Hết hạn nhận chào giá
#
#
# Business Development Hết hạn nhận chào giá
#
#
# Game đánh bài mobile (ios/android) Hết hạn nhận chào giá
#
#
# Lập trình web theo yêu cầu Hết hạn nhận chào giá
#
#
# Lập trình viên FrontEnd Hết hạn nhận chào giá
#
#
# Cần tìm 2 Ruby on Rails devs freelance cho dự án với khách hàng Nhật Hết hạn nhận chào giá
#
#
# Làm app đăng nhập facebook Hết hạn nhận chào giá
#
#
# PHP Developer (CMS wordpress) Hết hạn nhận chào giá
#
#
#
# Lập trình web Hết hạn nhận chào giá
#
#
# Gắn api vào Mobile app template Hết hạn nhận chào giá
#
#
# Dev game hyper casual. Hết hạn nhận chào giá
#
#
# Chỉnh lại mã nguồn PHP của 1 trang dùng ghi dữ liệu XML vào database MySQL Đã hoàn thành
#
#
#
# Tìm đơn vị làm mạch PCB - ưu tiên HCM Hết hạn nhận chào giá
#
#
# Cần lập trình viên thông thạo Python, SQL và MS Access Hết hạn nhận chào giá
#
#
# Dự án POS sử dụng công nghệ WPF Hết hạn nhận chào giá
#
#
# Cai dat Server Digital Ocean cho Mobile App va Wordpress Website Hết hạn nhận chào giá
#
#
# Viết MQTT Broker và MQTT client ( dưới dạng app trên IOS/android ) Hết hạn nhận chào giá
#
#
# Làm website cho sự kiện Korean PATINEX(PATent INformation EXpo) 2020 Hết hạn nhận chào giá
#
#
# Tạo tài khoản quảng cáo tiktok, lên camp, kháng nghị Hết hạn nhận chào giá
#
#
# Thiết kế website nhà hàng Hết hạn nhận chào giá
#
#
# Android Native - Call Video (Webrtc) Hết hạn nhận chào giá
#
#
# Tool auto nạp game Free Fire theo ID trên website napthe.vn Đã hoàn thành
#
#
# Tuyển dev iONIC - Code frontend Ghép API Hết hạn nhận chào giá
#
#
# Chỉnh lại mã nguồn PHP của 1 trang dùng ghi dữ liệu XML vào database MySQL Đã hoàn thành
#
#
#
# XÂY DỰNG WEBAPP ĐƠN GIẢN NHẬP LIỆU THÔNG TIN Hết hạn nhận chào giá
#
#
# Tìm IT xây dựng web shopify bán hàng Hết hạn nhận chào giá
#
#
# Viết webscrap các trang vé máy bay Hết hạn nhận chào giá
#
#
# Tìm người hỗ trợ thiết lập auto leech truyện cho Wordpress (Đã có sẵn plugin autoleech) Hết hạn nhận chào giá
#
#
# [3D] Cần làm demo màn hình preview hero Hết hạn nhận chào giá
#
#
# TÌM QUY LUẬT BÀI TOÁN VÀ VIẾT PHẦN MỀM THEO QUY LUẬT Hết hạn nhận chào giá
#
#
# App quản trị nội bộ bằng React Native, đã có API backend Hết hạn nhận chào giá
#
#
# Tuyển BLACK CODER kỹ thuật cao làm dự án về FB (Lương $2000 - $3000/tháng) Hết hạn nhận chào giá
#
#
# Kiểm Tra Các File - Ghi Lại Tên File Nếu Bị Lỗi Hết hạn nhận chào giá
#
#
# Chuyển PSD sang HTML Hết hạn nhận chào giá
#
#
# Thiết kế nội dung website tối ưu SEO Hết hạn nhận chào giá
#
#
# Lập trình và phát triển front-end & back-end website công ty Hết hạn nhận chào giá
#
#
# Thiết kế web TMDT bằng nodeJS Hết hạn nhận chào giá
#
#
# Tuyển 2 Senior dev IOS (swift) Hết hạn nhận chào giá
#
#
# Thiết kế mục tin tức cho website Hết hạn nhận chào giá
#
#
# App IOS Hết hạn nhận chào giá
#
#
# Cần tìm Frontend magento 2 Hết hạn nhận chào giá
#
#
# Xây dựng phần mềm nhận diện khuôn mặt Hết hạn nhận chào giá
#
#
# Tuyển 2 Node.js backend devs freelance cho dự án với khách hàng Nhật Hết hạn nhận chào giá
#
#
# Mình cần 1 đoạn script tự động đơn giản cho trình duyệt Hết hạn nhận chào giá
#
#
# Tuyển 2 Go+React devs freelance cho dự án với khách hàng Nhật Hết hạn nhận chào giá
#
#
# Tuyển team freelance update hệ thống quản lý Hết hạn nhận chào giá
#
#
# Website bán hàng, giống shoptretho Hết hạn nhận chào giá
#
#
# Game bài Hết hạn nhận chào giá
#
#
# Customize phần mềm quản lý nhân sự, chấm công, tiền lương Hết hạn nhận chào giá
#
#
# Thiet ke web ban hang Ruou Hết hạn nhận chào giá
#
#
# Viết app trên giao diện và API có sẵn, kết nối máy in, upload app lên IOS Hết hạn nhận chào giá
#
#
# Viết Plugin Cổng Thanh Toán SquareUp Xoay Nhiều Account cho Woocommerce Hết hạn nhận chào giá
#
#
# Tool leech truyện tranh Hết hạn nhận chào giá
#
#
# Tôi cần thiết kế website bán hàng php giống demo Hết hạn nhận chào giá
#
#
# Tool reup Facebook từ Youtueb và các nguồn khác Hết hạn nhận chào giá
#
#
# Cần tìm IT Freeplancer làm web TMĐT Bằng Tiếng Anh Hết hạn nhận chào giá
#
#
# Tool auto facebook nhiều chứ năng Hết hạn nhận chào giá
#
#
# Kỹ thuật viên Hết hạn nhận chào giá
#
#
# Viết mini web game Hết hạn nhận chào giá
#
#
# Tìm đơn vị viết app mobile về quản lý thiết bị trên nền tảng web và backend có sẵn - ưu tiên HCM Hết hạn nhận chào giá
#
#
# Viết mini game cho di động Hết hạn nhận chào giá
#
#
# Cần viết chức năng quản lý chat facebook fanpage Hết hạn nhận chào giá
#
#
# Thiêt kế Website Wordpress Multisite, Nhiều ngôn ngữ. Hết hạn nhận chào giá
#
#
# Design và Code Shopify Đã hoàn thành
#
#
# Nâng cấp chức năng cho WordPress Plugin Hết hạn nhận chào giá
#
#
# BLACK CODER Hết hạn nhận chào giá
#
#
# Phần Mềm Tìm Việc Lam Hết hạn nhận chào giá
#
#
# Lập trình website Hết hạn nhận chào giá
#
#
# Thiết kế trang web bán hàng Hết hạn nhận chào giá
#
#
# Phát triển website thương mại điện tử Hết hạn nhận chào giá
#
#
# Xây dựng website trên nền wordpress Hết hạn nhận chào giá
#
#
# Sửa code plugin theo đúng chuẩn wordpress Hết hạn nhận chào giá
#
#
# Thiết kế UI/UX Hết hạn nhận chào giá
#
#
# Viết lại script theo yêu cầu mới để có thể chạy được trên trang https://www.bustabit.com/play Hết hạn nhận chào giá
#
#
#
# Chỉnh sửa website Wordpress Đã hoàn thành
#
#
# Mình cần làm 1 web bán hàng và giới thiệu sản phẩm Hết hạn nhận chào giá

# %%
# Loại bỏ ký tự xuống dòng (\n) trong Title
df['Title'] = df['Title'].str.replace('\n', ' ')

# Do không cần dùng trạng thái công việc nên ta sẽ loại bỏ các giá trị "Đã hoàn thành", "Hết hạn nhận chào giá", "Mới
df['Title'] = df['Title'].str.replace('Đã hoàn thành|Hết hạn nhận chào giá|Mới', '', regex=True).str.strip()
# Out:
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\1013757675.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Title'] = df['Title'].str.replace('\n', ' ')
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\1013757675.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Title'] = df['Title'].str.replace('Đã hoàn thành|Hết hạn nhận chào giá|Mới', '', regex=True).str.strip()

# %%
df['Title']
# Out:
# 0                              Chỉnh sửa website Wordpress
# 1        Mình cần làm 1 web bán hàng và giới thiệu sản ...
# 3         Thiết kế trang Web từ file thiết kế đã làm (PSD)
# 4                                       Mobile APP nhà cái
# 5                             Clone 1 trang bằng Elementor
#                                ...
# 11694            Sửa code plugin theo đúng chuẩn wordpress
# 11695                                       Thiết kế UI/UX
# 11696    Viết lại script theo yêu cầu mới để có thể chạ...
# 11698                          Chỉnh sửa website Wordpress
# 11699    Mình cần làm 1 web bán hàng và giới thiệu sản ...
# Name: Title, Length: 11457, dtype: object

# %%
df['Services']
# Out:
# 0        \nDịch vụ cần thuê:\n\n\nViết phần mềm theo yê...
# 1        \nDịch vụ cần thuê:\n\n\nDựng website bán hàng...
# 3        \nDịch vụ cần thuê:\n\n\nCắt HTML/CSS từ PSD \n\n
# 4        \nDịch vụ cần thuê:\n\n\nLàm Mobile App theo y...
# 5        \nDịch vụ cần thuê:\n\n\nThiết kế giao diện we...
#                                ...
# 11694    \nDịch vụ cần thuê:\n\n\nViết phần mềm theo yê...
# 11695    \nDịch vụ cần thuê:\n\n\nThiết kế giao diện we...
# 11696    \nDịch vụ cần thuê:\n\n\nViết phần mềm theo yê...
# 11698    \nDịch vụ cần thuê:\n\n\nViết phần mềm theo yê...
# 11699    \nDịch vụ cần thuê:\n\n\nDựng website bán hàng...
# Name: Services, Length: 11457, dtype: object

# %%
#Loại bỏ \n và "Dịch vụ cần thuê" trong Services
df['Services'] = df['Services'].str.replace('\n|Dịch vụ cần thuê:', '', regex=True).str.strip()
# Out:
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\2555506167.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Services'] = df['Services'].str.replace('\n|Dịch vụ cần thuê:', '', regex=True).str.strip()

# %%
df['Services'].unique()
# Out:
# array(['Viết phần mềm theo yêu cầu', 'Dựng website bán hàng',
#        'Cắt HTML/CSS từ PSD', 'Làm Mobile App theo yêu cầu',
#        'Thiết kế giao diện website', 'Viết Mobile App cho web có sẵn',
#        'Test và kiểm tra lỗi', 'Xử lý dữ liệu',
#        'Thiết kế Mockup cho Website', nan, 'Tối ưu SEO cho trang web',
#        'Xây dựng Web App MVP (Minium Viable Product)',
#        'Chuyển Template thành Website', 'Viết game di động',
#        'Xây dựng liên kết tới trang web - backlink',
#        'Nhập dữ liệu lên website', 'Cài đặt / Cấu hình server',
#        'SEO website', 'Lập kế hoạch kinh doanh', 'Viết nội dung cho blog',
#        'Viết nội dung cho website', 'Tư vấn / Thiết kế hệ thống mạng',
#        'Đăng sản phẩm lên website',
#        'Xây dựng Mobile App MVP (Minium Viable Product)',
#        'Thiết kế hình động / Flash', 'Thiết kế giao diện Mobile App',
#        'Thiết kế Mockup cho Mobile App', 'Lập hồ sơ gọi vốn',
#        'Đăng bài lên website / đăng tin rao vặt',
#        'Phát triển ứng dụng web', 'Làm app IOS',
#        'Xây dựng website wordpress', 'Xử lí tác vụ Machine Learning',
#        'Viết tài liệu đặc tả phần mềm (SRS)',
#        'Xây dựng hệ thống Crawler dữ liệu', 'Sửa máy tính để bàn',
#        'Xây dựng model AI', 'Chỉnh sửa shell script hệ thống',
#        'Làm ứng dụng Android theo yêu cầu', 'Bảo trì các dự án phần mềm',
#        'Lập trình hợp đồng thông minh(Smart Contract)',
#        'Lập trình module odoo', 'Thiết kế mạch điện tử, PCB',
#        'Tạo mô hình Deep Learning', 'Xây dựng website thương mại điện tử',
#        'Viết phần mềm quản lý', 'Sửa lỗi Selinux Android',
#        'Chuyển template thành theme Wordpress',
#        'Viết phần mềm quản lý bán hàng',
#        'Xây dựng Web thương mại điện tử Magento',
#        'Xây dựng hệ thống Embedded Linux', 'Tư vấn giải pháp phần mềm',
#        'Lập trình AutoLisp cho Autocad', 'Xây dựng Web App MVC( .net)',
#        'Lập trình giao diện GTK', 'Lập trình web Golang',
#        'Ứng cứu sự cố khẩn cấp về Hệ thống thông tin',
#        'Lập trình phần mềm trên Excel', 'Viết báo cáo - nghiên cứu',
#        'Biên tập / Chỉnh sửa nội dung',
#        'Tối ưu hóa công cụ tìm kiếm cho gian hàng và sản phẩm',
#        'Chụp ảnh sản phẩm', 'Khôi phục dữ liệu', 'Thiết kế theo yêu cầu',
#        'Khắc phục sự cố mạng', 'Đánh giá và kiểm định An toàn thông tin',
#        'Thiết kế Logo', 'Thiết kế sản phẩm in 3D',
#        'Làm video giới thiệu công ty', 'Thiết kế giao diện trò chơi 2D',
#        'Viết bài mới chuẩn SEO cho website tiếng Anh',
#        'Biên soạn tài liệu / giáo trình', 'Viết nội dung website',
#        'Viết bài PR sáng tạo nhiều người đọc', 'Forum seeding'],
#       dtype=object)

# %%
df['Skills']
# Out:
# 0        \nKỹ năng\n\nWordpress , \nresponsive , \ndesi...
# 1                                  \nKỹ năng\n\nBán hàng
# 3        \nKỹ năng\n\nTiếng Anh , \nPSD , \nThiết kế tr...
# 4                              \nKỹ năng\n\niOS , \ncode
# 5                                 \nKỹ năng\n\nWordpress
#                                ...
# 11694    \nKỹ năng\n\nPHP , \nWordpress , \nPlugin , \n...
# 11695    \nKỹ năng\n\niOS , \nGraphic Design , \nAndroi...
# 11696    \nKỹ năng\n\nJavascript , \njQuery , \nThiết k...
# 11698    \nKỹ năng\n\nWordpress , \nresponsive , \ndesi...
# 11699                              \nKỹ năng\n\nBán hàng
# Name: Skills, Length: 11457, dtype: object

# %%
# Loại bỏ ký tự xuống dòng (\n) và từ "Kỹ năng" trong Skills
df['Skills'] = df['Skills'].str.replace(r'\n|Kỹ năng', '', regex=True).str.strip()

# Loại bỏ khoảng trắng thừa trước dấu phẩy (nếu có)
df['Skills'] = df['Skills'].str.replace(' ,', ',', regex=False).str.strip()
# Out:
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\1349107112.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Skills'] = df['Skills'].str.replace(r'\n|Kỹ năng', '', regex=True).str.strip()
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\1349107112.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Skills'] = df['Skills'].str.replace(' ,', ',', regex=False).str.strip()

# %%
df['Skills']
# Out:
# 0                    Wordpress, responsive, design
# 1                                         Bán hàng
# 3               Tiếng Anh, PSD, Thiết kế trang web
# 4                                        iOS, code
# 5                                        Wordpress
#                            ...
# 11694    PHP, Wordpress, Plugin, code, Woocommerce
# 11695         iOS, Graphic Design, Android, design
# 11696       Javascript, jQuery, Thiết kế giao diện
# 11698                Wordpress, responsive, design
# 11699                                     Bán hàng
# Name: Skills, Length: 11457, dtype: object

# %%
#Đổi "\n" thành " " trong Description
df['Description'] = df['Description'].str.replace('\n', ' ').str.strip()
df['Description'].unique()
# Out:
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\163371316.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Description'] = df['Description'].str.replace('\n', ' ').str.strip()
# array(['Yêu cầu:  Làm giống Design thêm Responsive trên Mobile - Hiện tại cũng gần ổn rồi https://drive.google.com/drive/folders/1XE0uoc61uX30ED-4CkRhT4cqvJvj76UV?usp=sharing  Site đang làm dở: http://wondermedia.hostingviet.com.vn/  Kiểm tra xem còn chức năng nào chưa hoàn thiện thì xử lý nốt.  VD Trang chi tiết DV:  - Chưa đặt hàng được.  Thời gian hoàn thành: 4 ngày kể từ khi bắt đầu (tính cả T7, CN)',
#        'Website không yêu cầu nhiều chỉ cần giao diện thân thiện dễ nhìn , quản lý được số lượng sản phẩm và cổng thanh toán qua thẻ.  Mình cần làm việc trực tiếp nên chỉ cần những bạn ở TP.HCM ạ, (mình ở quận 3)  Bạn nào đã từng website cho nước ngoài thì càng tốt ạ.',
#        'Công ty mình cần tuyển một bạn Freelancer làm website từ file thiết kế PSD có sẵn. Các website từ dễ đến khó. Mình cần một bạn có kinh nghiệm và có thể hợp tác lâu dài (hợp tác từ 2 - 10 dự án). Mỗi website tùy vào độ phức tạp sẽ thỏa thuận giá với nhau. Bạn nào ở Hà Nội thì liên hệ mình nhé.',
#        ...,
#        'Hi all,  Tôi cần tìm một wordpress dev expert giúp sửa code 1 plugin theo đúng chuẩn Worpress để có thể submit plugin lên Wordpres plugin directory.  Plugin này đã được 1 bên outsource hoàn thành phần chức năng nhưng không đáp ứng tiêu chuẩn Wordpress và họ đã đơn phương dừng không làm tiếp.  (*) Đây là dự án fixed cost, chỉ khi plugin vượt qua vòng review code và được Wordpress chấp nhận plugin thì mới được coi là hoàn thành, khi đó thù lao mới đc thanh toán.  Đối với các anh chị expert Wordpress, task này có thể xong trong 1-2 tiếng !!!  (CHỈ DÀNH CHO FREELANCER ĐỘC LẬP)  Các bạn junior dev, công ty phần mềm hay freelancer bid lấy profile dự án tôi sẽ KHÔNG phản hồi.  Yêu cầu ứng viên:  - Trách nhiệm, tỉ mỉ.  - Wordpress expert, có kinh nghiệm optimize Wordpress plugin.  Vui lòng liên hệ s*k*ype - [được ẩn bởi vlance]',
#        'Xin chào  Hiện tại bên công ty mình đang cần design UI/UX webite, app android, ios cho trang âm nhạc. Chi tiết dự án sẽ được gửi trong chat khi bạn được chọn  Yêu cầu skill  ● Graphic Design  ● UI/UX Design  Cảm ơn',
#        '+OLDED: Script đang chạy được trên trang https://www.bustabit.com/play   1> Script cũ : Script Olded.png (doi lai thanh .js)   2> Giao diện cũ: UI Olded.png  +NEW : Yêu cầu viết lại Script mới với giao diện mới để có thể chạy được trên trang https://www.bustabit.com/play   1> Thiết kế giao diện + default value : B1 - Script UI.png   2> Mô tả chi tiết chức năng: B2 -Chú Thích Ch_c Năng.png   3> Kịch bản kiểm tra kết quả: B3 -Test Cases (edited #2).png'],
#       dtype=object)

# %%
df["In4_project"][1571]
# Out:
# '\n\nID dự án\n38267\nNgày đăng\n\n                                            05/02/2020, 18:44                                    \nChỉ còn\nHết hạn nhận chào giá\nĐịa điểm\n\n                Toàn Quốc            \nNgân sách\n\n                1.000.000đ                            \nHình thức làm việc\n\n                                            Làm tại văn phòng                                                                            \nHình thức trả lương\n\n                                    Trả theo dự án                            \n\n'

# %%
def extract_info(info):
    result = {
        'ID dự án': None,
        'Ngày đăng': None,
        'Chỉ còn': None,
        'Địa điểm': None,
        'Ngân sách': None,
        'Hình thức làm việc': None,
        'Hình thức trả lương': None
    }
    
    # Tạo các mẫu biểu thức chính quy cho từng mục
    patterns = {
        'ID dự án': r'ID dự án\n(\d+)|Id\n\s*(\d+)',
        'Ngày đăng': r'Ngày đăng\n\s+([^\n]+)',
        'Chỉ còn': r'Chỉ còn\n([^\n]+)',
        'Địa điểm': r'Địa điểm\n\s+([^\n]+)',
        'Ngân sách': r'Ngân sách\n\s+([^\n]+(?:\s+-\s+[^\n]+)?)',  # Cập nhật cho hai dạng Ngân sách
        'Hình thức làm việc': r'Hình thức làm việc\n\s+([^\n]+)',
        'Hình thức trả lương': r'Hình thức trả lương\n\s+([^\n]+)'
    }
    
    # Áp dụng từng mẫu để trích xuất giá trị
    for key, pattern in patterns.items():
        match = re.search(pattern, info)
        if match is not None and match.group(1) is not None:
            result[key] = match.group(1).strip()
        else:
            result[key] = None

    return result

# %%
# Giả sử df là DataFrame của bạn
info_list = []
# Thay thế các giá trị NaN bằng chuỗi rỗng
df["In4_project"] = df["In4_project"].fillna("")

for index, project_info in enumerate(df["In4_project"]):
    print(f"Processing project {index}...") 
    extracted_info = extract_info(project_info)
    info_list.append(extracted_info)
# Out:
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\3900237239.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["In4_project"] = df["In4_project"].fillna("")
# Processing project 0...
# Processing project 1...
# Processing project 2...
# Processing project 3...
# Processing project 4...
# Processing project 5...
# Processing project 6...
# Processing project 7...
# Processing project 8...
# Processing project 9...
# Processing project 10...
# Processing project 11...
# Processing project 12...
# Processing project 13...
# Processing project 14...
# Processing project 15...
# Processing project 16...
# Processing project 17...
# Processing project 18...
# Processing project 19...
# Processing project 20...
# Processing project 21...
# Processing project 22...
# Processing project 23...
# Processing project 24...
# Processing project 25...
# Processing project 26...
# Processing project 27...
# Processing project 28...
# Processing project 29...
# Processing project 30...
# Processing project 31...
# Processing project 32...
# Processing project 33...
# Processing project 34...
# Processing project 35...
# Processing project 36...
# Processing project 37...
# Processing project 38...
# Processing project 39...
# Processing project 40...
# Processing project 41...
# Processing project 42...
# Processing project 43...
# Processing project 44...
# Processing project 11364...
# Processing project 11365...
# Processing project 11366...
# Processing project 11367...
# Processing project 11368...
# Processing project 11369...
# Processing project 11370...
# Processing project 11371...
# Processing project 11372...
# Processing project 11373...
# Processing project 11374...
# Processing project 11375...
# Processing project 11376...
# Processing project 11377...
# Processing project 11378...
# Processing project 11379...
# Processing project 11380...
# Processing project 11381...
# Processing project 11382...
# Processing project 11383...
# Processing project 11384...
# Processing project 11385...
# Processing project 11386...
# Processing project 11387...
# Processing project 11388...
# Processing project 11389...
# Processing project 11390...
# Processing project 11391...
# Processing project 11392...
# Processing project 11393...
# Processing project 11394...
# Processing project 11395...
# Processing project 11396...
# Processing project 11397...
# Processing project 11398...
# Processing project 11399...
# Processing project 11400...
# Processing project 11401...
# Processing project 11402...
# Processing project 11403...
# Processing project 11404...
# Processing project 11405...
# Processing project 11406...
# Processing project 11407...
# Processing project 11408...
# Processing project 11409...
# Processing project 11410...
# Processing project 11411...
# Processing project 11412...
# Processing project 11413...
# Processing project 11414...
# Processing project 11415...
# Processing project 11416...
# Processing project 11417...
# Processing project 11418...
# Processing project 11419...
# Processing project 11420...
# Processing project 11421...
# Processing project 11422...
# Processing project 11423...
# Processing project 11424...
# Processing project 11425...
# Processing project 11426...
# Processing project 11427...
# Processing project 11428...
# Processing project 11429...
# Processing project 11430...
# Processing project 11431...
# Processing project 11432...
# Processing project 11433...
# Processing project 11434...
# Processing project 11435...
# Processing project 11436...
# Processing project 11437...
# Processing project 11438...
# Processing project 11439...
# Processing project 11440...
# Processing project 11441...
# Processing project 11442...
# Processing project 11443...
# Processing project 11444...
# Processing project 11445...
# Processing project 11446...
# Processing project 11447...
# Processing project 11448...
# Processing project 11449...
# Processing project 11450...
# Processing project 11451...
# Processing project 11452...
# Processing project 11453...
# Processing project 11454...
# Processing project 11455...
# Processing project 11456...

# %%
len(df)
# Out:
# 11457

# %%
df.iloc[1610]
# Out:
# Type                                                      Đăng việc
# Title                                                Web3 Developer
# Services                                 Viết phần mềm theo yêu cầu
# Skills            CSS, HTML, Javascript, JSON, Tiếng Anh, Postgr...
# Description       ● > 2 years experience working as a full stack...
# In4_project       \n\nID dự án\n79910\nNgày đăng\n\n            ...
# In4_employment    \n\n\n\n\n\n\n\n\n\n                        Bi...
# Num_applicants    \n                Chào giá:                   ...
# Applicants        ['/freelancer/tuan-anh-truong-10', '/freelance...
# Duration          \n                Trung bình:                6...
# Price             \n\n                Thấp nhất:                ...
# Link                  https://www.vlance.vn/viec-lam/web3-developer
# Name: 1640, dtype: object

# %%
len(info_list)
# Out:
# 11457

# %%
info_list[1610]
# Out:
# {'ID dự án': '79910',
#  'Ngày đăng': '10/10/2024, 11:18',
#  'Chỉ còn': 'Hết hạn nhận chào giá',
#  'Địa điểm': 'Hà Nội',
#  'Ngân sách': '250.000đ                                                             - 350.000đ',
#  'Hình thức làm việc': 'Làm online',
#  'Hình thức trả lương': 'Trả theo giờ'}

# %%
#nối info_list vào df
info_df = pd.DataFrame(info_list)
info_df
# Out:
#       ID dự án          Ngày đăng                Chỉ còn         Địa điểm  \
# 0        42059  27/08/2020, 13:45          Đã hoàn thành           Hà Nội
# 1        42057  27/08/2020, 12:23  Hết hạn nhận chào giá  TP. Hồ Chí Minh
# 2        42052  27/08/2020, 08:43  Hết hạn nhận chào giá           Hà Nội
# 3        42051  27/08/2020, 05:00  Hết hạn nhận chào giá        Toàn Quốc
# 4        42044  26/08/2020, 22:03  Hết hạn nhận chào giá        Toàn Quốc
# ...        ...                ...                    ...              ...
# 11452    42064  27/08/2020, 21:43  Hết hạn nhận chào giá        Toàn Quốc
# 11453    42063  27/08/2020, 17:06  Hết hạn nhận chào giá  TP. Hồ Chí Minh
# 11454    42056  27/08/2020, 11:44  Hết hạn nhận chào giá        Toàn Quốc
# 11455    42059  27/08/2020, 13:45          Đã hoàn thành           Hà Nội
# 11456    42057  27/08/2020, 12:23  Hết hạn nhận chào giá  TP. Hồ Chí Minh
#
#          Ngân sách Hình thức làm việc Hình thức trả lương
# 0       4.000.000đ  Làm tại văn phòng      Trả theo dự án
# 1       2.000.000đ  Làm tại văn phòng      Trả theo dự án
# 2      20.000.000đ  Làm tại văn phòng      Trả theo dự án
# 3      20.000.000đ  Làm tại văn phòng      Trả theo dự án
# 4         300.000đ  Làm tại văn phòng      Trả theo dự án
# ...            ...                ...                 ...
# 11452   1.000.000đ  Làm tại văn phòng      Trả theo dự án
# 11453  10.000.000đ  Làm tại văn phòng      Trả theo dự án
# 11454   3.000.000đ  Làm tại văn phòng      Trả theo dự án
# 11455   4.000.000đ  Làm tại văn phòng      Trả theo dự án
# 11456   2.000.000đ  Làm tại văn phòng      Trả theo dự án
#
# [11457 rows x 7 columns]

# %%
df["In4_project"]
# Out:
# 0        \n\nID dự án\n42059\nNgày đăng\n\n            ...
# 1        \n\nID dự án\n42057\nNgày đăng\n\n            ...
# 3        \n\nID dự án\n42052\nNgày đăng\n\n            ...
# 4        \n\nID dự án\n42051\nNgày đăng\n\n            ...
# 5        \n\nID dự án\n42044\nNgày đăng\n\n            ...
#                                ...
# 11694    \n\nID dự án\n42064\nNgày đăng\n\n            ...
# 11695    \n\nID dự án\n42063\nNgày đăng\n\n            ...
# 11696    \n\nID dự án\n42056\nNgày đăng\n\n            ...
# 11698    \n\nID dự án\n42059\nNgày đăng\n\n            ...
# 11699    \n\nID dự án\n42057\nNgày đăng\n\n            ...
# Name: In4_project, Length: 11457, dtype: object

# %%
# Đặt lại chỉ số, loại bỏ chỉ số cũ
df.reset_index(drop=True, inplace=True)
df["In4_project"]
# Out:
# 0        \n\nID dự án\n42059\nNgày đăng\n\n            ...
# 1        \n\nID dự án\n42057\nNgày đăng\n\n            ...
# 2        \n\nID dự án\n42052\nNgày đăng\n\n            ...
# 3        \n\nID dự án\n42051\nNgày đăng\n\n            ...
# 4        \n\nID dự án\n42044\nNgày đăng\n\n            ...
#                                ...
# 11452    \n\nID dự án\n42064\nNgày đăng\n\n            ...
# 11453    \n\nID dự án\n42063\nNgày đăng\n\n            ...
# 11454    \n\nID dự án\n42056\nNgày đăng\n\n            ...
# 11455    \n\nID dự án\n42059\nNgày đăng\n\n            ...
# 11456    \n\nID dự án\n42057\nNgày đăng\n\n            ...
# Name: In4_project, Length: 11457, dtype: object

# %%
#nối info_df vào df
df = pd.concat([df, info_df], axis=1)
df
# Out:
#                 Type                                              Title  \
# 0      Nhận chào giá                        Chỉnh sửa website Wordpress
# 1          Đăng việc  Mình cần làm 1 web bán hàng và giới thiệu sản ...
# 2          Đăng việc   Thiết kế trang Web từ file thiết kế đã làm (PSD)
# 3          Đăng việc                                 Mobile APP nhà cái
# 4          Đăng việc                       Clone 1 trang bằng Elementor
# ...              ...                                                ...
# 11452      Đăng việc          Sửa code plugin theo đúng chuẩn wordpress
# 11453      Đăng việc                                     Thiết kế UI/UX
# 11454      Đăng việc  Viết lại script theo yêu cầu mới để có thể chạ...
# 11455  Nhận chào giá                        Chỉnh sửa website Wordpress
# 11456      Đăng việc  Mình cần làm 1 web bán hàng và giới thiệu sản ...
#
#                           Services                                     Skills  \
# 0       Viết phần mềm theo yêu cầu              Wordpress, responsive, design
# 1            Dựng website bán hàng                                   Bán hàng
# 2              Cắt HTML/CSS từ PSD         Tiếng Anh, PSD, Thiết kế trang web
# 3      Làm Mobile App theo yêu cầu                                  iOS, code
# 4       Thiết kế giao diện website                                  Wordpress
# ...                            ...                                        ...
# 11452   Viết phần mềm theo yêu cầu  PHP, Wordpress, Plugin, code, Woocommerce
# 11453   Thiết kế giao diện website       iOS, Graphic Design, Android, design
# 11454   Viết phần mềm theo yêu cầu     Javascript, jQuery, Thiết kế giao diện
# 11455   Viết phần mềm theo yêu cầu              Wordpress, responsive, design
# 11456        Dựng website bán hàng                                   Bán hàng
#
#                                              Description  \
# 0      Yêu cầu:  Làm giống Design thêm Responsive trê...
# 1      Website không yêu cầu nhiều chỉ cần giao diện ...
# 2      Công ty mình cần tuyển một bạn Freelancer làm ...
# 3      App chỉ có chức năng gọi API kết quả bóng đá v...
# 4      Mình cần clone lại chỉ 1 trang này: tidal.com/...
# ...                                                  ...
# 11452  Hi all,  Tôi cần tìm một wordpress dev expert ...
# 11453  Xin chào  Hiện tại bên công ty mình đang cần d...
# 11454  +OLDED: Script đang chạy được trên trang https...
# 11455  Yêu cầu:  Làm giống Design thêm Responsive trê...
# 11456  Website không yêu cầu nhiều chỉ cần giao diện ...
#
#                                              In4_project  \
# 0      \n\nID dự án\n42059\nNgày đăng\n\n            ...
# 1      \n\nID dự án\n42057\nNgày đăng\n\n            ...
# 2      \n\nID dự án\n42052\nNgày đăng\n\n            ...
# 3      \n\nID dự án\n42051\nNgày đăng\n\n            ...
# 4      \n\nID dự án\n42044\nNgày đăng\n\n            ...
# ...                                                  ...
# 11452  \n\nID dự án\n42064\nNgày đăng\n\n            ...
# 11453  \n\nID dự án\n42063\nNgày đăng\n\n            ...
# 11454  \n\nID dự án\n42056\nNgày đăng\n\n            ...
# 11455  \n\nID dự án\n42059\nNgày đăng\n\n            ...
# 11456  \n\nID dự án\n42057\nNgày đăng\n\n            ...
#
#                                           In4_employment  \
# 0      \n\n\n\n\n\n\n\n\n\n                        Vă...
# 1      \n\n\n\n\n\n\n\n\n\n                        Tu...
# 2      \n\n\n\n\n\n\n\n\n\n                        Ph...
# 3      \n\n\n\n\n\n\n\n\n\n                        Tr...
# 4      \n\n\n\n\n\n\n\n\n\n                        Tu...
# ...                                                  ...
# 11452  \n\n\n\n\n\n\n\n\n\n                        Tu...
# 11453  \n\n\n\n\n\n\n\n\n\n                        Dư...
# 11454  \n\n\n\n\n\n\n\n\n\n                        Ng...
# 11455  \n\n\n\n\n\n\n\n\n\n                        Vă...
# 11456  \n\n\n\n\n\n\n\n\n\n                        Tu...
#
#                                           Num_applicants  \
# 0      \n                Chào giá:                   ...
# 1      \n                Chào giá:                   ...
# 2      \n                Chào giá:                   ...
# 3      \n                Chào giá:                   ...
# 4      \n                Chào giá:                   ...
# ...                                                  ...
# 11452  \n                Chào giá:                   ...
# 11453  \n                Chào giá:                   ...
# 11454  \n                Chào giá:                   ...
# 11455  \n                Chào giá:                   ...
# 11456  \n                Chào giá:                   ...
#
#                                               Applicants  \
# 0                                   ['/freelancer/dong']
# 1      ['/freelancer/luu-ngoc-quang', '/freelancer/ng...
/08/2020, 12:23  Hết hạn nhận chào giá  TP. Hồ Chí Minh   2.000.000đ
#
#       Hình thức làm việc Hình thức trả lương
# 0      Làm tại văn phòng      Trả theo dự án
# 1      Làm tại văn phòng      Trả theo dự án
# 2      Làm tại văn phòng      Trả theo dự án
# 3      Làm tại văn phòng      Trả theo dự án
# 4      Làm tại văn phòng      Trả theo dự án
# ...                  ...                 ...
# 11452  Làm tại văn phòng      Trả theo dự án
# 11453  Làm tại văn phòng      Trả theo dự án
# 11454  Làm tại văn phòng      Trả theo dự án
# 11455  Làm tại văn phòng      Trả theo dự án
# 11456  Làm tại văn phòng      Trả theo dự án
#
# [11457 rows x 19 columns]

# %%
# Xóa khoảng trắng dư thừa ở bất kỳ đâu trong chuỗi của cột "Ngân sách"
df["Ngân sách"] = df["Ngân sách"].str.replace(r'\s+', ' ', regex=True).str.strip()

# %%
#In ra các cột mà ID dự án = null
df[df["ID dự án"].isnull()]
# Out:
#                      Type                                              Title  \
# 1570  Chiến dịch hiển thị  (869) Mình cần tìm 25 bạn RV cho maps Chợ đồ c...
# 1571                  NaN                                                NaN
# 6305  Chiến dịch hiển thị  (869) Mình cần tìm 25 bạn RV cho maps Chợ đồ c...
# 7585  Chiến dịch hiển thị  (869) Mình cần tìm 25 bạn RV cho maps Chợ đồ c...
#
#      Services Skills                                        Description  \
# 1570      NaN    NaN  "A. Yêu cầu về nội dung: Review map về nơi mua...
# 1571      NaN    NaN                                                NaN
# 6305      NaN    NaN  "A. Yêu cầu về nội dung: Review map về nơi mua...
# 7585      NaN    NaN  "A. Yêu cầu về nội dung: Review map về nơi mua...
#
#                                             In4_project  \
# 1570  \n\nId\n80085\nNgày đăng\n\n                16...
# 1571
# 6305  \n\nId\n80085\nNgày đăng\n\n                16...
# 7585  \n\nId\n80085\nNgày đăng\n\n                16...
#
#                                          In4_employment  \
# 1570  \n\n\n\n\n\n\n\n\n\n                        Th...
# 1571                                                NaN
# 6305  \n\n\n\n\n\n\n\n\n\n                        Th...
# 7585  \n\n\n\n\n\n\n\n\n\n                        Th...
#
#                               Num_applicants Applicants  \
# 1570  \n                Số lượng hồ sơ 123\n        NaN
# 1571                                     NaN        NaN
# 6305  \n                Số lượng hồ sơ 125\n        NaN
# 7585  \n                Số lượng hồ sơ 125\n        NaN
#
#                                                Duration  \
# 1570  \n                                            ...
# 1571                                                NaN
# 6305  \n                                            ...
# 7585  \n                                            ...
#
#                                                   Price  \
# 1570  \n\n                Tổng ngân sách 250.000 VNĐ...
# 1571                                                NaN
# 6305  \n\n                Tổng ngân sách 250.000 VNĐ...
# 7585  \n\n                Tổng ngân sách 250.000 VNĐ...
#
#                                                    Link ID dự án   Ngày đăng  \
# 1570  https://www.vlance.vn/cd-tang-review/869-minh-...     None  16/10/2024
# 1571  https://www.vlance.vn/cuoc-thi/thiet-ke-logo-c...     None        None
# 6305  https://www.vlance.vn/cd-tang-review/869-minh-...     None  16/10/2024
# 7585  https://www.vlance.vn/cd-tang-review/869-minh-...     None  16/10/2024
#
#              Chỉ còn Địa điểm Ngân sách Hình thức làm việc Hình thức trả lương
# 1570   28 ngày 1 giờ     None      None               None                None
# 1571            None     None      None               None                None
# 6305  27 ngày 22 giờ     None      None               None                None
# 7585  27 ngày 22 giờ     None      None               None                None

# %%
#drop các dòng mà cột ID dự án = null
df = df.dropna(subset=["ID dự án"]) 
#reset index
df.reset_index(drop=True, inplace=True)

# %%
df["Num_applicants"][0]
# Out:
# '\n                Chào giá:                                        \n                        1                    \n'

# %%
#'\n                Chào giá:                                        \n                        1                    \n'
df["Num_applicants"] = df["Num_applicants"].str.replace(r'\n|\s+|Chào giá:', '', regex=True).str.strip()
# Out:
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\1517301625.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Num_applicants"] = df["Num_applicants"].str.replace(r'\n|\s+|Chào giá:', '', regex=True).str.strip()

# %%
df
# Out:
#                 Type                                              Title  \
# 0      Nhận chào giá                        Chỉnh sửa website Wordpress
# 1          Đăng việc  Mình cần làm 1 web bán hàng và giới thiệu sản ...
# 2          Đăng việc   Thiết kế trang Web từ file thiết kế đã làm (PSD)
# 3          Đăng việc                                 Mobile APP nhà cái
# 4          Đăng việc                       Clone 1 trang bằng Elementor
# ...              ...                                                ...
# 11448      Đăng việc          Sửa code plugin theo đúng chuẩn wordpress
# 11449      Đăng việc                                     Thiết kế UI/UX
# 11450      Đăng việc  Viết lại script theo yêu cầu mới để có thể chạ...
# 11451  Nhận chào giá                        Chỉnh sửa website Wordpress
# 11452      Đăng việc  Mình cần làm 1 web bán hàng và giới thiệu sản ...
#
#                           Services                                     Skills  \
# 0       Viết phần mềm theo yêu cầu              Wordpress, responsive, design
# 1            Dựng website bán hàng                                   Bán hàng
# 2              Cắt HTML/CSS từ PSD         Tiếng Anh, PSD, Thiết kế trang web
# 3      Làm Mobile App theo yêu cầu                                  iOS, code
# 4       Thiết kế giao diện website                                  Wordpress
# ...                            ...                                        ...
# 11448   Viết phần mềm theo yêu cầu  PHP, Wordpress, Plugin, code, Woocommerce
# 11449   Thiết kế giao diện website       iOS, Graphic Design, Android, design
# 11450   Viết phần mềm theo yêu cầu     Javascript, jQuery, Thiết kế giao diện
# 11451   Viết phần mềm theo yêu cầu              Wordpress, responsive, design
# 11452        Dựng website bán hàng                                   Bán hàng
#
#                                              Description  \
# 0      Yêu cầu:  Làm giống Design thêm Responsive trê...
# 1      Website không yêu cầu nhiều chỉ cần giao diện ...
# 2      Công ty mình cần tuyển một bạn Freelancer làm ...
# 3      App chỉ có chức năng gọi API kết quả bóng đá v...
# 4      Mình cần clone lại chỉ 1 trang này: tidal.com/...
# ...                                                  ...
# 11448  Hi all,  Tôi cần tìm một wordpress dev expert ...
# 11449  Xin chào  Hiện tại bên công ty mình đang cần d...
# 11450  +OLDED: Script đang chạy được trên trang https...
# 11451  Yêu cầu:  Làm giống Design thêm Responsive trê...
# 11452  Website không yêu cầu nhiều chỉ cần giao diện ...
#
#                                              In4_project  \
# 0      \n\nID dự án\n42059\nNgày đăng\n\n            ...
# 1      \n\nID dự án\n42057\nNgày đăng\n\n            ...
# 2      \n\nID dự án\n42052\nNgày đăng\n\n            ...
# 3      \n\nID dự án\n42051\nNgày đăng\n\n            ...
# 4      \n\nID dự án\n42044\nNgày đăng\n\n            ...
# ...                                                  ...
# 11448  \n\nID dự án\n42064\nNgày đăng\n\n            ...
# 11449  \n\nID dự án\n42063\nNgày đăng\n\n            ...
# 11450  \n\nID dự án\n42056\nNgày đăng\n\n            ...
# 11451  \n\nID dự án\n42059\nNgày đăng\n\n            ...
# 11452  \n\nID dự án\n42057\nNgày đăng\n\n            ...
#
#                                           In4_employment Num_applicants  \
# 0      \n\n\n\n\n\n\n\n\n\n                        Vă...              1
# 1      \n\n\n\n\n\n\n\n\n\n                        Tu...              9
# 2      \n\n\n\n\n\n\n\n\n\n                        Ph...             16
# 3      \n\n\n\n\n\n\n\n\n\n                        Tr...              5
# 4      \n\n\n\n\n\n\n\n\n\n                        Tu...              3
# ...                                                  ...            ...
# 11448  \n\n\n\n\n\n\n\n\n\n                        Tu...              1
# 11449  \n\n\n\n\n\n\n\n\n\n                        Dư...              9
# 11450  \n\n\n\n\n\n\n\n\n\n                        Ng...              2
# 11451  \n\n\n\n\n\n\n\n\n\n                        Vă...              1
# 11452  \n\n\n\n\n\n\n\n\n\n                        Tu...              9
#
#                                               Applicants  \
# 0                                   ['/freelancer/dong']
# 1      ['/freelancer/luu-ngoc-quang', '/freelancer/ng...
# 2      ['/freelancer/hoang-van-quang-2', '/freelancer...
# 3      ['/freelancer/tung-pham-thanh-5', '/freelancer...
# 4      ['/freelancer/huynh-chi-hieu', '/freelancer/gu...
# ...                                                  ...
# 11448                 ['/freelancer/tran-xuan-truong-7']
# 11449  ['/freelancer/nghi-tran-nguyen', '/freelancer/...
# 11450  ['/freelancer/khanh-nguyen-253', '/freelancer/...
# 11451                               ['/freelancer/dong']
# 11452  ['/freelancer/luu-ngoc-quang', '/freelancer/ng...
#
#                                                 Duration  \
# 0      \n                Trung bình:                3...
# 1      \n                Trung bình:                5...
# 2      \n                Trung bình:                9...
# 3      \n                Trung bình:                1...
# 4      \n                Trung bình:                1...
# ...                                                  ...
# 11448  \n                Trung bình:                3...
# 11449  \n                Trung bình:                8...
# 11450  \n                Trung bình:                2...
# 11451  \n                Trung bình:                3...
# 11452  \n                Trung bình:                5...
#
#                                                    Price  \
# 0      \n\n                Thấp nhất:                ...
# 1      \n\n                Thấp nhất:                ...
# 2      \n\n                Thấp nhất:                ...
# 3      \n\n                Thấp nhất:                ...
# 4      \n\n                Thấp nhất:                ...
# ...                                                  ...
# 11448  \n\n                Thấp nhất:                ...
# 11449  \n\n                Thấp nhất:                ...
# 11450  \n\n                Thấp nhất:                ...
# 11451  \n\n                Thấp nhất:                ...
# 11452  \n\n                Thấp nhất:                ...
#
#                                                     Link ID dự án  \
# 0      https://www.vlance.vn/viec-freelance/chinh-sua...    42059
# 1      https://www.vlance.vn/viec-freelance/minh-can-...    42057
# 2      https://www.vlance.vn/viec-freelance/thiet-ke-...    42052
# 3      https://www.vlance.vn/viec-freelance/mobile-ap...    42051
# 4      https://www.vlance.vn/viec-freelance/clone-1-t...    42044
# ...                                                  ...      ...
# 11448  https://www.vlance.vn/viec-freelance/sua-code-...    42064
# 11449  https://www.vlance.vn/viec-freelance/thiet-ke-...    42063
# 11450  https://www.vlance.vn/viec-freelance/viet-lai-...    42056
# 11451  https://www.vlance.vn/viec-freelance/chinh-sua...    42059
# 11452  https://www.vlance.vn/viec-freelance/minh-can-...    42057
#
#                Ngày đăng                Chỉ còn         Địa điểm    Ngân sách  \
# 0      27/08/2020, 13:45          Đã hoàn thành           Hà Nội   4.000.000đ
# 1      27/08/2020, 12:23  Hết hạn nhận chào giá  TP. Hồ Chí Minh   2.000.000đ
# 2      27/08/2020, 08:43  Hết hạn nhận chào giá           Hà Nội  20.000.000đ
# 3      27/08/2020, 05:00  Hết hạn nhận chào giá        Toàn Quốc  20.000.000đ
# 4      26/08/2020, 22:03  Hết hạn nhận chào giá        Toàn Quốc     300.000đ
# ...                  ...                    ...              ...          ...
# 11448  27/08/2020, 21:43  Hết hạn nhận chào giá        Toàn Quốc   1.000.000đ
# 11449  27/08/2020, 17:06  Hết hạn nhận chào giá  TP. Hồ Chí Minh  10.000.000đ
# 11450  27/08/2020, 11:44  Hết hạn nhận chào giá        Toàn Quốc   3.000.000đ
# 11451  27/08/2020, 13:45          Đã hoàn thành           Hà Nội   4.000.000đ
# 11452  27/08/2020, 12:23  Hết hạn nhận chào giá  TP. Hồ Chí Minh   2.000.000đ
#
#       Hình thức làm việc Hình thức trả lương
# 0      Làm tại văn phòng      Trả theo dự án
# 1      Làm tại văn phòng      Trả theo dự án
# 2      Làm tại văn phòng      Trả theo dự án
# 3      Làm tại văn phòng      Trả theo dự án
# 4      Làm tại văn phòng      Trả theo dự án
# ...                  ...                 ...
# 11448  Làm tại văn phòng      Trả theo dự án
# 11449  Làm tại văn phòng      Trả theo dự án
# 11450  Làm tại văn phòng      Trả theo dự án
# 11451  Làm tại văn phòng      Trả theo dự án
# 11452  Làm tại văn phòng      Trả theo dự án
#
# [11453 rows x 19 columns]

# %%
df["Price"].unique()
# Out:
# array(['\n\n                Thấp nhất:                2.000.000 VNĐ\n\n|\n\n                Trung bình:                2.000.000 VNĐ\n\n|\n\n                Cao nhất:                2.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                2.000.000 VNĐ\n\n|\n\n                Trung bình:                2.777.778 VNĐ\n\n|\n\n                Cao nhất:                5.500.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                2.000.000 VNĐ\n\n|\n\n                Trung bình:                10.250.000 VNĐ\n\n|\n\n                Cao nhất:                20.000.000 VNĐ\n\n',
#        ...,
#        '\n\n                Thấp nhất:                3.000.000 VNĐ\n\n|\n\n                Trung bình:                3.142.857 VNĐ\n\n|\n\n                Cao nhất:                4.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                1.000.000 VNĐ\n\n|\n\n                Trung bình:                15.800.000 VNĐ\n\n|\n\n                Cao nhất:                30.000.000 VNĐ\n\n',
#        '\n\n                Thấp nhất:                5.000.000 VNĐ\n\n|\n\n                Trung bình:                9.222.222 VNĐ\n\n|\n\n                Cao nhất:                10.000.000 VNĐ\n\n'],
#       dtype=object)

# %%
#Bỏ dấu "."
df["Price"] = df["Price"].str.replace('.', '')


# Sử dụng regex để tách giá trị thấp nhất, trung bình và cao nhất
df['Chào giá thấp nhất'] = df['Price'].str.extract(r'Thấp nhất:\s*([\d]+)').astype(float)
df['Chào giá trung bình'] = df['Price'].str.extract(r'Trung bình:\s*([\d]+)').astype(float)
df['Chào giá cao nhất'] = df['Price'].str.extract(r'Cao nhất:\s*([\d]+)').astype(float)
# Out:
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\370082299.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Price"] = df["Price"].str.replace('.', '')
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\370082299.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Chào giá thấp nhất'] = df['Price'].str.extract(r'Thấp nhất:\s*([\d]+)').astype(float)
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\370082299.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Chào giá trung bình'] = df['Price'].str.extract(r'Trung bình:\s*([\d]+)').astype(float)
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\370082299.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Chào giá cao nhất'] = df['Price'].str.extract(r'Cao nhất:\s*([\d]+)').astype(float)

# %%
df
# Out:
#                 Type                                              Title  \
# 0      Nhận chào giá                        Chỉnh sửa website Wordpress
# 1          Đăng việc  Mình cần làm 1 web bán hàng và giới thiệu sản ...
# 2          Đăng việc   Thiết kế trang Web từ file thiết kế đã làm (PSD)
# 3          Đăng việc                                 Mobile APP nhà cái
# 4          Đăng việc                       Clone 1 trang bằng Elementor
# ...              ...                                                ...
# 11448      Đăng việc          Sửa code plugin theo đúng chuẩn wordpress
# 11449      Đăng việc                                     Thiết kế UI/UX
# 11450      Đăng việc  Viết lại script theo yêu cầu mới để có thể chạ...
# 11451  Nhận chào giá                        Chỉnh sửa website Wordpress
# 11452      Đăng việc  Mình cần làm 1 web bán hàng và giới thiệu sản ...
#
#                           Services                                     Skills  \
# 0       Viết phần mềm theo yêu cầu              Wordpress, responsive, design
# 1            Dựng website bán hàng                                   Bán hàng
# 2              Cắt HTML/CSS từ PSD         Tiếng Anh, PSD, Thiết kế trang web
# 3      Làm Mobile App theo yêu cầu                                  iOS, code
# 4       Thiết kế giao diện website                                  Wordpress
# ...                            ...                                        ...
# 11448   Viết phần mềm theo yêu cầu  PHP, Wordpress, Plugin, code, Woocommerce
# 11449   Thiết kế giao diện website       iOS, Graphic Design, Android, design
# 11450   Viết phần mềm theo yêu cầu     Javascript, jQuery, Thiết kế giao diện
# 11451   Viết phần mềm theo yêu cầu              Wordpress, responsive, design
# 11452        Dựng website bán hàng                                   Bán hàng
#
#                                              Description  \
# 0      Yêu cầu:  Làm giống Design thêm Responsive trê...
# 1      Website không yêu cầu nhiều chỉ cần giao diện ...
# 2      Công ty mình cần tuyển một bạn Freelancer làm ...
# 3      App chỉ có chức năng gọi API kết quả bóng đá v...
# 4      Mình cần clone lại chỉ 1 trang này: tidal.com/...
# ...                                                  ...
# 11448  Hi all,  Tôi cần tìm một wordpress dev expert ...
# 11449  Xin chào  Hiện tại bên công ty mình đang cần d...
# 11450  +OLDED: Script đang chạy được trên trang https...
# 11451  Yêu cầu:  Làm giống Design thêm Responsive trê...
# 11452  Website không yêu cầu nhiều chỉ cần giao diện ...
#
#                                              In4_project  \
# 0      \n\nID dự án\n42059\nNgày đăng\n\n            ...
# 1      \n\nID dự án\n42057\nNgày đăng\n\n            ...
# 2      \n\nID dự án\n42052\nNgày đăng\n\n            ...
# 3      \n\nID dự án\n42051\nNgày đăng\n\n            ...
# 4      \n\nID dự án\n42044\nNgày đăng\n\n            ...
# ...                                                  ...
# 11448  \n\nID dự án\n42064\nNgày đăng\n\n            ...
# 11449  \n\nID dự án\n42063\nNgày đăng\n\n            ...
# 11450  \n\nID dự án\n42056\nNgày đăng\n\n            ...
# 11451  \n\nID dự án\n42059\nNgày đăng\n\n            ...
# 11452  \n\nID dự án\n42057\nNgày đăng\n\n            ...
#
#                                           In4_employment Num_applicants  \
# 0      \n\n\n\n\n\n\n\n\n\n                        Vă...              1
# 1      \n\n\n\n\n\n\n\n\n\n                        Tu...              9
# 2      \n\n\n\n\n\n\n\n\n\n                        Ph...             16
# 3      \n\n\n\n\n\n\n\n\n\n                        Tr...              5
# 4      \n\n\n\n\n\n\n\n\n\n                        Tu...              3
# ...                                                  ...            ...
# 11448  \n\n\n\n\n\n\n\n\n\n                        Tu...              1
# 11449  \n\n\n\n\n\n\n\n\n\n                        Dư...              9
# 11450  \n\n\n\n\n\n\n\n\n\n                        Ng...              2
# 11451  \n\n\n\n\n\n\n\n\n\n                        Vă...              1
# 11452  \n\n\n\n\n\n\n\n\n\n                        Tu...              9
#
#                                               Applicants  \
# 0                                   ['/freelancer/dong']
# 1      ['/freelancer/luu-ngoc-quang', '/freelancer/ng...
# 2      ['/freelancer/hoang-van-quang-2', '/freelancer...
# 3      ['/freelancer/tung-pham-thanh-5', '/freelancer...
# 4      ['/freelancer/huynh-chi-hieu', '/freelancer/gu...
# ...                                                  ...
# 11448                 ['/freelancer/tran-xuan-truong-7']
# 11449  ['/freelancer/nghi-tran-nguyen', '/freelancer/...
# 11450  ['/freelancer/khanh-nguyen-253', '/freelancer/...
# 11451                               ['/freelancer/dong']
# 11452  ['/freelancer/luu-ngoc-quang', '/freelancer/ng...
#
#                                                 Duration  ... ID dự án  \
# 0      \n                Trung bình:                3...  ...    42059
# 1      \n                Trung bình:                5...  ...    42057
# 2      \n                Trung bình:                9...  ...    42052
# 3      \n                Trung bình:                1...  ...    42051
# 4      \n                Trung bình:                1...  ...    42044
# ...                                                  ...  ...      ...
# 11448  \n                Trung bình:                3...  ...    42064
# 11449  \n                Trung bình:                8...  ...    42063
# 11450  \n                Trung bình:                2...  ...    42056
# 11451  \n                Trung bình:                3...  ...    42059
# 11452  \n                Trung bình:                5...  ...    42057
#
#                Ngày đăng                Chỉ còn         Địa điểm    Ngân sách  \
# 0      27/08/2020, 13:45          Đã hoàn thành           Hà Nội   4.000.000đ
# 1      27/08/2020, 12:23  Hết hạn nhận chào giá  TP. Hồ Chí Minh   2.000.000đ
# 2      27/08/2020, 08:43  Hết hạn nhận chào giá           Hà Nội  20.000.000đ
# 3      27/08/2020, 05:00  Hết hạn nhận chào giá        Toàn Quốc  20.000.000đ
# 4      26/08/2020, 22:03  Hết hạn nhận chào giá        Toàn Quốc     300.000đ
# ...                  ...                    ...              ...          ...
# 11448  27/08/2020, 21:43  Hết hạn nhận chào giá        Toàn Quốc   1.000.000đ
# 11449  27/08/2020, 17:06  Hết hạn nhận chào giá  TP. Hồ Chí Minh  10.000.000đ
# 11450  27/08/2020, 11:44  Hết hạn nhận chào giá        Toàn Quốc   3.000.000đ
# 11451  27/08/2020, 13:45          Đã hoàn thành           Hà Nội   4.000.000đ
# 11452  27/08/2020, 12:23  Hết hạn nhận chào giá  TP. Hồ Chí Minh   2.000.000đ
#
#       Hình thức làm việc Hình thức trả lương Chào giá thấp nhất  \
# 0      Làm tại văn phòng      Trả theo dự án          2000000.0
# 1      Làm tại văn phòng      Trả theo dự án          2000000.0
# 2      Làm tại văn phòng      Trả theo dự án          2000000.0
# 3      Làm tại văn phòng      Trả theo dự án          1500000.0
# 4      Làm tại văn phòng      Trả theo dự án           300000.0
# ...                  ...                 ...                ...
# 11448  Làm tại văn phòng      Trả theo dự án          2000000.0
# 11449  Làm tại văn phòng      Trả theo dự án          5000000.0
# 11450  Làm tại văn phòng      Trả theo dự án          3000000.0
# 11451  Làm tại văn phòng      Trả theo dự án          2000000.0
# 11452  Làm tại văn phòng      Trả theo dự án          2000000.0
#
#       Chào giá trung bình  Chào giá cao nhất
# 0               2000000.0          2000000.0
# 1               2777778.0          5500000.0
# 2              10250000.0         20000000.0
# 3              34700000.0        100000000.0
# 4                433333.0           500000.0
# ...                   ...                ...
# 11448           2000000.0          2000000.0
# 11449           9222222.0         10000000.0
# 11450           4000000.0          5000000.0
# 11451           2000000.0          2000000.0
# 11452           2777778.0          5500000.0
#
# [11453 rows x 22 columns]

# %%
df["Price"][11452]
# Out:
# '\n\n                Thấp nhất:                2000000 VNĐ\n\n|\n\n                Trung bình:                2777778 VNĐ\n\n|\n\n                Cao nhất:                5500000 VNĐ\n\n'

# %%
len(df["Duration"].unique())
# Out:
# 42

# %%
print(df["Duration"].unique())
# Out:
# ['\n                Trung bình:                3 ngày\n'
#  '\n                Trung bình:                5 ngày\n'
#  '\n                Trung bình:                9 ngày\n'
#  '\n                Trung bình:                15 ngày\n'
#  '\n                Trung bình:                1 ngày\n'
#  '\n                Trung bình:                7 ngày\n'
#  '\n                Trung bình:                27 ngày\n'
#  '\n                Trung bình:                10 ngày\n'
#  '\n                Trung bình:                33 ngày\n'
#  '\n                Trung bình:                21 ngày\n'
#  '\n                Trung bình:                6 ngày\n'
#  '\n                Trung bình:                0 ngày\n'
#  '\n                Trung bình:                4 ngày\n'
#  '\n                Trung bình:                14 ngày\n'
#  '\n                Trung bình:                12 ngày\n'
#  '\n                Trung bình:                23 ngày\n'
#  '\n                Trung bình:                17 ngày\n'
#  '\n                Trung bình:                16 ngày\n'
#  '\n                Trung bình:                19 ngày\n'
#  '\n                Trung bình:                2 ngày\n'
#  '\n                Trung bình:                8 ngày\n'
#  '\n                Trung bình:                18 ngày\n'
#  '\n                Trung bình:                25 ngày\n'
#  '\n                Trung bình:                24 ngày\n'
#  '\n                Trung bình:                13 ngày\n'
#  '\n                Trung bình:                11 ngày\n'
#  '\n                Trung bình:                28 ngày\n'
#  '\n                Trung bình:                30 ngày\n'
#  '\n                Trung bình:                26 ngày\n'
#  '\n                Trung bình:                29 ngày\n'
#  '\n                Trung bình:                20 ngày\n'
#  '\n                Trung bình:                22 ngày\n'
#  '\n                Trung bình:                35 ngày\n'
#  '\n                Trung bình:                42 ngày\n'
#  '\n                Trung bình:                -3 ngày\n'
#  '\n                Trung bình:                34 ngày\n'
#  '\n                Trung bình:                31 ngày\n'
#  '\n                Trung bình:                37 ngày\n'
#  '\n                Trung bình:                39 ngày\n'
#  '\n                Trung bình:                -2 ngày\n'
#  '\n                Trung bình:                32 ngày\n'
#  '\n                Trung bình:                36 ngày\n']

# %%
#đổi tên cột Duration thành Duration (ngày)
df.rename(columns={"Duration": "Duration (ngày)"}, inplace=True)
#chỉ giữ số trong cột Duration (ngày)
df["Duration (ngày)"] = df["Duration (ngày)"].str.replace(r'\n|\s+|Trung bình:|ngày|-', '', regex=True).str.strip()
df["Duration (ngày)"].unique()
# Out:
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\574547533.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"Duration": "Duration (ngày)"}, inplace=True)
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\574547533.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["
#        '200.000đ - 9.999.999đ', '4.444.444đ - 7.777.777đ',
#        '36.000.000đ - 48.000.000đ', '14.000.000đ - 20.000.000đ',
#        '420.000đ - 500.000đ', '1.500.000đ - 4.000.000đ',
#        '30.000.000đ - 75.000.000đ', '80.000.000đ - 150.000.000đ',
#        '8.000.000đ - 50.000.000đ', '200.000đ - 1.300.000đ',
#        '12.000.000đ - 30.000.000đ', '250.000đ - 7.000.000đ',
#        '250.000đ - 5.000.000đ', '23.000.000đ - 50.000.000đ',
#        '1.001.000đ - 10.001.000đ', '15.000.000đ - 24.000.000đ',
#        '4.000.000đ - 6.500.000đ', '6.400.000đ - 9.600.000đ',
#        '60.000.000đ - 150.000.000đ', '34.500.000đ - 115.000.000đ',
#        '80.000.000đ - 90.000.000đ', '210.000đ - 1.835.253đ',
#        '200.000đ - 1.495.000đ', '210.000đ - 2.000.000đ',
#        '400.000đ - 40.000.000đ', '500.000đ - 575.000đ',
#        '500.000đ - 3.000.300đ', '210.000đ - 1.000.000đ',
#        '3.000.000đ - 10.001.000đ', '2.400.000đ - 2.500.000đ',
#        '50.000.000đ - 55.000.000đ', '3.000.000đ - 3.100.000đ',
#        '11.000.000đ - 22.000.000đ', '100.000.000đ - 101.000.000đ',
#        '5.500.000đ - 6.000.000đ', '22.000.000đ - 34.368.355đ',
#        '800.000đ - 915.000đ', '14.000.000đ - 30.000.000đ',
#        '3.000.000đ - 13.000.000đ', '12.000.000đ - 14.000.000đ',
#        '1.232.222đ - 2.000.001đ', '1.000.000đ - 99.999.999đ',
#        '2.300.000đ', '960.000đ - 1.270.000đ', '25.000.000đ - 32.000.000đ',
#        '50.000.000đ - 75.000.000đ', '30.000.000đ - 65.000.000đ',
#        '9.999.999đ - 99.999.999đ', '345.000đ - 670.000đ', '5.000.005đ',
#        '7.000.000đ - 50.000.000đ', '75.000.000đ', '1.750.000đ',
#        '3.000.000đ - 180.000.000đ', '15.500.000đ', '80.005.000đ',
#        '3.000.000đ - 35.000.000đ', '3.000.000đ - 70.000.000đ',
#        '3.000.000đ - 66.000.000đ'], dtype=object)

# %%
# Hàm để tách ngân sách thấp nhất và cao nhất
def parse_budget(budget):
    # Xóa ký tự 'đ' và chuyển đổi thành số nguyên
    budget = budget.replace('đ', '').replace('.', '').strip()
    
    # Kiểm tra có dấu '-' không
    if '-' in budget:
        low, high = budget.split('-')
        return (float(low.strip()), float(high.strip()))
    else:
        # Không có dấu '-', gán ngân sách thấp nhất là 0
        return (0.0, float(budget))

# %%
# Áp dụng hàm để tách ngân sách
df[['Ngân sách thấp nhất', 'Ngân sách cao nhất']] = df['Ngân sách'].apply(parse_budget).apply(pd.Series)
# Out:
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\3959358976.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Ngân sách thấp nhất', 'Ngân sách cao nhất']] = df['Ngân sách'].apply(parse_budget).apply(pd.Series)
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\3959358976.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Ngân sách thấp nhất', 'Ngân sách cao nhất']] = df['Ngân sách'].apply(parse_budget).apply(pd.Series)

# %%
df.columns
# Out:
# Index(['Type', 'Title', 'Services', 'Skills', 'Description', 'In4_project',
#        'In4_employment', 'Num_applicants', 'Applicants', 'Duration (ngày)',
#        'Price', 'Link', 'ID dự án', 'Ngày đăng', 'Chỉ còn', 'Địa điểm',
#        'Ngân sách', 'Hình thức làm việc', 'Hình thức trả lương',
#        'Chào giá thấp nhất', 'Chào giá trung bình', 'Chào giá cao nhất',
#        'Ngân sách thấp nhất', 'Ngân sách cao nhất'],
#       dtype='object')

# %%
#Cỉ lấy các cột cần thiết: ID dự án, Type, Title, Services, Skills, Description, Ngày đăng , Chỉ còn , Địa điểm ,Ngân sách thấp nhất, Ngân sách cao nhất, Hình thức làm việc, Hình thức trả lương, Num_applicants, Chào giá thấp nhất, Chào giá trung bình, Chào giá cao nhất, Duration (ngày)
df = df[['ID dự án', 'Type', 'Title', 'Services', 'Skills', 'Description', 'Ngày đăng', 'Chỉ còn', 'Địa điểm', 'Ngân sách thấp nhất', 'Ngân sách cao nhất', 'Hình thức làm việc', 'Hình thức trả lương', 'Num_applicants', 'Chào giá thấp nhất', 'Chào giá trung bình', 'Chào giá cao nhất', 'Duration (ngày)', "Link"]]
df
# Out:
#       ID dự án           Type  \
# 0        42059  Nhận chào giá
# 1        42057      Đăng việc
# 2        42052      Đăng việc
# 3        42051      Đăng việc
# 4        42044      Đăng việc
# ...        ...            ...
# 11448    42064      Đăng việc
# 11449    42063      Đăng việc
# 11450    42056      Đăng việc
# 11451    42059  Nhận chào giá
# 11452    42057      Đăng việc
#
#                                                    Title  \
# 0                            Chỉnh sửa website Wordpress
# 1      Mình cần làm 1 web bán hàng và giới thiệu sản ...
# 2       Thiết kế trang Web từ file thiết kế đã làm (PSD)
# 3                                     Mobile APP nhà cái
# 4                           Clone 1 trang bằng Elementor
# ...                                                  ...
# 11448          Sửa code plugin theo đúng chuẩn wordpress
# 11449                                     Thiết kế UI/UX
# 11450  Viết lại script theo yêu cầu mới để có thể chạ...
# 11451                        Chỉnh sửa website Wordpress
# 11452  Mình cần làm 1 web bán hàng và giới thiệu sản ...
#
#                           Services                                     Skills  \
# 0       Viết phần mềm theo yêu cầu              Wordpress, responsive, design
# 1            Dựng website bán hàng                                   Bán hàng
# 2              Cắt HTML/CSS từ PSD         Tiếng Anh, PSD, Thiết kế trang web
# 3      Làm Mobile App theo yêu cầu                                  iOS, code
# 4       Thiết kế giao diện website                                  Wordpress
# ...                            ...                                        ...
# 11448   Viết phần mềm theo yêu cầu  PHP, Wordpress, Plugin, code, Woocommerce
# 11449   Thiết kế giao diện website       iOS, Graphic Design, Android, design
# 11450   Viết phần mềm theo yêu cầu     Javascript, jQuery, Thiết kế giao diện
# 11451   Viết phần mềm theo yêu cầu              Wordpress, responsive, design
# 11452        Dựng website bán hàng                                   Bán hàng
#
#                                              Description          Ngày đăng  \
# 0      Yêu cầu:  Làm giống Design thêm Responsive trê...  27/08/2020, 13:45
# 1      Website không yêu cầu nhiều chỉ cần giao diện ...  27/08/2020, 12:23
# 2      Công ty mình cần tuyển một bạn Freelancer làm ...  27/08/2020, 08:43
# 3      App chỉ có chức năng gọi API kết quả bóng đá v...  27/08/2020, 05:00
# 4      Mình cần clone lại chỉ 1 trang này: tidal.com/...  26/08/2020, 22:03
# ...                                                  ...                ...
# 11448  Hi all,  Tôi cần tìm một wordpress dev expert ...  27/08/2020, 21:43
# 11449  Xin chào  Hiện tại bên công ty mình đang cần d...  27/08/2020, 17:06
# 11450  +OLDED: Script đang chạy được trên trang https...  27/08/2020, 11:44
# 11451  Yêu cầu:  Làm giống Design thêm Responsive trê...  27/08/2020, 13:45
# 11452  Website không yêu cầu nhiều chỉ cần giao diện ...  27/08/2020, 12:23
#
#                      Chỉ còn         Địa điểm  Ngân sách thấp nhất  \
# 0              Đã hoàn thành           Hà Nội                  0.0
# 1      Hết hạn nhận chào giá  TP. Hồ Chí Minh                  0.0
# 2      Hết hạn nhận chào giá           Hà Nội                  0.0
# 3      Hết hạn nhận chào giá        Toàn Quốc                  0.0
# 4      Hết hạn nhận chào giá        Toàn Quốc                  0.0
# ...                      ...              ...                  ...
# 11448  Hết hạn nhận chào giá        Toàn Quốc                  0.0
# 11449  Hết hạn nhận chào giá  TP. Hồ Chí Minh                  0.0
# 11450  Hết hạn nhận chào giá        Toàn Quốc                  0.0
# 11451          Đã hoàn thành           Hà Nội                  0.0
# 11452  Hết hạn nhận chào giá  TP. Hồ Chí Minh                  0.0
#
#        Ngân sách cao nhất Hình thức làm việc Hình thức trả lương  \
# 0               4000000.0  Làm tại văn phòng      Trả theo dự án
# 1               2000000.0  Làm tại văn phòng      Trả theo dự án
# 2              20000000.0  Làm tại văn phòng      Trả theo dự án
# 3              20000000.0  Làm tại văn phòng      Trả theo dự án
# 4                300000.0  Làm tại văn phòng      Trả theo dự án
# ...                   ...                ...                 ...
# 11448           1000000.0  Làm tại văn phòng      Trả theo dự án
# 11449          10000000.0  Làm tại văn phòng      Trả theo dự án
# 11450           3000000.0  Làm tại văn phòng      Trả theo dự án
# 11451           4000000.0  Làm tại văn phòng      Trả theo dự án
# 11452           2000000.0  Làm tại văn phòng      Trả theo dự án
#
#       Num_applicants  Chào giá thấp nhất  Chào giá trung bình  \
# 0                  1           2000000.0            2000000.0
# 1                  9           2000000.0            2777778.0
# 2                 16           2000000.0           10250000.0
# 3                  5           1500000.0           34700000.0
# 4                  3            300000.0             433333.0
# ...              ...                 ...                  ...
# 11448              1           2000000.0            2000000.0
# 11449              9           5000000.0            9222222.0
# 11450              2           3000000.0            4000000.0
# 11451              1           2000000.0            2000000.0
# 11452              9           2000000.0            2777778.0
#
#        Chào giá cao nhất Duration (ngày)  \
# 0              2000000.0               3
# 1              5500000.0               5
# 2             20000000.0               9
# 3            100000000.0              15
# 4               500000.0               1
# ...                  ...             ...
# 11448          2000000.0               3
# 11449         10000000.0               8
# 11450          5000000.0               2
# 11451          2000000.0               3
# 11452          5500000.0               5
#
#                                                     Link
# 0      https://www.vlance.vn/viec-freelance/chinh-sua...
# 1      https://www.vlance.vn/viec-freelance/minh-can-...
# 2      https://www.vlance.vn/viec-freelance/thiet-ke-...
# 3      https://www.vlance.vn/viec-freelance/mobile-ap...
# 4      https://www.vlance.vn/viec-freelance/clone-1-t...
# ...                                                  ...
# 11448  https://www.vlance.vn/viec-freelance/sua-code-...
# 11449  https://www.vlance.vn/viec-freelance/thiet-ke-...
# 11450  https://www.vlance.vn/viec-freelance/viet-lai-...
# 11451  https://www.vlance.vn/viec-freelance/chinh-sua...
# 11452  https://www.vlance.vn/viec-freelance/minh-can-...
#
# [11453 rows x 19 columns]

# %%
#Tính tỉ lệ null của các cột
df.isnull().mean() * 100
# Out:
# ID dự án                0.000000
# Type                    0.000000
# Title                   0.000000
# Services                0.812014
# Skills                 16.781629
# Description             0.000000
# Ngày đăng               0.000000
# Chỉ còn                 0.000000
# Địa điểm                0.000000
# Ngân sách thấp nhất     0.000000
# Ngân sách cao nhất      0.000000
# Hình thức làm việc      0.000000
# Hình thức trả lương     0.000000
# Num_applicants          0.000000
# Chào giá thấp nhất      0.000000
# Chào giá trung bình     0.043657
# Chào giá cao nhất       0.000000
# Duration (ngày)         0.000000
# Link                    0.000000
# dtype: float64

# %%
df[df["Chào giá trung bình"].isnull()]
# Out:
#      ID dự án           Type  \
# 746     40097  Nhận chào giá
# 883     39786  Nhận chào giá
# 1101    39283  Nhận chào giá
# 1304    38848  Nhận chào giá
# 1454    38459  Nhận chào giá
#
#                                                   Title  \
# 746   Phần mềm quản lý tài sản cố định, thiết bị ngà...
# 883                      Viết thêm toolbox cho surveyjs
# 1101  App tracking vị trí người dùng nhiễm virus cor...
# 1304  Viết tool check và sửa giá tự động trên sản TM...
# 1454                Dựng lại trang web theo website mẫu
#
#                                           Services  \
# 746                     Viết phần mềm theo yêu cầu
# 883                                  Xử lý dữ liệu
# 1101                   Làm Mobile App theo yêu cầu
# 1304                    Viết phần mềm theo yêu cầu
# 1454  Xây dựng Web App MVP (Minium Viable Product)
#
#                                                  Skills  \
# 746   .NET, ASP, Bootstrap, jQuery, ASP.NET, Angular...
# 883                                                 NaN
# 1101                                                NaN
# 1304                                 Lập trình phần mềm
# 1454                                          Wordpress
#
#                                             Description          Ngày đăng  \
# 746   Chúng tôi cần tìm đối tác xây dựng phần mềm qu...  14/05/2020, 20:41
# 883   Xin chào  Hiện tại mình thêm 1 mục điền vào vă...  28/04/2020, 10:26
# 1101  Nội dung App:  - Cung cấp khai báo về tình trạ...  29/03/2020, 17:30
# 1304  Mình bán hàng trên Tiki, Tiki có kiểu là bài b...  05/03/2020, 22:20
# 1454  Cần dựng lại website wordpress theo website mẫ...  15/02/2020, 02:04
#
#                     Chỉ còn         Địa điểm  Ngân sách thấp nhất  \
# 746   Hết hạn nhận chào giá  TP. Hồ Chí Minh                  0.0
# 883   Hết hạn nhận chào giá  TP. Hồ Chí Minh                  0.0
# 1101  Hết hạn nhận chào giá        Toàn Quốc                  0.0
# 1304  Hết hạn nhận chào giá        Toàn Quốc                  0.0
# 1454  Hết hạn nhận chào giá           Hà Nội                  0.0
#
#       Ngân sách cao nhất Hình thức làm việc Hình thức trả lương  \
# 746          100000000.0  Làm tại văn phòng      Trả theo dự án
# 883            1000000.0  Làm tại văn phòng      Trả theo dự án
# 1101          10000000.0  Làm tại văn phòng      Trả theo dự án
# 1304           2000000.0  Làm tại văn phòng      Trả theo dự án
# 1454           5000000.0  Làm tại văn phòng      Trả theo dự án
#
#      Num_applicants  Chào giá thấp nhất  Chào giá trung bình  \
# 746              21          12000000.0                  NaN
# 883               2           1500000.0                  NaN
# 1101              5          10000000.0                  NaN
# 1304              4           3000000.0                  NaN
# 1454              8           5000000.0                  NaN
#
#       Chào giá cao nhất Duration (ngày)  \
# 746         200000000.0              17
# 883           1500000.0               3
# 1101         10000000.0              16
# 1304          4000000.0               4
# 1454         10000000.0               8
#
#                                                    Link
# 746   https://www.vlance.vn/viec-freelance/phan-mem-...
# 883   https://www.vlance.vn/viec-freelance/viet-them...
# 1101  https://www.vlance.vn/viec-freelance/app-track...
# 1304  https://www.vlance.vn/viec-freelance/viet-tool...
# 1454  https://www.vlance.vn/viec-freelance/dung-lai-...

# %%
#in ra dòng mà Chào giá trung bình là null

#fill null bằng giá trị trung bình Chào giá thấp nhất và Chào giá cao nhất/2
df["Chào giá trung bình"].fillna((df["Chào giá thấp nhất"] + df["Chào giá cao nhất"]) / 2, inplace=True)
# Out:
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\2963994882.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Chào giá trung bình"].fillna((df["Chào giá thấp nhất"] + df["Chào giá cao nhất"]) / 2, inplace=True)
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\2963994882.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Chào giá trung bình"].fillna((df["Chào giá thấp nhất"] + df["Chào giá cao nhất"]) / 2, inplace=True)

# %%
#Điền Service bằng mode 
df["Services"].fillna(df["Services"].mode()[0], inplace=True)
# Out:
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\1531877793.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Services"].fillna(df["Services"].mode()[0], inplace=True)
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\1531877793.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Services"].fillna(df["Services"].mode()[0], inplace=True)

# %%
#in ra các dòng mà Skills là null và Link
df[df["Skills"].isnull()]["Link"]
# Out:
# 13       https://www.vlance.vn/viec-freelance/chinh-sua...
# 21       https://www.vlance.vn/viec-freelance/thiet-ke-...
# 24       https://www.vlance.vn/viec-freelance/viet-srci...
# 37       https://www.vlance.vn/viec-freelance/design-a-...
# 43       https://www.vlance.vn/viec-freelance/phat-trie...
#                                ...
# 11420    https://www.vlance.vn/viec-freelance/minh-can-...
# 11425    https://www.vlance.vn/viec-freelance/customize...
# 11426    https://www.vlance.vn/viec-freelance/thiet-ke-...
# 11436    https://www.vlance.vn/viec-freelance/tim-don-v...
# 11442           https://www.vlance.vn/viec-lam/black-coder
# Name: Link, Length: 1922, dtype: object

# %%
#điền Skills bằng mode
df["Skills"].fillna(df["Skills"].mode()[0], inplace=True)
# Out:
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\1782406455.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Skills"].fillna(df["Skills"].mode()[0], inplace=True)
# C:\Users\kt061\AppData\Local\Temp\ipykernel_17088\1782406455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Skills"].fillna(df["Skills"].mode()[0], inplace=True)

# %%
len(df["Skills"].unique())
# Out:
# 5060

# %%
# Tạo từ điển để ánh xạ tên cột từ tiếng Việt sang tiếng Anh
column_mapping = {
    'ID dự án': 'Project ID',
    'Ngày đăng': 'Posted Date',
    'Chỉ còn': 'Remaining Days',
    'Địa điểm': 'Location',
    'Ngân sách thấp nhất': 'Minimum Budget',
    'Ngân sách cao nhất': 'Maximum Budget',
    'Hình thức làm việc': 'Working Type',
    'Hình thức trả lương': 'Payment Type',
    'Chào giá thấp nhất': 'Lowest Bid',
    'Chào giá trung bình': 'Average Bid',
    'Chào giá cao nhất': 'Highest Bid',
    'Duration (ngày)': 'Duration (Days)',
}

# Áp dụng ánh xạ để đổi tên cột
df = df.rename(columns=column_mapping)

# Kiểm tra lại tên cột sau khi đổi tên
print(df.columns)
# Out:
# Index(['Project ID', 'Type', 'Title', 'Services', 'Skills', 'Description',
#        'Posted Date', 'Remaining Days', 'Location', 'Minimum Budget',
#        'Maximum Budget', 'Working Type', 'Payment Type', 'Num_applicants',
#        'Lowest Bid', 'Average Bid', 'Highest Bid', 'Duration (Days)', 'Link'],
#       dtype='object')

# %%
df
# Out:
#       Project ID           Type  \
# 0          42059  Nhận chào giá
# 1          42057      Đăng việc
# 2          42052      Đăng việc
# 3          42051      Đăng việc
# 4          42044      Đăng việc
# ...          ...            ...
# 11448      42064      Đăng việc
# 11449      42063      Đăng việc
# 11450      42056      Đăng việc
# 11451      42059  Nhận chào giá
# 11452      42057      Đăng việc
#
#                                                    Title  \
# 0                            Chỉnh sửa website Wordpress
# 1      Mình cần làm 1 web bán hàng và giới thiệu sản ...
# 2       Thiết kế trang Web từ file thiết kế đã làm (PSD)
# 3                                     Mobile APP nhà cái
# 4                           Clone 1 trang bằng Elementor
# ...                                                  ...
# 11448          Sửa code plugin theo đúng chuẩn wordpress
# 11449                                     Thiết kế UI/UX
# 11450  Viết lại script theo yêu cầu mới để có thể chạ...
# 11451                        Chỉnh sửa website Wordpress
# 11452  Mình cần làm 1 web bán hàng và giới thiệu sản ...
#
#                           Services                                     Skills  \
# 0       Viết phần mềm theo yêu cầu              Wordpress, responsive, design
# 1            Dựng website bán hàng                                   Bán hàng
# 2              Cắt HTML/CSS từ PSD         Tiếng Anh, PSD, Thiết kế trang web
# 3      Làm Mobile App theo yêu cầu                                  iOS, code
# 4       Thiết kế giao diện website                                  Wordpress
# ...                            ...                                        ...
# 11448   Viết phần mềm theo yêu cầu  PHP, Wordpress, Plugin, code, Woocommerce
# 11449   Thiết kế giao diện website       iOS, Graphic Design, Android, design
# 11450   Viết phần mềm theo yêu cầu     Javascript, jQuery, Thiết kế giao diện
# 11451   Viết phần mềm theo yêu cầu              Wordpress, responsive, design
# 11452        Dựng website bán hàng                                   Bán hàng
#
#                                              Description        Posted Date  \
# 0      Yêu cầu:  Làm giống Design thêm Responsive trê...  27/08/2020, 13:45
# 1      Website không yêu cầu nhiều chỉ cần giao diện ...  27/08/2020, 12:23
# 2      Công ty mình cần tuyển một bạn Freelancer làm ...  27/08/2020, 08:43
# 3      App chỉ có chức năng gọi API kết quả bóng đá v...  27/08/2020, 05:00
# 4      Mình cần clone lại chỉ 1 trang này: tidal.com/...  26/08/2020, 22:03
# ...                                                  ...                ...
# 11448  Hi all,  Tôi cần tìm một wordpress dev expert ...  27/08/2020, 21:43
# 11449  Xin chào  Hiện tại bên công ty mình đang cần d...  27/08/2020, 17:06
# 11450  +OLDED: Script đang chạy được trên trang https...  27/08/2020, 11:44
# 11451  Yêu cầu:  Làm giống Design thêm Responsive trê...  27/08/2020, 13:45
# 11452  Website không yêu cầu nhiều chỉ cần giao diện ...  27/08/2020, 12:23
#
#               Remaining Days         Location  Minimum Budget  Maximum Budget  \
# 0              Đã hoàn thành           Hà Nội             0.0       4000000.0
# 1      Hết hạn nhận chào giá  TP. Hồ Chí Minh             0.0       2000000.0
# 2      Hết hạn nhận chào giá           Hà Nội             0.0      20000000.0
# 3      Hết hạn nhận chào giá        Toàn Quốc             0.0      20000000.0
# 4      Hết hạn nhận chào giá        Toàn Quốc             0.0        300000.0
# ...                      ...              ...             ...             ...
# 11448  Hết hạn nhận chào giá        Toàn Quốc             0.0       1000000.0
# 11449  Hết hạn nhận chào giá  TP. Hồ Chí Minh             0.0      10000000.0
# 11450  Hết hạn nhận chào giá        Toàn Quốc             0.0       3000000.0
# 11451          Đã hoàn thành           Hà Nội             0.0       4000000.0
# 11452  Hết hạn nhận chào giá  TP. Hồ Chí Minh             0.0       2000000.0
#
#             Working Type    Payment Type Num_applicants  Lowest Bid  \
# 0      Làm tại văn phòng  Trả theo dự án              1   2000000.0
# 1      Làm tại văn phòng  Trả theo dự án              9   2000000.0
# 2      Làm tại văn phòng  Trả theo dự án             16   2000000.0
# 3      Làm tại văn phòng  Trả theo dự án              5   1500000.0
# 4      Làm tại văn phòng  Trả theo dự án              3    300000.0
# ...                  ...             ...            ...         ...
# 11448  Làm tại văn phòng  Trả theo dự án              1   2000000.0
# 11449  Làm tại văn phòng  Trả theo dự án              9   5000000.0
# 11450  Làm tại văn phòng  Trả theo dự án              2   3000000.0
# 11451  Làm tại văn phòng  Trả theo dự án              1   2000000.0
# 11452  Làm tại văn phòng  Trả theo dự án              9   2000000.0
#
#        Average Bid  Highest Bid Duration (Days)  \
# 0        2000000.0    2000000.0               3
# 1        2777778.0    5500000.0               5
# 2       10250000.0   20000000.0               9
# 3       34700000.0  100000000.0              15
# 4         433333.0     500000.0               1
# ...            ...          ...             ...
# 11448    2000000.0    2000000.0               3
# 11449    9222222.0   10000000.0               8
# 11450    4000000.0    5000000.0               2
# 11451    2000000.0    2000000.0               3
# 11452    2777778.0    5500000.0               5
#
#                                                     Link
# 0      https://www.vlance.vn/viec-freelance/chinh-sua...
# 1      https://www.vlance.vn/viec-freelance/minh-can-...
# 2      https://www.vlance.vn/viec-freelance/thiet-ke-...
# 3      https://www.vlance.vn/viec-freelance/mobile-ap...
# 4      https://www.vlance.vn/viec-freelance/clone-1-t...
# ...                                                  ...
# 11448  https://www.vlance.vn/viec-freelance/sua-code-...
# 11449  https://www.vlance.vn/viec-freelance/thiet-ke-...
# 11450  https://www.vlance.vn/viec-freelance/viet-lai-...
# 11451  https://www.vlance.vn/viec-freelance/chinh-sua...
# 11452  https://www.vlance.vn/viec-freelance/minh-can-...
#
# [11453 rows x 19 columns]

# %%
#ghi xuống file csv ..\..\..\..\..\data\processed\cleaned_job_posts.csv
df.to_csv(r'..\..\..\..\data\processed\cleaned_job_posts.csv', index=False)
